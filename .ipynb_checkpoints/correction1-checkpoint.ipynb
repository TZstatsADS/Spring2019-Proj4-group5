# %%
import correction_lib as corr
from word_dict import Create_Words_Dictionary, Create_Word_Pair
import string
import glob
import os
import itertools
import collections
import timeit
import random
import pandas as pd
import numpy as np

# %%
def clean_word(w):
    out = []
    for c in w:
        c = c.lower()
        # Searching set is faster than list: O(1) vs. O(n=26)
        if c in set(string.ascii_lowercase):
            out.append(c)
    return(''.join(out))

def char_to_index(c):
    if c=="{":
        return(26)
    else:
        return(ord(c) - ord('a'))

# %%
word_list = []
gt_filenames = glob.glob(os.path.join(os.getcwd(), 'data', 'ground_truth', '*.txt'))

count = 0
for gt_f in gt_filenames:
    with open(gt_f) as file:
        raw = file.read()
        # Split file content into words (by '\n', '\t', ' ', etc.)
        uncleaned_words = raw.split()
        
        # Clean up words, leave only all-alpha chars of length > 1 (function programming)
        word_list += list(filter(lambda x: 1 < len(x) < 21, map(clean_word, uncleaned_words)))
        
word_set=set(word_list)

# %%
group_by_len = collections.defaultdict(list)
for w in word_set:
    group_by_len[len(w)].append(w)

# A dictionary of positional binary digrams (matrices),
# ordered by word length and then by binary positions
digrams_by_len = collections.defaultdict(dict)
for length in group_by_len:
    for i, j in itertools.combinations(range(length), 2):
        key = (i, j)
        matrix = [[0] * 26 for _ in range(26)]
        for w in group_by_len[length]:
            matrix[char_to_index(w[i])][char_to_index(w[j])] = 1
        digrams_by_len[length][key] = matrix

# %%
tmp=pd.read_csv("detection.csv")
tr_word_list=tmp['tokens_tesseract'].tolist()
tr_word_list=list(map(str,tr_word_list))
tr_word_list=list(filter(lambda x: 1 < len(x) < 21, map(clean_word, tr_word_list)))
# print(tr_word_list)
tr_word_list=np.unique(tr_word_list)

# %%
detected_error_tuples = []
for idx, w in enumerate(tr_word_list):
    error = False
    for i, j in itertools.combinations(range(len(w)), 2):
#         print(i, j, w[i], w[j], len(digrams_by_len[len(w)][(i, j)]), len(digrams_by_len[len(w)][(i, j)][0]))
        if not digrams_by_len[len(w)][(i, j)][char_to_index(w[i])][char_to_index(w[j])]:
            error = True
    if error:
        left = tr_word_list[i-1] if i > 0 else ''
        right = tr_word_list[i+1] if i < len(tr_word_list)-1 else ''
        detected_error_tuples.append((w, left, right))

# A list of detected error words
detected_error_words = [x[0] for x in detected_error_tuples]

# %%
#改动
# read Confusion matrix
add_matrix=np.array(pd.read_csv("./data/confusion_matrix/add_matrix.csv",index_col=0))
del_matrix=np.array(pd.read_csv("./data/confusion_matrix/del_matrix.csv",index_col=0))
rev_matrix=np.array(pd.read_csv("./data/confusion_matrix/rev_matrix.csv",index_col=0))
sub_matrix=np.array(pd.read_csv("./data/confusion_matrix/sub_matrix.csv",index_col=0))

# Useful values from section 3 of paper C-4.
N = len(word_list)
V = len(word_set)
denominator = N + V/2

# %%
print(N)
# Out:
# 277888

# %%
print(V)
# Out:
# 15702

# %%
def get_correction_candidates(w):
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    candidate_list = [[] for _ in range(4)]
    
    ### 4 kinds of correction candidates (see Table 2, C-4)
    # 0. Deletion
    for i in range(len(w) + 1):
        for c in alphabet:
            correction = w[:i] + c + w[i:]
            if correction in word_set:
                diff = corr.find_deletion_letters(correction, w) 
                candidate_list[0].append((correction, diff['pre_letter'], diff['delete_letter']))
            
    # 1. Insertion
    for i in range(len(w)):
        correction = w[:i] + w[i+1:]
        if correction in word_set:
            diff = corr.find_insertion_letters(correction, w) 
            candidate_list[1].append((correction, diff['pre_letter'], diff['insert_letter']))
    
    # 2. Substitution
    for i in range(len(w)):
        for c in alphabet:
            if c != w[i]:
                correction = w[:i] + c + w[i+1:]
                if correction in word_set:
                    diff = corr.find_sub_rev_letters(correction, w) 
                    if diff['tag'] == 'sub':
                        candidate_list[2].append((correction, diff['pre_letter'], diff['changed_letter']))
    
    # 3. Reversal
    for i in range(len(w) - 1):
        correction = w[:i] + w[i+1] + w[i] + w[i+2:]
        if correction in word_set:
            diff = corr.find_sub_rev_letters(correction, w) 
            if diff['tag'] == 'rev':
                candidate_list[3].append((correction, diff['pre_letter'], diff['changed_letter']))
    
    return(candidate_list)

# %%
get_correction_candidates('responder')
# Out:
# [[('responders', 'r', 's')], [], [('responded', 'd', 'r')], []]

# %%
#read detected words from detection
import re
detection=pd.read_excel('detection.xlsx')
detected_error_words=[str(i) for i in np.array(detection['tokens_tesseract'])]
detected_error_words=[''.join(re.findall('[a-z]+',i)) for i in detected_error_words]
# detection.info()

# %%
start = timeit.default_timer()

all_candidates = collections.defaultdict(list)
for word in detected_error_words:
    all_candidates[word] = get_correction_candidates(word)
    
stop = timeit.default_timer()
print('Time:', stop - start, 'seconds')
# Out:
# Time: 2.572426127999279 seconds

# %%
# all_candidates = collections.defaultdict(list)
temp=['admlnlstratlon','responder','responder']
# for word in temp:
#     all_candidates[word] = get_correction_candidates(word)
# all_candidates
print(detected_error_words[0:10])
print(temp)
# Out:
# ['admlnlstratlon', 'exemptlons', 'ommlttee', 'closediloop', 'n', 'whlch', 'responder', 'authorlty', 'sso', 'olunteers']
# ['admlnlstratlon', 'responder', 'responder']

# %%
all_candidates['admlnlstratlon']
# Out:
# [[], [], [], []]

# %%
word_freqs = collections.defaultdict(int)
for word in word_list:
    word_freqs[word] += 1
# print(dict((k, v) for k, v in word_freqs.items() if v >= 2))

# Pr(c) of all possible corrections (all words from ground truth)
word_freqs_freqs = {}
for freqs in word_freqs.values():
    if freqs in word_freqs_freqs.keys():
        word_freqs_freqs[freqs] += 1
    else:
        word_freqs_freqs[freqs] = 1
word_freqsN = {}
for k in word_freqs_freqs.keys():
    if k + 1  in word_freqs_freqs.keys():
        word_freqsN[k+1] = word_freqs_freqs[k+1]
    else:
        word_freqsN[k+1] = 0.5
N1 = 0
for j in word_freqsN.keys():
    N1 = N1 + j*word_freqsN[j]
word_freqs_freqsfinal = {}
for k in word_freqs_freqs.keys():
    word_freqs_freqsfinal[k] = word_freqs_freqs[k]
    if k + 1  in word_freqs_freqs.keys():
        word_freqs_freqsfinal[k+1] = word_freqs_freqs[k+1]
    else:
        word_freqs_freqsfinal[k+1] = 0.5

corr_probs_mle = collections.defaultdict(float)
for word, freq in word_freqs.items():
    corr_probs_mle[word] =freq/N
corr_probs_ele = collections.defaultdict(float)
for word, freq in word_freqs.items():
    corr_probs_ele[word] = (freq + 0.5)/denominator
corr_probs_gt = collections.defaultdict(float)
for word, freq in word_freqs.items():
    corr_probs_gt[word] = (freq + 1)*word_freqs_freqsfinal[freqs + 1]/word_freqs_freqsfinal[freqs]/N1

# %%
def is_empty(any_structure):
    if any_structure:
        return False
    else:
        return True

# %%
def get_Pr_c(correction,method):
    if method == "MLE":
        return(corr_probs_mle[correction])
    elif method == "ELE":
        return(corr_probs_ele[correction])
    else:
        return(corr_probs_gt[correction])

# %%
# chars[x] and chars[xy]
# word_list=['abcdefg','awses']
chars_x = np.zeros(27)
chars_x[26] = len(word_list)
chars_xy = np.zeros([27,26])
print(chars_xy.shape)
for word in word_list:
    for i, c in enumerate(word):
        chars_x[char_to_index(c)] += 1
        if i==0:
            chars_xy[26][char_to_index(c)] += 1
        else:
            chars_xy[char_to_index(word[i-1])][char_to_index(c)] += 1
for i in range(len(chars_xy)):
    for j in range(len(chars_xy[0])):
        if not chars_xy[i][j]:
            chars_xy[i][j] = 0.5
# Out:
# (27, 26)

# %%
def get_Pr_tc(pre, cur, error_type):
        if pre == None and cur == None:
            return 0
        if error_type == 'del':
            t =  del_matrix[char_to_index(pre)][char_to_index(cur)] \
                   / chars_xy[char_to_index(pre)][char_to_index(cur)]
            if t:
                return t
            else:
                return 0
        if error_type == 'add':
            t = add_matrix[char_to_index(pre)][char_to_index(cur)] \
                   / chars_x[char_to_index(pre)]
            if t:
                return t
            else:
                return 0
        if error_type == 'sub':
            t =  sub_matrix[char_to_index(pre)][char_to_index(cur)] \
                   / chars_x[char_to_index(pre)]
            if t:
                return t
            else:
                return 0
        if error_type == 'rev':
            t = rev_matrix[char_to_index(pre)][char_to_index(cur)] \
                   / chars_xy[char_to_index(pre)][char_to_index(cur)]
            if t:
                return t
            else:
                return 0

# %%
neighbor_dict = Create_Words_Dictionary()
neighbor_dict
# Out:
# {'communications': {'left': {'requirements': 1,
#    'spring': 1,
#    'crisis': 1,
#    'develop': 1,
#    'may': 1,
#    'communications': 1,
#    'the': 38,
#    'cmas': 9,
#    'company': 1,
#    'of': 12,
#    'exhibit': 2,
#    'management': 1,
#    'hasard': 1,
#    'on': 2,
#    'case': 1,
#    'mca': 1,
#    'industrys': 6,
#    'areas': 2,
#    'this': 4,
#    'early': 1,
#    'workshops': 1,
#    'regional': 8,
#    'and': 19,
#    'risk': 1,
#    'other': 2,
#    'hazards': 7,
#    'hazard': 4,
#    'without': 1,
#    'arrangements': 1,
#    'issues': 1,
#    'cma': 11,
#    'cic': 1,
#    'in': 2,
#    'emergency': 1,
#    'improve': 3,
#    'mcas': 2,
#    'shorten': 1,
#    'activity': 1,
#    'specific': 1,
#    'useful': 1,
#    'program': 1,
#    'second': 1,
#    'costeffective': 1,
#    'major': 4,
#    'states': 3,
#    'industry': 1,
#    'chairman': 1,
#    'our': 11,
#    'future': 3,
#    'reduce': 1,
#    'planning': 1,
#    'innovative': 1,
#    'model': 1,
#    'new': 2,
#    'overall': 1,
#    'broadcast': 1,
#    'resultsoriented': 1,
#    'tough': 1,
#    'approved': 1,
#    'language': 1,
#    'document': 2,
#    'tech': 1,
#    'total': 2,
#    'preparing': 1,
#    'to': 1,
#    'all': 1,
#    'edwards': 1,
#    'general': 1,
#    'relations': 2,
#    'special': 1,
#    'their': 2,
#    'legislative': 6,
#    'between': 1,
#    'target': 1,
#    'increased': 1,
#    'coordinating': 1,
#    'constituent': 1,
#    'identify': 1,
#    'improving': 1,
#    'is': 1,
#    'developing': 1,
#    'proving': 1,
#    'forecasted': 1,
#    'with': 1,
#    'advisory': 1,
#    'necessary': 1,
#    'credible': 1,
#    'excellent': 1,
#    'greatest': 1,
#    'caer': 5,
#    'for': 1,
#    'council': 1,
#    'solid': 1,
#    'senior': 1,
#    'focused': 1,
#    'channel': 1,
#    'compensation': 1,
#    'officials': 1,
#    'open': 1,
#    'average': 1,
#    'local': 1,
#    'active': 1,
#    'processes': 1,
#    'process': 1,
#    'court': 1,
#    'rulemaking': 1,
#    'chemtrec': 1,
#    'combined': 1,
#    'improved': 1,
#    'or': 1,
#    'upcoming': 1,
#    'toxics': 2,
#    'some': 1,
#    'effective': 1,
#    'provide': 1,
#    'normal': 1,
#    'important': 1,
#    'thereof': 1,
#    'group': 1,
#    'january': 1,
#    'facilitate': 1,
#    'remarkable': 1,
#    'caerrelated': 1,
#    'publicmedia': 1,
#    'nationwide': 1,
#    'appropriate': 1},
#   'right': {'network': 2,
#    'nearly': 1,
#    'the': 8,
#    'workshop': 2,
#    'messages': 1,
#    'communications': 1,
#    'department': 6,
#    'committee': 30,
#    'staff': 3,
#    'wilson': 1,
#    'assessment': 1,
#    'and': 9,
#    'expanding': 1,
#    'programs': 8,
#    'program': 31,
#    'support': 5,
#    'with': 4,
#    'role': 4,
#    'sessions': 1,
#    'division': 2,
#    'has': 1,
#    'other': 1,
#    'compensation': 1,
#    'materials': 2,
#    'posthearing': 1,
#    'were': 1,
#    'grant': 1,
#    'cma': 1,
#    'committees': 2,
#    'commit': 3,
#    'activities': 12,
#    'area': 1,
#    'proce': 1,
#    'can': 1,
#    'lines': 1,
#    'considerably': 1,
#    'among': 1,
#    'to': 2,
#    'better': 1,
#    'departments': 1,
#    'efforts': 7,
#    'strategy': 1,
#    'pro': 2,
#    'needs': 2,
#    'challenges': 1,
#    'expenditure': 1,
#    'expenditures': 1,
#    'is': 2,
#    'strategies': 1,
#    'more': 1,
#    'approaches': 1,
#    'priorities': 2,
#    'budget': 2,
#    'activity': 2,
#    'problems': 2,
#    'following': 2,
#    'of': 3,
#    'sub': 1,
#    'mr': 2,
#    'packet': 1,
#    'could': 2,
#    'parti': 1,
#    'jon': 1,
#    'yellow': 1,
#    'we': 2,
#    'standards': 1,
#    'richard': 2,
#    'gave': 1,
#    'effort': 4,
#    'packages': 1,
#    'recommendation': 1,
#    'staffs': 1,
#    'professionals': 2,
#    'which': 1,
#    'as': 2,
#    'identify': 1,
#    'issues': 1,
#    'why': 1,
#    'that': 1,
#    'working': 1,
#    'ex': 1,
#    'energy': 1,
#    'specialists': 1,
#    'have': 1,
#    'skills': 2,
#    'preparation': 1,
#    'opportunity': 1,
#    'asset': 1,
#    'achievement': 1,
#    'assets': 1,
#    'objectives': 1,
#    'seminar': 1,
#    'executives': 1,
#    'revolution': 1,
#    'plan': 2,
#    'task': 1,
#    'aimed': 1,
#    'significant': 1,
#    'job': 1,
#    'spelling': 1,
#    'operation': 1,
#    'on': 2,
#    'in': 1,
#    'cleaning': 1,
#    'coimnittee': 1,
#    'institute': 1,
#    'special': 2,
#    'ano': 1,
#    'sense': 1,
#    'hurdles': 1,
#    'barriers': 1,
#    'success': 1,
#    'policy': 1,
#    'capabilities': 1,
#    'extending': 1,
#    'counsel': 1,
#    'topics': 1,
#    'comtlttee': 1,
#    'progrms': 1,
#    'people': 1,
#    'standard': 4,
#    'proposal': 1,
#    'it': 1,
#    'education': 1,
#    'requirements': 1,
#    'page': 1}},
#  'network': {'left': {'communications': 2,
#    'computer': 1,
#    'tv': 1,
#    'grassroots': 2,
#    'on': 1,
#    'consnunlcatlons': 1,
#    'broadcasting': 1,
#    'television': 1,
#    'caer': 1,
#    'broadcast': 1,
#    'station': 2,
#    'news': 1,
#    'board': 1,
#    'aid': 1,
#    'our': 2,
#    'information': 2,
#    'the': 5,
#    'state': 1,
#    'existing': 1,
#    'alternative': 1,
#    'radio': 1,
#    'abc': 1,
#    'copy': 1,
#    'program': 1,
#    'that': 1,
#    'cics': 1,
#    'national': 1,
#    'have': 1,
#    'to': 1,
#    'cmacic': 1},
#   'right': {'member': 1,
#    'will': 1,
#    'providing': 1,
#    'cma': 1,
#    'television': 1,
#    'for': 3,
#    'the': 1,
#    'alexandria': 1,
#    'therefore': 1,
#    'continuas': 1,
#    'spontaneous': 1,
#    'reaching': 1,
#    'and': 1,
#    'has': 1,
#    'of': 4,
#    'csin': 1,
#    'task': 3,
#    'interview': 1,
#    'formed': 1,
#    'is': 1,
#    'programs': 1,
#    'on': 1,
#    'coverage': 1,
#    'approximately': 1,
#    'needed': 1,
#    'by': 1,
#    'when': 1,
#    'delivered': 1,
#    'to': 1,
#    'that': 1,
#    'or': 1,
#    'approach': 1}},
#  'member': {'left': {'network': 1,
#    'cma': 70,
#    'of': 40,
#    'the': 13,
#    'its': 11,
#    'approximately': 1,
#    'minority': 5,
#    'each': 9,
#    'assist': 7,
#    'many': 3,
#    'corporation': 2,
#    'all': 11,
#    'november': 1,
#    'urge': 1,
#    'also': 1,
#    'single': 2,
#    'to': 16,
#    'teams': 1,
#    'from': 9,
#    'are': 2,
#    'and': 18,
#    'motels': 1,
#    'by': 14,
#    'is': 2,
#    'several': 6,
#    'basis': 1,
#    'consolidating': 1,
#    'whether': 1,
#    'with': 9,
#    'other': 1,
#    'among': 2,
#    'ott': 1,
#    'on': 3,
#    'legislation': 1,
#    'protect': 1,
#    'mca': 20,
#    'developing': 1,
#    'crac': 1,
#    'september': 1,
#    'in': 5,
#    'whose': 1,
#    'individual': 4,
#    'for': 8,
#    'active': 2,
#    'new': 1,
#    'more': 1,
#    'suggested': 1,
#    'that': 2,
#    'documenting': 1,
#    'document': 1,
#    'clia': 1,
#    'tcc': 1,
#    'founding': 1,
#    'strong': 1,
#    'programs': 1,
#    'our': 5,
#    'if': 1,
#    'spac': 1,
#    'their': 1,
#    'ten': 1,
#    'exhibit': 2,
#    'january': 1,
#    'cmas': 3,
#    'continued': 1,
#    'annual': 1,
#    'urging': 1,
#    'nical': 1,
#    'almost': 1,
#    'demand': 1,
#    'congressional': 1,
#    'campaign': 1,
#    'as': 4,
#    'winson': 1,
#    'most': 1,
#    'caused': 1,
#    'cause': 1,
#    'staff': 2,
#    'commission': 1,
#    'years': 1,
#    'where': 1,
#    'at': 1,
#    'direct': 1,
#    'some': 3,
#    'companies': 1,
#    'save': 1,
#    'twentyfour': 1,
#    'advise': 1,
#    'fall': 1,
#    'key': 2,
#    'schools': 1,
#    'noncompany': 1,
#    'those': 1,
#    'become': 1,
#    'any': 3,
#    'such': 3,
#    'appropriate': 1,
#    'severing': 1,
#    'seventerm': 1,
#    'cracs': 1,
#    'maintaining': 1,
#    'participation': 1,
#    'rnc': 1,
#    'changes': 1,
#    'certain': 1,
#    'foreclosed': 1,
#    'nting': 1,
#    'canvassed': 1,
#    'kodak': 1,
#    'able': 1,
#    'house': 1,
#    'include': 1,
#    'through': 2,
#    'over': 1,
#    'iso': 1,
#    'releases': 1,
#    'facilitate': 1,
#    'upon': 1,
#    'interested': 1,
#    'associate': 1,
#    'cabinet': 1,
#    'offering': 1,
#    'offers': 1,
#    'addition': 1,
#    'however': 1,
#    'five': 1,
#    'budget': 1,
#    'general': 1,
#    'canadian': 1,
#    'us': 1,
#    'assise': 1,
#    'proposals': 1,
#    'others': 1,
#    'principally': 1,
#    'year': 1,
#    'incorporate': 1,
#    'identify': 1,
#    'encourage': 1,
#    'only': 1,
#    'panel': 1,
#    'significant': 1,
#    'issues': 1,
#    'leadership': 1,
#    'capitol': 1,
#    'opposition': 1,
#    'lacks': 1,
#    'cics': 1,
#    'success': 1,
#    'required': 1,
#    'one': 1,
#    'additional': 1,
#    'ec': 1},
#   'right': {'companies': 237,
#    'company': 102,
#    'norman': 1,
#    'companys': 2,
#    'relations': 2,
#    'of': 22,
#    'speaking': 1,
#    'teams': 1,
#    'has': 2,
#    'cma': 1,
#    'coavanies': 1,
#    'input': 1,
#    'awareness': 1,
#    'compa': 1,
#    'firms': 2,
#    'compan': 1,
#    'developed': 1,
#    'services': 8,
#    'countries': 3,
#    'governments': 1,
#    'participation': 3,
#    'ship': 2,
#    'and': 3,
#    'does': 1,
#    'states': 3,
#    'though': 1,
#    'can': 1,
#    'if': 1,
#    'from': 3,
#    'to': 2,
#    'who': 1,
#    'each': 1,
#    'james': 1,
#    'companiesthrough': 1,
#    'people': 1,
#    'com': 2,
#    'may': 1,
#    'article': 1,
#    'failing': 1,
#    'shall': 1,
#    'involvement': 1,
#    'represented': 1,
#    'could': 1,
#    'compani': 1,
#    'on': 2,
#    'carl': 1,
#    'jacob': 1,
#    'letter': 1,
#    'said': 1,
#    'insurance': 1,
#    'dues': 1,
#    'plant': 1,
#    'peter': 1,
#    'survey': 1,
#    'support': 1,
#    'noting': 1}},
#  'companies': {'left': {'member': 237,
#    'individual': 15,
#    'certain': 1,
#    'that': 5,
#    'included': 1,
#    'chemical': 21,
#    'private': 2,
#    'inspection': 4,
#    'pharmaceutical': 1,
#    'us': 8,
#    'is': 1,
#    'these': 4,
#    'manufacturing': 1,
#    'workers': 1,
#    'and': 2,
#    'require': 2,
#    'relieve': 1,
#    'wastes': 1,
#    'believe': 1,
#    'encourage': 2,
#    'for': 6,
#    'activities': 1,
#    'cma': 8,
#    'insured': 1,
#    'the': 13,
#    'various': 2,
#    'instances': 1,
#    'over': 2,
#    'fiftythree': 1,
#    'international': 1,
#    'smaller': 3,
#    'domestic': 1,
#    'trading': 1,
#    'participating': 22,
#    'their': 3,
#    'date': 1,
#    'those': 4,
#    'subscribing': 2,
#    'other': 2,
#    'our': 6,
#    'jersey': 2,
#    'few': 3,
#    'how': 1,
#    'canadian': 1,
#    'sales': 1,
#    'some': 3,
#    'nonparticipating': 1,
#    'more': 3,
#    'of': 13,
#    'your': 6,
#    'have': 1,
#    'from': 4,
#    'lining': 1,
#    'mca': 1,
#    'leasing': 1,
#    'utility': 2,
#    'expanded': 1,
#    'by': 4,
#    'small': 1,
#    'appropriate': 1,
#    'to': 5,
#    'major': 3,
#    'several': 3,
#    'encouraging': 1,
#    'large': 4,
#    'oil': 5,
#    'ber': 1,
#    'six': 2,
#    'nineteen': 1,
#    'take': 1,
#    'basis': 1,
#    'affords': 1,
#    'affect': 1,
#    'grade': 2,
#    'only': 2,
#    'help': 2,
#    'responding': 1,
#    'supporting': 1,
#    'most': 2,
#    'energy': 2,
#    'insurance': 1,
#    'providing': 1,
#    'concerned': 1,
#    'or': 1,
#    'effective': 1,
#    'all': 2,
#    'which': 1,
#    'fortune': 1,
#    'many': 5,
#    'pipeline': 2,
#    'foresighted': 1,
#    'guiding': 1,
#    'interested': 3,
#    'following': 1,
#    'distribution': 2,
#    'gives': 1,
#    'prohibit': 1,
#    'energyconsuming': 3,
#    'are': 1,
#    'pating': 1,
#    'hundred': 1,
#    'years': 1,
#    'cs': 1,
#    'crag': 1,
#    'lists': 1,
#    'sponsoring': 1,
#    'system': 1,
#    'nonmember': 1,
#    'additional': 1,
#    'different': 1,
#    'neaber': 1,
#    'american': 1,
#    'membar': 1,
#    'organizations': 1,
#    'find': 1,
#    'seventeen': 1,
#    'meeting': 1,
#    'affected': 1,
#    'europeanbased': 1,
#    'appendix': 1,
#    'audits': 1,
#    'has': 1,
#    'among': 1,
#    'home': 1,
#    'where': 1,
#    'purposes': 1,
#    'with': 1,
#    'highestranking': 1,
#    'such': 1,
#    'regulations': 1,
#    'mber': 1,
#    'now': 1,
#    'mambar': 1,
#    'own': 1,
#    'industry': 2,
#    'instate': 1,
#    'includes': 1},
#   'right': {'are': 30,
#    'under': 1,
#    'report': 1,
#    'for': 4,
#    'the': 25,
#    'if': 3,
#    'in': 32,
#    'met': 1,
#    'focus': 1,
#    'requests': 1,
#    'can': 7,
#    'sincerely': 1,
#    'covered': 1,
#    'currently': 2,
#    'on': 7,
#    'that': 8,
#    'have': 32,
#    'request': 1,
#    'including': 1,
#    'it': 7,
#    'at': 6,
#    'to': 41,
#    'support': 1,
#    'donate': 1,
#    'who': 11,
#    'paid': 1,
#    'hold': 1,
#    'and': 45,
#    'being': 1,
#    'since': 1,
#    'participated': 2,
#    'of': 3,
#    'sued': 1,
#    'worked': 1,
#    'should': 9,
#    'establish': 1,
#    'issu': 1,
#    'has': 4,
#    'participating': 7,
#    'both': 1,
#    'through': 2,
#    'mem': 1,
#    'survey': 1,
#    'responded': 2,
#    'going': 1,
#    'assisted': 1,
#    'were': 7,
#    'carry': 1,
#    'while': 2,
#    'we': 4,
#    'faced': 1,
#    'working': 2,
#    'completely': 1,
#    'other': 1,
#    'alerted': 1,
#    'had': 1,
#    'operating': 3,
#    'out': 2,
#    'send': 1,
#    'sufficient': 1,
#    'process': 1,
#    'manufacture': 1,
#    'see': 1,
#    'will': 17,
#    'represent': 2,
#    'produce': 1,
#    'wishing': 1,
#    'from': 3,
#    'number': 1,
#    'with': 7,
#    'not': 3,
#    'represented': 2,
#    'over': 1,
#    'indicating': 1,
#    'provide': 1,
#    'requested': 1,
#    'be': 1,
#    'expand': 1,
#    'or': 2,
#    'communicate': 1,
#    'performance': 1,
#    'he': 2,
#    'cannot': 1,
#    'would': 6,
#    'present': 1,
#    'acting': 2,
#    'which': 5,
#    'described': 1,
#    'hospitals': 1,
#    'health': 1,
#    'liability': 2,
#    'response': 2,
#    'as': 3,
#    'funds': 1,
#    'staff': 3,
#    'make': 1,
#    'cma': 5,
#    'was': 2,
#    'suggest': 1,
#    'interested': 3,
#    'designation': 3,
#    'success': 1,
#    'by': 2,
#    'but': 2,
#    'following': 1,
#    'attorneys': 1,
#    'obvious': 1,
#    'within': 1,
#    'is': 5,
#    'reported': 1,
#    'using': 1,
#    'disposing': 1,
#    'several': 1,
#    'consisting': 1,
#    'representatives': 1,
#    'submitting': 1,
#    'responding': 2,
#    'showing': 1,
#    'this': 3,
#    'sponsor': 1,
#    'our': 3,
#    'continue': 1,
#    'each': 1,
#    'employing': 1,
#    'million': 1,
#    'member': 1,
#    'millions': 1,
#    'presented': 1,
#    'ordered': 1,
#    'informed': 1,
#    'agreed': 1,
#    'utility': 1,
#    'more': 1,
#    'dr': 1,
#    'attended': 2,
#    'meanwhile': 1,
#    'mr': 1,
#    'pvith': 1,
#    'distribution': 1,
#    'opened': 1,
#    'must': 1,
#    'prepare': 1,
#    'identify': 1,
#    'generally': 1,
#    'west': 1,
#    'suggested': 1,
#    'keeping': 1,
#    'status': 1,
#    'here': 2,
#    'respond': 1,
#    'an': 1,
#    'identified': 1,
#    'listed': 1,
#    'whose': 1,
#    'so': 1,
#    'individually': 1,
#    'abandoned': 1,
#    'affected': 1,
#    'before': 1,
#    'combined': 1,
#    'supporting': 1,
#    'into': 2,
#    'tices': 1,
#    'decision': 1,
#    'january': 1,
#    'eligible': 1,
#    'recommendations': 1,
#    'options': 1,
#    'resulted': 1,
#    'completed': 1,
#    'sponsored': 1,
#    'made': 1,
#    'grassroots': 1,
#    'taped': 1,
#    'duplicating': 1,
#    'effect': 2,
#    'their': 1,
#    'ln': 1,
#    'intend': 1,
#    'apprised': 1,
#    'litigious': 1,
#    'industry': 1,
#    'signed': 1,
#    'desiring': 1,
#    'however': 1,
#    'fit': 1,
#    'complying': 1,
#    'conducted': 1,
#    'studies': 1,
#    'all': 1,
#    'reporting': 3,
#    'may': 1,
#    'designed': 1,
#    'raaourcas': 1,
#    'understand': 1,
#    'took': 1,
#    'lack': 1,
#    'urging': 1,
#    'exxon': 1,
#    'ldcs': 1}},
#  'are': {'left': {'companies': 30,
#    'which': 47,
#    'states': 6,
#    'concerns': 6,
#    'what': 2,
#    'analyses': 1,
#    'court': 1,
#    'that': 54,
#    'parties': 2,
#    'comments': 13,
#    'party': 1,
#    'conferees': 3,
#    'contacts': 4,
#    'dioxins': 1,
#    'they': 40,
#    'supplemented': 1,
#    'issues': 10,
#    'subcommittee': 1,
#    'copies': 3,
#    'manual': 1,
#    'clrs': 1,
#    'coalitions': 1,
#    'assignments': 1,
#    'transportation': 4,
#    'there': 76,
#    'area': 1,
#    'programs': 14,
#    'records': 2,
#    'summaries': 2,
#    'year': 4,
#    'he': 3,
#    'we': 94,
#    'members': 11,
#    'points': 5,
#    'activities': 17,
#    'settlements': 1,
#    'questionnaires': 1,
#    'act': 2,
#    'groups': 10,
#    'proposal': 3,
#    'trichlorobenzene': 1,
#    'chat': 1,
#    'program': 4,
#    'committee': 7,
#    'regulatory': 1,
#    'who': 19,
#    'sdwa': 1,
#    'plans': 5,
#    'items': 1,
#    'offices': 2,
#    'rules': 1,
#    'and': 35,
#    'limits': 2,
#    'chemicals': 12,
#    'rmcls': 1,
#    'officials': 4,
#    'representatives': 3,
#    'others': 3,
#    'votes': 1,
#    'requirements': 3,
#    'provisions': 9,
#    'response': 1,
#    'rooney': 1,
#    'regulation': 2,
#    'successes': 1,
#    'imports': 3,
#    'effect': 1,
#    'houses': 1,
#    'americans': 1,
#    'amendments': 7,
#    'approach': 1,
#    'staff': 7,
#    'petitioners': 1,
#    'you': 10,
#    'procrams': 1,
#    'tsca': 1,
#    'pmns': 1,
#    'outlined': 1,
#    'gotten': 1,
#    'agreements': 2,
#    'law': 2,
#    'risk': 1,
#    'procedures': 5,
#    'patents': 1,
#    'trademarks': 1,
#    'inventions': 2,
#    'review': 1,
#    'groins': 1,
#    'however': 3,
#    'reality': 1,
#    'exports': 1,
#    'congress': 5,
#    'products': 3,
#    'objectives': 4,
#    'context': 1,
#    'industry': 4,
#    'collections': 2,
#    'meetings': 3,
#    'positions': 4,
#    'areas': 3,
#    'costs': 6,
#    'policy': 1,
#    'chairmen': 1,
#    'process': 2,
#    'develop': 1,
#    'emissions': 1,
#    'controls': 3,
#    'standard': 1,
#    'interests': 4,
#    'authorities': 1,
#    'discussions': 5,
#    'received': 1,
#    'emergencies': 1,
#    'crc': 1,
#    'totals': 1,
#    'calls': 2,
#    'shares': 1,
#    'disbursements': 2,
#    'releases': 2,
#    'plan': 1,
#    'units': 1,
#    'future': 1,
#    'commerce': 3,
#    'people': 2,
#    'workers': 1,
#    'risks': 3,
#    'finding': 1,
#    'results': 8,
#    'egee': 1,
#    'eh': 1,
#    'gas': 2,
#    'letters': 1,
#    'fema': 1,
#    'spokespersons': 1,
#    'countries': 4,
#    'terms': 1,
#    'agreement': 3,
#    'governments': 3,
#    'tpsc': 1,
#    'investigations': 1,
#    'paper': 2,
#    'canada': 3,
#    'availability': 1,
#    'feedstocks': 1,
#    'than': 1,
#    'efforts': 12,
#    'neda': 1,
#    'institute': 1,
#    'date': 1,
#    'discharges': 1,
#    'standards': 4,
#    'development': 1,
#    'operations': 2,
#    'or': 9,
#    'dischargus': 1,
#    'practices': 1,
#    'cox': 1,
#    'now': 2,
#    'also': 4,
#    'regulations': 6,
#    'versions': 1,
#    'cma': 2,
#    'negotiations': 2,
#    'observers': 2,
#    'senators': 1,
#    'these': 14,
#    'organizations': 1,
#    'materials': 5,
#    'dures': 1,
#    'principles': 1,
#    'board': 3,
#    'sure': 1,
#    'numbers': 2,
#    'pockets': 1,
#    'up': 1,
#    'talks': 2,
#    'instead': 1,
#    'producers': 5,
#    'bach': 1,
#    'for': 1,
#    'steps': 1,
#    'timing': 1,
#    'mittee': 2,
#    'statements': 1,
#    'arrangements': 1,
#    'decade': 1,
#    'conference': 1,
#    'committees': 4,
#    'initiatives': 1,
#    'consunltles': 1,
#    'currently': 1,
#    'none': 2,
#    'needs': 2,
#    'leaders': 2,
#    'council': 1,
#    'psas': 1,
#    'films': 1,
#    'awrt': 1,
#    'both': 1,
#    'factors': 1,
#    'partners': 1,
#    'victories': 1,
#    'funds': 5,
#    'experts': 1,
#    'section': 3,
#    'disincentives': 1,
#    'guidance': 1,
#    'systems': 4,
#    'differences': 1,
#    'liability': 1,
#    'examples': 2,
#    'relationships': 1,
#    'moderates': 1,
#    'csi': 1,
#    'schedules': 1,
#    'provision': 1,
#    'impact': 1,
#    'features': 1,
#    'establishment': 1,
#    'past': 1,
#    'number': 2,
#    'as': 2,
#    'increase': 1,
#    'activity': 1,
#    'employees': 3,
#    'many': 4,
#    'unions': 3,
#    'bills': 4,
#    'benefits': 6,
#    'vii': 1,
#    'engineers': 1,
#    'dings': 1,
#    'diplomats': 1,
#    'avenue': 1,
#    'vetoes': 1,
#    'legislation': 2,
#    'ten': 1,
#    'dues': 3,
#    'mind': 2,
#    'presently': 3,
#    'usefulness': 1,
#    'agencies': 4,
#    'proposals': 6,
#    'of': 1,
#    'intermediates': 1,
#    'hearings': 11,
#    'associations': 2,
#    'concepts': 1,
#    'data': 5,
#    'averages': 1,
#    'scenarios': 1,
#    'iv': 1,
#    'iii': 1,
#    'sices': 1,
#    'advantages': 1,
#    'carriers': 2,
#    'victims': 1,
#    'paid': 1,
#    'views': 1,
#    'claims': 1,
#    'administrators': 1,
#    'liabilities': 1,
#    'disease': 1,
#    'further': 1,
#    'aihc': 1,
#    'documents': 1,
#    'reports': 2,
#    'present': 1,
#    'industries': 1,
#    'actions': 2,
#    'recommendations': 5,
#    'control': 1,
#    'exemptions': 1,
#    'organization': 1,
#    'devices': 2,
#    'origins': 1,
#    'inquiries': 1,
#    'obligations': 2,
#    'options': 1,
#    'sw': 1,
#    'dischargers': 1,
#    'determined': 1,
#    'briefings': 1,
#    'credit': 1,
#    'contracts': 2,
#    'distributors': 1,
#    'bill': 3,
#    'wastes': 1,
#    'pollutants': 1,
#    'massachusetts': 1,
#    'processes': 1,
#    'receivers': 1,
#    'years': 3,
#    'europeans': 1,
#    'europe': 1,
#    'available': 1,
#    'mexico': 1,
#    'studies': 6,
#    'ings': 1,
#    'some': 3,
#    'commission': 1,
#    'problems': 4,
#    'contamination': 1,
#    'groundwater': 1,
#    'making': 1,
#    'thousand': 1,
#    'comnon': 1,
#    'nfpa': 1,
#    'advocacy': 1,
#    'capitals': 1,
#    'ing': 1,
#    'august': 1,
#    'sessions': 2,
#    'ordinances': 1,
#    'jan': 1,
#    'disposal': 1,
#    'actuality': 1,
#    'newsfeatures': 1,
#    'awards': 1,
#    'uncils': 1,
#    'spots': 1,
#    'papers': 1,
#    'in': 2,
#    'exceptions': 2,
#    'things': 1,
#    'whom': 1,
#    'more': 2,
#    'japanese': 1,
#    'possibilities': 1,
#    'them': 2,
#    'details': 2,
#    'jobs': 1,
#    'dollars': 1,
#    'oshas': 1,
#    'attached': 1,
#    'manpower': 1,
#    'lobbyists': 1,
#    'aqr': 1,
#    'jects': 1,
#    'levels': 2,
#    'laws': 3,
#    'republicans': 2,
#    'streams': 1,
#    'agency': 1,
#    'remarks': 1,
#    've': 1,
#    'listed': 2,
#    'justifications': 1,
#    'administration': 1,
#    'presentation': 1,
#    'resources': 2,
#    'sights': 1,
#    'audiences': 1,
#    'researchers': 1,
#    'based': 1,
#    'consumers': 1,
#    'pipelines': 1,
#    'guidelines': 2,
#    'importance': 1,
#    'sheets': 1,
#    'drafts': 2,
#    'guides': 1,
#    'four': 2,
#    'dates': 1,
#    'technology': 1,
#    'far': 1,
#    'changes': 3,
#    'young': 1,
#    'solution': 1,
#    'study': 1,
#    'organics': 1,
#    'voluntary': 1,
#    'fact': 1,
#    'epa': 1,
#    'following': 2,
#    'dollar': 1,
#    'germany': 1,
#    'two': 2,
#    'democrats': 1,
#    'chair': 1,
#    'dny': 1,
#    'chairmanship': 1,
#    'here': 1,
#    'engineering': 1,
#    'then': 1,
#    'scientists': 2,
#    'ideas': 1,
#    'courses': 1,
#    'publics': 1,
#    'reviews': 1,
#    'policies': 2,
#    'counsel': 1,
#    'spac': 1,
#    'secretaries': 1,
#    'etc': 1,
#    'companlas': 1,
#    'reserves': 1,
#    'callers': 1,
#    'prograas': 1,
#    'assets': 1,
#    'question': 2,
#    'communicating': 1,
#    'already': 1,
#    'but': 3,
#    'package': 1,
#    'revisions': 1,
#    'treaties': 1,
#    'indications': 3,
#    'bombshells': 1,
#    'recovery': 1,
#    'fees': 2,
#    'fee': 1,
#    'wells': 1,
#    'dep': 1,
#    'july': 1,
#    'group': 4,
#    'issue': 1,
#    'contaminants': 1,
#    'effects': 1,
#    'state': 1,
#    'testing': 1,
#    'concern': 2,
#    'merger': 1,
#    'considered': 1,
#    'criteria': 2,
#    'increases': 1,
#    'produce': 1,
#    'restrictions': 2,
#    'dtx': 1,
#    'ther': 1,
#    'conaunicatlons': 1,
#    'developments': 1,
#    'licenses': 1,
#    'rights': 1,
#    'deadlines': 1,
#    'communities': 1,
#    'funding': 1,
#    'several': 1,
#    'profits': 2,
#    'regard': 1,
#    'alsp': 1,
#    'without': 1,
#    'signatories': 1,
#    'aaterials': 1,
#    'requireaents': 1,
#    'ncric': 1,
#    'rule': 1,
#    'officers': 1,
#    'legislatures': 1,
#    'goals': 2,
#    'substances': 1,
#    'project': 1,
#    'congressmen': 1,
#    'matter': 1,
#    'conmittee': 1,
#    'techniques': 2,
#    'mechanics': 1,
#    'toxicity': 1,
#    'processors': 1,
#    'lines': 1,
#    'account': 1,
#    'assessment': 1,
#    'figures': 1,
#    'association': 2,
#    'booklets': 1,
#    'prafjram': 1,
#    'pressures': 1,
#    'represented': 1,
#    'corporations': 1,
#    'forums': 1,
#    'today': 1,
#    'trends': 1,
#    'plants': 1,
#    'understandably': 1,
#    'managers': 1,
#    'facilities': 1,
#    'action': 1,
#    'effort': 1,
#    'gathered': 1,
#    'list': 1,
#    'tions': 1,
#    'compounds': 1,
#    'reauthorization': 1,
#    'warnings': 1,
#    'only': 1,
#    'election': 1,
#    'adjournment': 1,
#    'preparations': 2,
#    'rates': 1,
#    'boycotts': 1,
#    'level': 1,
#    'esters': 1,
#    'alcohols': 1,
#    'nonmanufacturers': 1,
#    'case': 1,
#    'bodies': 1,
#    'reform': 1,
#    'osha': 1,
#    'interest': 1,
#    'cresols': 1,
#    'workshops': 1,
#    'orders': 1,
#    'advisors': 1,
#    'seminars': 1,
#    'emc': 1,
#    'vs': 1,
#    'legislators': 1,
#    'townships': 1,
#    'success': 1,
#    'battles': 1,
#    'surveys': 2,
#    'services': 2,
#    'included': 1,
#    'priorities': 1,
#    'subject': 1,
#    'prospects': 1},
#   'right': {'strongly': 3,
#    'currently': 8,
#    'involved': 2,
#    'epa': 2,
#    'relevant': 1,
#    'valuable': 1,
#    'whether': 2,
#    'amenable': 1,
#    'willing': 4,
#    'reclaimed': 1,
#    'designed': 12,
#    'arguing': 1,
#    'the': 28,
#    'expected': 31,
#    'set': 6,
#    'even': 3,
#    'equally': 1,
#    'repeated': 1,
#    'selected': 1,
#    'available': 9,
#    'being': 58,
#    'establishing': 1,
#    'meeting': 2,
#    'made': 6,
#    'satisfied': 2,
#    'number': 2,
#    'no': 11,
#    'exposed': 4,
#    'now': 29,
#    'attached': 3,
#    'urged': 3,
#    'to': 21,
#    'open': 2,
#    'redoubling': 1,
#    'in': 31,
#    'constantly': 1,
#    'active': 6,
#    'included': 3,
#    'fourteen': 1,
#    'demonstrated': 1,
#    'having': 1,
#    'addressed': 1,
#    'strong': 2,
#    'high': 1,
#    'actually': 2,
#    'some': 8,
#    'seeking': 7,
#    'substantial': 2,
#    'preparing': 6,
#    'particular': 1,
#    'essential': 2,
#    'of': 14,
#    'capital': 3,
#    'so': 3,
#    'organized': 1,
#    'working': 17,
#    'true': 1,
#    'unsurpassed': 1,
#    'primarily': 5,
#    'especially': 3,
#    'required': 6,
#    'member': 2,
#    'charged': 2,
#    'also': 24,
#    'incorporating': 1,
#    'unnecessary': 2,
#    'important': 3,
#    'benzene': 1,
#    'technically': 1,
#    'often': 1,
#    'circumstances': 1,
#    'participating': 4,
#    'planned': 5,
#    'significant': 5,
#    'based': 6,
#    'basically': 1,
#    'following': 2,
#    'negated': 1,
#    'unable': 1,
#    'certain': 2,
#    'underway': 7,
#    'hardpressed': 1,
#    'more': 9,
#    'calling': 2,
#    'overly': 1,
#    'recommended': 3,
#    'interested': 2,
#    'unsure': 1,
#    'probably': 1,
#    'addressing': 2,
#    'considerably': 1,
#    'implemented': 2,
#    'few': 2,
#    'regulations': 1,
#    'unenforceable': 1,
#    'completing': 1,
#    'actively': 3,
#    'acceptable': 3,
#    'or': 2,
#    'prepared': 4,
#    'granted': 1,
#    'registered': 1,
#    'issued': 2,
#    'assigned': 1,
#    'used': 4,
#    'two': 4,
#    'grouped': 1,
#    'on': 5,
#    'clear': 2,
#    'decreasing': 1,
#    'seeing': 2,
#    'not': 49,
#    'awaiting': 2,
#    'communicated': 1,
#    'similar': 1,
#    'considered': 9,
#    'judged': 1,
#    'likely': 11,
#    'at': 8,
#    'somewhat': 1,
#    'generally': 8,
#    'responsible': 4,
#    'establish': 1,
#    'listed': 3,
#    'vitally': 1,
#    'conducted': 6,
#    'reported': 1,
#    'obtained': 1,
#    'adequately': 5,
#    'surely': 1,
#    'already': 8,
#    'still': 11,
#    'ulti': 1,
#    'pressuring': 1,
#    'exemplary': 1,
#    'all': 8,
#    'chronic': 1,
#    'subject': 3,
#    'preempted': 2,
#    'compatible': 1,
#    'continuing': 8,
#    'showing': 1,
#    'off': 1,
#    'members': 3,
#    'participants': 1,
#    'subscribers': 1,
#    'located': 2,
#    'referred': 1,
#    'cma': 3,
#    'stressed': 1,
#    'prorated': 1,
#    'risk': 1,
#    'shown': 2,
#    'detailed': 5,
#    'anticipated': 2,
#    'both': 2,
#    'employed': 2,
#    'evaluated': 2,
#    'farreaching': 1,
#    'adversely': 1,
#    'suggesting': 1,
#    'implementing': 2,
#    'extremely': 1,
#    'anxious': 2,
#    'discussing': 1,
#    'casting': 1,
#    'just': 3,
#    'undertaken': 2,
#    'faulty': 1,
#    'achievable': 3,
#    'considering': 6,
#    'intended': 1,
#    'each': 1,
#    'critical': 1,
#    'canadian': 1,
#    'contained': 3,
#    'how': 1,
#    'adequate': 3,
#    'developing': 3,
#    'summarized': 2,
#    'an': 2,
#    'applied': 1,
#    'sought': 1,
#    'faced': 1,
#    'studying': 1,
#    'too': 2,
#    'concluding': 1,
#    'urging': 2,
#    'signs': 3,
#    'scheduled': 9,
#    'as': 8,
#    'directed': 3,
#    'one': 1,
#    'wellconceived': 1,
#    'empty': 1,
#    'exporting': 1,
#    'we': 3,
#    'impacted': 2,
#    'causing': 2,
#    'experiencing': 2,
#    'asked': 1,
#    'general': 1,
#    'that': 3,
#    'mca': 3,
#    'called': 1,
#    'effectively': 1,
#    'indicated': 1,
#    'handled': 4,
#    'reviewing': 1,
#    'familiar': 1,
#    'over': 2,
#    'hazardous': 3,
#    'far': 3,
#    'lower': 2,
#    'driven': 1,
#    'consistent': 2,
#    'reasonable': 5,
#    'evident': 2,
#    'convinced': 1,
#    'due': 8,
#    'targeted': 2,
#    'enthusiastic': 1,
#    'locked': 1,
#    'difficult': 1,
#    'hopeful': 1,
#    'increasing': 2,
#    'interviewed': 1,
#    'seen': 1,
#    'those': 4,
#    'classified': 1,
#    'substantive': 1,
#    'alkanolamines': 1,
#    'california': 2,
#    'concerned': 10,
#    'making': 2,
#    'good': 2,
#    'breakeven': 1,
#    'under': 9,
#    'endorsed': 1,
#    'chemical': 1,
#    'among': 2,
#    'unique': 1,
#    'tcc': 1,
#    'authorrized': 1,
#    'hereby': 2,
#    'foregone': 1,
#    'occupational': 1,
#    'becoming': 5,
#    'building': 3,
#    'impatient': 2,
#    'utilizing': 1,
#    'going': 3,
#    'pending': 2,
#    'sure': 1,
#    'giving': 1,
#    'therefore': 2,
#    'new': 1,
#    'seven': 1,
#    'written': 1,
#    'democrats': 1,
#    'vacancies': 1,
#    'intertwined': 1,
#    'human': 2,
#    'you': 2,
#    'telling': 2,
#    'largely': 3,
#    'sometimes': 1,
#    'starting': 2,
#    'practically': 1,
#    'rapidly': 2,
#    'covered': 2,
#    'completed': 1,
#    'serious': 2,
#    'they': 1,
#    'defeated': 2,
#    'economically': 1,
#    'minimal': 1,
#    'adjusted': 1,
#    'revising': 1,
#    'reluctant': 3,
#    'unlikely': 1,
#    'most': 3,
#    'provide': 1,
#    'identified': 2,
#    'eliminating': 1,
#    'fairly': 1,
#    'reliable': 1,
#    'sound': 1,
#    'coo': 1,
#    'shared': 1,
#    'with': 1,
#    'focused': 1,
#    'objectives': 1,
#    'unreasonable': 1,
#    'specifically': 2,
#    'somehow': 1,
#    'incorporated': 1,
#    'when': 1,
#    'undecided': 1,
#    'described': 1,
#    'deeply': 1,
#    'pledged': 1,
#    'forum': 1,
#    'needed': 7,
#    'quite': 3,
#    'commencing': 1,
#    'published': 1,
#    'assisting': 1,
#    'taking': 2,
#    'incompatible': 1,
#    'inappropriate': 1,
#    'medically': 1,
#    'appropriate': 2,
#    'properly': 3,
#    'extended': 2,
#    'take': 1,
#    'trained': 1,
#    'tentatively': 1,
#    'scientifically': 2,
#    'specific': 1,
#    'finding': 1,
#    'impressive': 1,
#    'other': 1,
#    'estimated': 1,
#    'renegotiated': 1,
#    'limited': 2,
#    'eliminated': 1,
#    'trying': 2,
#    'uncertain': 1,
#    'watching': 2,
#    'several': 4,
#    'ranked': 1,
#    'obvious': 3,
#    'air': 1,
#    'supportive': 1,
#    'recommending': 1,
#    'illus': 1,
#    'voluntary': 1,
#    'perhaps': 1,
#    'many': 3,
#    'consensus': 1,
#    'carefully': 1,
#    'admitted': 1,
#    'developed': 1,
#    'aimed': 2,
#    'obviously': 1,
#    'less': 1,
#    'only': 1,
#    'their': 1,
#    'great': 1,
#    'encourag': 1,
#    'small': 2,
#    'instrumental': 1,
#    'done': 1,
#    'given': 1,
#    'tied': 1,
#    'expect': 1,
#    'taken': 2,
#    'aware': 1,
#    'indeed': 1,
#    'from': 1,
#    'providing': 1,
#    'func': 1,
#    'determined': 1,
#    'benzenoid': 1,
#    'hard': 1,
#    'informed': 1,
#    'using': 2,
#    'presently': 4,
#    'rushing': 1,
#    'monitoring': 1,
#    'dormant': 1,
#    'difficulties': 1,
#    'directly': 2,
#    'deemed': 3,
#    'secondary': 1,
#    'someone': 1,
#    'specified': 1,
#    'if': 1,
#    'roughly': 1,
#    'detrimental': 1,
#    'usually': 1,
#    'like': 2,
#    'operating': 1,
#    'before': 1,
#    'getting': 2,
#    'devoted': 2,
#    'looking': 1,
#    'any': 1,
#    'headed': 1,
#    'welcomed': 1,
#    'responding': 1,
#    'dedicated': 1,
#    'candid': 1,
#    'our': 1,
#    'always': 2,
#    'permitted': 3,
#    'classed': 1,
#    'stopped': 1,
#    'manifest': 1,
#    'greatly': 1,
#    'well': 3,
#    'effec': 1,
#    'hes': 1,
#    'spelled': 1,
#    'times': 1,
#    'people': 1,
#    'predicted': 1,
#    'crucial': 2,
#    'confident': 1,
#    'necessary': 1,
#    'slowly': 1,
#    'requesting': 1,
#    'useful': 1,
#    'worthwhile': 1,
#    'problems': 1,
#    'passed': 1,
#    'con': 1,
#    'arbitrarily': 1,
#    'issuerelated': 1,
#    'crosscutting': 1,
#    'claiming': 1,
#    'fire': 1,
#    'presented': 3,
#    'approaching': 1,
#    'moving': 2,
#    'met': 2,
#    'substantially': 2,
#    'companies': 1,
#    'reporting': 1,
#    'relative': 1,
#    'low': 1,
#    'transcending': 1,
#    'influencing': 1,
#    'potential': 1,
#    'cautiously': 1,
#    'toxic': 1,
#    'setting': 1,
#    'fuming': 1,
#    'intense': 1,
#    'focusing': 1,
#    'major': 3,
#    'trends': 1,
#    'close': 2,
#    'david': 1,
#    'returning': 1,
#    'confronted': 1,
#    'declining': 1,
#    'organizing': 1,
#    'career': 1,
#    'unemployed': 1,
#    'concrete': 1,
#    'transferred': 1,
#    'un': 1,
#    'represented': 1,
#    'co': 1,
#    'invoiced': 1,
#    'maintained': 1,
#    'carried': 1,
#    'committed': 1,
#    'handling': 1,
#    'kept': 1,
#    'four': 1,
#    'perceived': 1,
#    'worth': 2,
#    'comprehensive': 1,
#    'things': 1,
#    'ready': 1,
#    'indications': 1,
#    'very': 2,
#    'supported': 1,
#    'twentysix': 1,
#    'negotiated': 1,
#    'however': 1,
#    'distinct': 1,
#    'discussed': 2,
#    'dim': 1,
#    'created': 1,
#    'florida': 1,
#    'contaminated': 1,
#    'age': 2,
#    'acid': 1,
#    'minnesota': 1,
#    'closely': 1,
#    'found': 1,
#    'conducting': 1,
#    'improved': 1,
#    'npdes': 1,
#    'running': 1,
#    'result': 1,
#    'greater': 1,
#    'asuptodate': 1,
#    'ail': 1,
#    'warranted': 1,
#    'thus': 1,
#    'fast': 1,
#    'harmonization': 1,
#    'strengthening': 1,
#    'undertaking': 1,
#    'encouraged': 2,
#    'emitted': 1,
#    'appointed': 1,
#    'likewise': 1,
#    'repealed': 1,
#    'fielded': 1,
#    'appended': 1,
#    'targets': 2,
#    'consider': 1,
#    'hansen': 1,
#    'contributing': 1,
#    'submitted': 1,
#    'proposed': 1,
#    'manifested': 1,
#    'demanding': 1,
#    'counterproductive': 2,
#    'prime': 1,
#    'objectionable': 1,
#    'bolstered': 1,
#    'searching': 1,
#    'reshaping': 1,
#    'protected': 1,
#    'part': 2,
#    'clearly': 1,
#    'opposed': 1,
#    'inextricably': 1,
#    'observed': 1,
#    'inadequate': 1,
#    'excessive': 1,
#    'reciprocal': 1,
#    'almost': 1,
#    'burdensome': 1,
#    'higher': 1,
#    'it': 1,
#    'upcoming': 1,
#    'cause': 1,
#    'entitled': 1,
#    'tax': 1,
#    'senator': 1,
#    'lot': 1,
#    'requested': 1,
#    'better': 1,
#    'enacting': 1,
#    'either': 1,
#    'individually': 1,
#    'ipas': 1,
#    'emerging': 1,
#    'key': 1,
#    'skeptical': 1,
#    'proving': 1,
#    'expanded': 1,
#    'applicable': 1,
#    'denied': 1,
#    'brought': 1,
#    'sanctioned': 1,
#    'education': 1,
#    'groundwater': 1,
#    'reduced': 1,
#    'able': 1,
#    'helping': 1,
#    'sponsoring': 1,
#    'routinely': 2,
#    'facing': 1,
#    'viewed': 1,
#    'minimum': 1,
#    'coming': 1,
#    'numerous': 1,
#    'thousands': 1,
#    'bills': 1,
#    'contacting': 1,
#    'turning': 1,
#    'gratifying': 1,
#    'felt': 1,
#    'otherwise': 1,
#    'contributed': 1,
#    'voted': 1,
#    'listing': 1,
#    'exchanging': 1,
#    'incidentally': 1,
#    'cooperating': 1,
#    'bei': 1,
#    'mathiasrmd': 1,
#    'heavily': 1,
#    'doubtful': 1}},
#  'strongly': {'left': {'are': 3,
#    'again': 1,
#    'but': 1,
#    'will': 1,
#    'spoke': 1,
#    'has': 2,
#    'baldridge': 1,
#    'cma': 3,
#    'levels': 1,
#    'supported': 1,
#    'press': 1,
#    'industry': 1,
#    'taxes': 1,
#    'be': 1,
#    'minority': 1,
#    'is': 5,
#    'comments': 1,
#    'house': 1,
#    'and': 1,
#    'testimony': 1,
#    'was': 1,
#    'moved': 1,
#    'association': 1,
#    'been': 1},
#   'right': {'encouraged': 1,
#    'confirmed': 1,
#    'opposed': 7,
#    'espouse': 1,
#    'for': 2,
#    'supported': 7,
#    'urges': 2,
#    'oppose': 2,
#    'on': 1,
#    'by': 1,
#    'supports': 1,
#    'made': 1,
#    'opposing': 1,
#    'emphasized': 2,
#    'to': 1,
#    'promoted': 1,
#    'opposes': 1}},
#  'encouraged': {'left': {'strongly': 1,
#    'be': 3,
#    'and': 2,
#    'then': 1,
#    'committee': 1,
#    'successfully': 1,
#    'mentioned': 1,
#    'commants': 1,
#    'also': 1,
#    'are': 2,
#    'most': 1,
#    'has': 1,
#    'he': 1,
#    'even': 1},
#   'right': {'to': 7,
#    'initiation': 1,
#    'its': 1,
#    'epa': 1,
#    'the': 2,
#    'other': 1,
#    'by': 1,
#    'changes': 1,
#    'that': 1,
#    'us': 1,
#    'attendance': 1}},
#  'to': {'left': {'encouraged': 7,
#    'continue': 137,
#    'continues': 84,
#    'state': 10,
#    'groundwater': 2,
#    'failure': 7,
#    'attention': 25,
#    'opposed': 18,
#    'relating': 34,
#    'appeared': 5,
#    'referred': 10,
#    'relationship': 4,
#    'judge': 2,
#    'likely': 49,
#    'appealed': 3,
#    'precedent': 1,
#    'intended': 20,
#    'producer': 1,
#    'savings': 4,
#    'at': 2,
#    'cost': 12,
#    'available': 26,
#    'amendment': 28,
#    'lost': 2,
#    'feedstock': 3,
#    'dec': 1,
#    'need': 56,
#    'issues': 12,
#    'discretion': 2,
#    'when': 2,
#    'effort': 60,
#    'began': 3,
#    'back': 10,
#    'moved': 9,
#    'continued': 20,
#    'be': 18,
#    'comments': 46,
#    'amendments': 61,
#    'cma': 30,
#    'revisions': 18,
#    'addition': 53,
#    'dedicated': 7,
#    'october': 5,
#    'newsfeeds': 1,
#    'waste': 6,
#    'million': 3,
#    'prior': 39,
#    'members': 20,
#    'film': 1,
#    'distributed': 27,
#    'sold': 3,
#    'rules': 5,
#    'used': 35,
#    'model': 3,
#    'rule': 10,
#    'whether': 6,
#    'similar': 27,
#    'developing': 1,
#    'group': 39,
#    'survey': 6,
#    'designed': 53,
#    'supposed': 2,
#    'questions': 2,
#    'pursuant': 8,
#    'respond': 27,
#    'invited': 8,
#    'needs': 17,
#    'allowed': 6,
#    'meeting': 10,
#    'applicable': 11,
#    'is': 94,
#    'amenable': 1,
#    'question': 4,
#    'willing': 11,
#    'subject': 47,
#    'estimated': 7,
#    'epa': 36,
#    'challenge': 4,
#    'of': 17,
#    'plans': 52,
#    'intent': 12,
#    'program': 48,
#    'required': 21,
#    'authorized': 8,
#    'statute': 1,
#    'first': 7,
#    'concern': 18,
#    'relative': 12,
#    'compared': 9,
#    'alternatives': 6,
#    'benefit': 6,
#    'modifications': 7,
#    'opportunity': 41,
#    'staff': 20,
#    'opposition': 34,
#    'districts': 2,
#    'expected': 93,
#    'issue': 7,
#    'begin': 8,
#    'landfill': 1,
#    'unit': 1,
#    'agreed': 30,
#    'council': 11,
#    'capacity': 5,
#    'up': 37,
#    'proposes': 3,
#    'compounds': 1,
#    'petitions': 2,
#    'requirement': 3,
#    'wastes': 2,
#    'refusal': 1,
#    'deciding': 1,
#    'lead': 17,
#    'costs': 3,
#    'response': 80,
#    'replying': 1,
#    'letter': 21,
#    'him': 2,
#    'vowed': 1,
#    'plan': 26,
#    'bill': 22,
#    'and': 148,
#    'committed': 15,
#    'identical': 1,
#    'working': 14,
#    'expect': 13,
#    'not': 32,
#    'responding': 19,
#    'pertaining': 12,
#    'time': 24,
#    'position': 16,
#    'difficult': 12,
#    'manual': 1,
#    'mailed': 11,
#    'information': 19,
#    'programs': 21,
#    'provided': 11,
#    'workshop': 4,
#    'how': 23,
#    'needed': 24,
#    'performing': 1,
#    'summer': 1,
#    'counter': 2,
#    'court': 6,
#    'scheduled': 17,
#    'funding': 7,
#    'sufficient': 3,
#    'like': 29,
#    'drivers': 1,
#    'enacted': 2,
#    'reported': 20,
#    'begun': 9,
#    'shipments': 1,
#    'guard': 3,
#    'columbia': 1,
#    'reply': 2,
#    'parties': 3,
#    'decided': 22,
#    'rates': 3,
#    'them': 17,
#    'exporters': 1,
#    'trying': 10,
#    'industrywide': 1,
#    'efforts': 54,
#    'taken': 4,
#    'forces': 3,
#    'exposed': 18,
#    'industry': 29,
#    'friday': 1,
#    'shifts': 1,
#    'call': 12,
#    'called': 11,
#    'exhibit': 1,
#    'circulated': 2,
#    'presented': 22,
#    'referring': 6,
#    'reduced': 8,
#    'asked': 17,
#    'perception': 1,
#    'added': 7,
#    'work': 10,
#    'related': 44,
#    'order': 62,
#    'effectively': 2,
#    'appointed': 4,
#    'elected': 7,
#    'made': 34,
#    'urged': 10,
#    'brought': 9,
#    'alluding': 1,
#    'volunteered': 1,
#    'makers': 1,
#    'directors': 3,
#    'tions': 1,
#    'responses': 10,
#    'able': 49,
#    'perspective': 1,
#    'devoted': 14,
#    'expanded': 7,
#    'osha': 12,
#    'ways': 9,
#    'try': 11,
#    'departaent': 1,
#    'screening': 1,
#    'balance': 3,
#    'vehicle': 1,
#    'are': 21,
#    'osra': 1,
#    'ezpected': 1,
#    'pressure': 4,
#    'aaterials': 1,
#    'groups': 17,
#    'remarks': 14,
#    'clear': 3,
#    'equipped': 1,
#    'america': 1,
#    'as': 60,
#    'chance': 3,
#    'credence': 1,
#    'corporations': 1,
#    'nor': 1,
#    'attempting': 14,
#    'appropriate': 9,
#    'from': 24,
#    'practices': 3,
#    'responded': 16,
#    'passed': 1,
#    'recommended': 8,
#    'shown': 6,
#    'planning': 2,
#    'sequel': 1,
#    'communication': 3,
#    'committee': 40,
#    'objections': 4,
#    'chemicals': 5,
#    'promised': 2,
#    'failed': 13,
#    'unlikely': 9,
#    'react': 2,
#    'congress': 19,
#    'passage': 1,
#    'matters': 3,
#    'seminar': 1,
#    'bring': 3,
#    'investigate': 1,
#    'arbitrarily': 1,
#    'sent': 29,
#    'coalition': 6,
#    'reasons': 1,
#    'amended': 9,
#    'changes': 26,
#    'objected': 4,
#    'refused': 4,
#    'legislation': 36,
#    'contrast': 2,
#    'expeditiously': 1,
#    'role': 2,
#    'infringement': 1,
#    'looking': 5,
#    'dnj': 3,
#    'also': 6,
#    'have': 31,
#    'officials': 9,
#    'december': 5,
#    'appeal': 3,
#    'seeks': 5,
#    'applies': 7,
#    'states': 18,
#    'roughly': 1,
#    'enough': 6,
#    'administration': 10,
#    'damage': 2,
#    'legislature': 4,
#    'seeking': 9,
#    'approach': 31,
#    'but': 3,
#    'stappa': 1,
#    'power': 5,
#    'commission': 4,
#    'regulations': 12,
#    'association': 12,
#    'exposure': 34,
#    'due': 41,
#    'drugs': 1,
#    'fda': 3,
#    'dichlorobenzenes': 1,
#    'preparing': 8,
#    'submitted': 34,
#    'actions': 12,
#    'reaction': 3,
#    'respect': 41,
#    'essential': 6,
#    'companies': 41,
#    'professionals': 1,
#    'areas': 2,
#    'commit': 2,
#    'hmacs': 1,
#    'individuals': 3,
#    'except': 2,
#    'important': 15,
#    'years': 10,
#    'was': 30,
#    'comparable': 3,
#    'extent': 6,
#    'cooperatively': 1,
#    'forward': 9,
#    'proud': 1,
#    'contribution': 11,
#    'waterhouse': 1,
#    'grant': 4,
#    'meetings': 5,
#    'statement': 6,
#    'visits': 6,
#    'means': 12,
#    'request': 8,
#    'transmitted': 2,
#    'delivered': 4,
#    'modification': 2,
#    'teams': 3,
#    'study': 12,
#    'papers': 3,
#    'assignments': 2,
#    'activities': 13,
#    'brackets': 1,
#    'expenses': 6,
#    'remain': 2,
#    'it': 18,
#    'add': 2,
#    'rapidly': 2,
#    'sure': 3,
#    'adhering': 1,
#    'case': 4,
#    'appears': 29,
#    'preferable': 3,
#    'plana': 1,
#    'charged': 4,
#    'totaled': 1,
#    'forwarded': 6,
#    'proposal': 30,
#    'supplementary': 1,
#    'desire': 4,
#    'basis': 2,
#    'chosen': 5,
#    'deadline': 1,
#    'in': 18,
#    'agency': 6,
#    'objects': 1,
#    'primarily': 5,
#    'section': 6,
#    'subsequent': 4,
#    'limited': 22,
#    'to': 5,
#    'january': 8,
#    'aerodynamics': 1,
#    'necessary': 35,
#    'experiments': 1,
#    'contribute': 5,
#    'proposals': 15,
#    'exceptions': 1,
#    'tsca': 3,
#    'manufacturers': 4,
#    'ostp': 1,
#    'act': 11,
#    'charter': 2,
#    'advisors': 5,
#    'jcia': 1,
#    'yields': 1,
#    'views': 1,
#    'relate': 5,
#    'appear': 8,
#    'action': 10,
#    'claimants': 1,
#    'worked': 9,
#    'offered': 4,
#    'report': 61,
#    'recommendations': 15,
#    'niosh': 2,
#    'lautenberg': 1,
#    'endangerment': 1,
#    'company': 8,
#    'dpa': 1,
#    'hastily': 1,
#    'opened': 2,
#    'pleased': 8,
#    'come': 8,
#    'modified': 1,
#    'or': 16,
#    'finally': 1,
#    'proven': 2,
#    'nswma': 1,
#    'solely': 2,
#    'importance': 16,
#    'data': 17,
#    'activity': 3,
#    'input': 9,
#    'requested': 4,
#    'yet': 6,
#    'assigned': 8,
#    'beneficial': 3,
#    'annually': 1,
#    'unable': 6,
#    'quickly': 2,
#    'committees': 2,
#    'closer': 2,
#    'that': 6,
#    'forced': 6,
#    'prepared': 21,
#    'intention': 6,
#    'monies': 1,
#    'superfund': 1,
#    'funds': 9,
#    'certain': 3,
#    'authority': 29,
#    'proved': 2,
#    'attempts': 6,
#    'language': 6,
#    'goes': 5,
#    'attempt': 24,
#    'significance': 3,
#    'approved': 2,
#    'intact': 1,
#    'spread': 1,
#    'decision': 8,
#    'part': 6,
#    'democrats': 1,
#    'alternative': 9,
#    'slow': 1,
#    'early': 6,
#    'go': 8,
#    'fifra': 1,
#    'divisions': 1,
#    'commitment': 8,
#    'created': 1,
#    'november': 6,
#    'relevant': 4,
#    'evaluation': 1,
#    'lyon': 1,
#    'adherence': 4,
#    'paper': 1,
#    'manuscript': 1,
#    'wrote': 3,
#    'representatives': 12,
#    'letters': 1,
#    'awarded': 2,
#    'money': 3,
#    'form': 1,
#    'corporation': 4,
#    'body': 1,
#    'associations': 7,
#    'organize': 1,
#    'government': 9,
#    'results': 3,
#    'led': 6,
#    'records': 2,
#    'ongoing': 2,
#    'me': 2,
#    'right': 41,
#    'hope': 6,
#    'remains': 6,
#    'harmful': 1,
#    'restricted': 6,
#    'key': 3,
#    'push': 6,
#    'requirements': 7,
#    'doing': 4,
#    'risks': 7,
#    'interests': 2,
#    'neoessary': 1,
#    'again': 4,
#    'assistance': 8,
#    'want': 10,
#    'petition': 6,
#    'done': 5,
#    'seems': 7,
#    'negotiations': 1,
#    'us': 20,
#    'exemptions': 1,
#    'refreshing': 1,
#    'priority': 5,
#    'hearings': 3,
#    'seek': 7,
#    'intend': 9,
#    'office': 5,
#    'process': 7,
#    'reason': 4,
#    'one': 4,
#    'endeavoring': 2,
#    'discussion': 1,
#    'these': 3,
#    'criteria': 1,
#    'dow': 1,
#    'given': 18,
#    'goals': 1,
#    'protection': 5,
#    'return': 8,
#    'better': 1,
#    'place': 4,
#    'issuance': 1,
#    'law': 11,
#    'countries': 7,
#    'resources': 19,
#    'takes': 1,
#    'procedure': 4,
#    'defer': 1,
#    'others': 5,
#    'wishes': 3,
#    'year': 14,
#    'compensation': 5,
#    'filing': 1,
#    'country': 3,
#    'had': 5,
#    'europe': 1,
#    'governments': 3,
#    'relates': 9,
#    'courts': 5,
#    'unrelated': 1,
#    'processes': 2,
#    'ability': 21,
#    'ing': 4,
#    'impediments': 1,
#    'specific': 5,
#    'assisted': 2,
#    'policy': 8,
#    'wellpositioned': 1,
#    'reporting': 3,
#    'obvious': 2,
#    'slipped': 1,
#    'going': 11,
#    'percent': 5,
#    'has': 3,
#    'trade': 2,
#    'number': 1,
#    'croup': 1,
#    'changed': 2,
#    'name': 1,
#    'support': 17,
#    'treaty': 1,
#    'investment': 1,
#    'turning': 5,
#    'seem': 8,
#    'preparatory': 1,
#    'guidance': 3,
#    'aid': 5,
#    'helpful': 2,
#    'been': 5,
#    'tied': 3,
#    'succeeded': 1,
#    'considered': 9,
#    'precursor': 1,
#    'exception': 3,
#    'worthwhile': 1,
#    'anticipated': 3,
#    'acceptable': 9,
#    'voices': 1,
#    'down': 4,
#    'blessed': 1,
#    'you': 8,
#    'way': 10,
#    'projected': 2,
#    'equivalent': 3,
#    'insight': 1,
#    'area': 2,
#    'wish': 13,
#    'came': 7,
#    'sentiment': 1,
#    'months': 3,
#    'increase': 6,
#    'access': 33,
#    'geared': 2,
#    'adequate': 3,
#    'updated': 2,
#    'chairmen': 1,
#    'steps': 6,
#    'ustr': 2,
#    'cradlt': 1,
#    'benefits': 10,
#    'agree': 3,
#    'round': 1,
#    'september': 7,
#    'sought': 8,
#    'fta': 1,
#    'agreement': 13,
#    'connected': 1,
#    'positions': 7,
#    'regard': 22,
#    'willingness': 10,
#    'revision': 2,
#    'canada': 5,
#    'start': 2,
#    'modules': 1,
#    'surely': 1,
#    'alerted': 3,
#    'itc': 2,
#    'advice': 2,
#    'prepares': 1,
#    'pleasure': 3,
#    'today': 2,
#    'contributions': 10,
#    'served': 3,
#    'iii': 1,
#    'inception': 1,
#    'limits': 1,
#    'presentation': 12,
#    'endeavors': 1,
#    'approaches': 3,
#    'avenue': 1,
#    'sum': 1,
#    'chose': 4,
#    'believe': 3,
#    'activityone': 1,
#    'sensitive': 2,
#    'partnership': 1,
#    'tend': 4,
#    'resolvedproblem': 1,
#    'lawsuit': 1,
#    'ahead': 2,
#    'personnel': 11,
#    'necessity': 2,
#    'repairing': 1,
#    'struggle': 1,
#    'relegated': 1,
#    'additions': 2,
#    'applied': 5,
#    'pertains': 2,
#    'remanded': 2,
#    'disclosure': 1,
#    'impossible': 1,
#    'prepare': 2,
#    'comment': 1,
#    'looks': 1,
#    'profiles': 1,
#    'contacts': 5,
#    'coordinator': 1,
#    'reports': 8,
#    'procedures': 8,
#    'sites': 2,
#    'best': 4,
#    'initiatives': 5,
#    'went': 2,
#    'trained': 2,
#    'economical': 1,
#    'jointly': 1,
#    'conrail': 5,
#    'closest': 1,
#    'competition': 1,
#    'continuing': 11,
#    'exemption': 3,
#    'apply': 16,
#    'owners': 1,
#    'formed': 8,
#    'dot': 2,
#    'rail': 2,
#    'railroads': 2,
#    'railroad': 3,
#    'leave': 1,
#    'conveyed': 5,
#    'brazil': 2,
#    'imports': 4,
#    'objection': 2,
#    'immunity': 2,
#    'referrals': 1,
#    'off': 1,
#    'resource': 2,
#    'provides': 1,
#    'dc': 1,
#    'operation': 2,
#    'where': 2,
#    'donated': 1,
#    'requests': 3,
#    'were': 6,
#    'developed': 10,
#    'reference': 17,
#    'according': 12,
#    'aggregate': 1,
#    'representative': 6,
#    'useful': 3,
#    'obligation': 2,
#    'internal': 1,
#    'notification': 2,
#    'agraad': 1,
#    'agraamant': 1,
#    'rasponsa': 1,
#    'bagan': 1,
#    'axpactad': 3,
#    'continuad': 1,
#    'gatt': 1,
#    'anough': 1,
#    'established': 6,
#    'session': 2,
#    'president': 10,
#    'affort': 1,
#    'continua': 4,
#    'ba': 1,
#    'dacidad': 1,
#    'ratainad': 1,
#    'naad': 2,
#    'present': 2,
#    'vital': 1,
#    'ues': 1,
#    'described': 1,
#    'selected': 2,
#    'distribution': 4,
#    'helped': 3,
#    'initiative': 2,
#    'now': 2,
#    'expertise': 2,
#    'approval': 5,
#    'rewritten': 1,
#    'leadership': 1,
#    'rulemaking': 2,
#    'collectively': 1,
#    'mechanism': 10,
#    'conform': 3,
#    'opportunities': 4,
#    'unresponsive': 2,
#    'interest': 18,
#    'ready': 6,
#    'exists': 4,
#    'itself': 4,
#    'more': 4,
#    'however': 5,
#    'departments': 1,
#    'decide': 5,
#    'intends': 14,
#    'glad': 1,
#    'objective': 8,
#    'followup': 1,
#    'costly': 2,
#    'surveyed': 1,
#    'expense': 1,
#    'tion': 4,
#    'klein': 1,
#    'age': 1,
#    'ies': 1,
#    'on': 5,
#    'appendices': 1,
#    'pda': 1,
#    'jecfa': 1,
#    'research': 4,
#    'bulletin': 1,
#    'proposed': 13,
#    'objecting': 1,
#    'toxicologists': 1,
#    'commissioners': 2,
#    'tunity': 2,
#    'pe': 1,
#    'tma': 1,
#    'deha': 1,
#    'lowered': 1,
#    'returning': 1,
#    'july': 4,
#    'votes': 1,
#    'equal': 8,
#    'principles': 3,
#    'tives': 3,
#    'prices': 11,
#    'tax': 2,
#    'grounds': 1,
#    'newsletter': 2,
#    'anxious': 3,
#    'standards': 2,
#    'allude': 1,
#    'beginning': 8,
#    'held': 2,
#    'techniques': 2,
#    'cic': 1,
#    'international': 1,
#    'cefic': 1,
#    'june': 7,
#    'soard': 1,
#    'formally': 1,
# ...
#    'regula': 1,
#    'approach': 1,
#    'leaks': 1,
#    'standard': 1,
#    'rates': 1,
#    'characteristics': 1,
#    'inventories': 2,
#    'data': 3,
#    'points': 1,
#    'measuring': 1,
#    'controls': 2}},
#  'frank': {'left': {'senator': 6,
#    'barney': 1,
#    'results': 1,
#    'program': 1,
#    'policy': 1,
#    'invitation': 1,
#    'for': 1,
#    'sorgenti': 1,
#    'corporation': 2,
#    'winson': 1,
#    'opposition': 1,
#    'and': 1,
#    'congressman': 1,
#    'committee': 1,
#    'response': 1,
#    'recommendations': 1},
#   'right': {'lautenberg': 4,
#    'dma': 2,
#    'berryman': 10,
#    'moss': 1,
#    'deliberation': 1,
#    'seamans': 1,
#    'mckeeunited': 1,
#    'church': 1,
#    'murkowski': 1}},
#  'lautenberg': {'left': {'frank': 4,
#    'with': 1,
#    'and': 1,
#    'the': 1,
#    'senator': 1},
#   'right': {'dnj': 6, 'to': 1, 'amendments': 1}},
#  'dnj': {'left': {'lautenberg': 6,
#    'florios': 2,
#    'florio': 10,
#    'roe': 7,
#    'bradley': 2,
#    'committee': 1,
#    'williams': 1,
#    'lautenbcrg': 1,
#    'row': 1},
#   'right': {'in': 1,
#    'to': 3,
#    'cma': 2,
#    'staff': 1,
#    'subcommittee': 1,
#    'chairman': 1,
#    'and': 1,
#    'has': 6,
#    'last': 1,
#    'basically': 1,
#    'held': 2,
#    'introduced': 2,
#    'may': 1,
#    'expectations': 1,
#    'anticipates': 1,
#    'would': 1,
#    'the': 1,
#    'henry': 1,
#    'edward': 1,
#    'worked': 1,
#    'became': 1}},
#  'acid': {'left': {'on': 6,
#    'the': 3,
#    'onerous': 2,
#    'houae': 1,
#    'including': 1,
#    'and': 1,
#    'waxman': 1,
#    'as': 1,
#    'sulfuric': 3,
#    'current': 1,
#    'psd': 1,
#    'an': 1,
#    'nitric': 1,
#    'pollutant': 1,
#    'are': 1,
#    'ethylhexanoic': 3,
#    'ethvlhexanolc': 1,
#    'acetic': 1,
#    'groundwater': 1,
#    'ethylhexaiioic': 1},
#   'right': {'rain': 21,
#    'mist': 1,
#    'carboys': 1,
#    'plants': 2,
#    'producers': 1,
#    'the': 3,
#    'cma': 1,
#    'esters': 1,
#    'panel': 1}},
#  'rain': {'left': {'acid': 21, 'will': 1},
#   'right': {'began': 1,
#    'bills': 1,
#    'control': 5,
#    'air': 1,
#    'legislation': 2,
#    'bill': 1,
#    'increasing': 1,
#    'provisions': 1,
#    'groundwater': 1,
#    'she': 1,
#    'mobile': 1,
#    'amendment': 1,
#    'and': 3,
#    'issue': 1,
#    'high': 1}},
#  'next': {'left': {'the': 94,
#    'room': 3,
#    'meeting': 3,
#    'early': 4,
#    'debate': 1,
#    'up': 1,
#    'discussed': 1,
#    'by': 1,
#    'intensify': 1,
#    'legislation': 1,
#    'again': 1,
#    'issues': 1,
#    'of': 3,
#    'attention': 1,
#    'che': 1,
#    'and': 2,
#    'before': 1,
#    'participation': 1,
#    'buy': 1,
#    'our': 1,
#    'tsca': 1,
#    'adjournment': 2,
#    'concerning': 1,
#    'worse': 1,
#    'this': 1,
#    'which': 1,
#    'return': 1,
#    'is': 2,
#    'however': 1,
#    'bill': 2,
#    'industry': 1,
#    'tilt': 1,
#    'into': 1,
#    'states': 1,
#    'on': 1,
#    'consideration': 1,
#    'through': 1,
#    'two': 1,
#    'for': 1,
#    'support': 1,
#    'job': 1,
#    'earlv': 1,
#    'activity': 1,
#    'atlanta': 1},
#   'right': {'topic': 1,
#    'few': 13,
#    'two': 4,
#    'set': 1,
#    'meeting': 6,
#    'following': 1,
#    'year': 40,
#    'round': 3,
#    'quarter': 2,
#    'five': 1,
#    'three': 9,
#    'couple': 4,
#    'congress': 7,
#    'months': 3,
#    'nominee': 1,
#    'major': 1,
#    'thirty': 1,
#    'years': 8,
#    'executive': 1,
#    'day': 1,
#    'session': 1,
#    'regular': 1,
#    'million': 1,
#    'mca': 1,
#    'there': 1,
#    'several': 3,
#    'ten': 1,
#    'draft': 1,
#    'symposium': 1,
#    'month': 3,
#    'april': 2,
#    'week': 2,
#    'to': 1,
#    'step': 1,
#    'primary': 1,
#    'part': 1,
#    'slide': 1,
#    'annual': 1,
#    'monday': 1,
#    'concma': 1,
#    'edition': 1,
#    'nine': 1,
#    'teacher': 1,
#    'in': 1,
#    'behind': 1,
#    'choice': 1,
#    'four': 1,
#    'fiscal': 2,
#    'six': 1,
#    'issue': 1,
#    'report': 1,
#    'chemtrec': 1,
#    'ar': 1,
#    'hearings': 1,
#    'may': 1}},
#  'topic': {'left': {'next': 1,
#    'the': 6,
#    'related': 1,
#    'al': 1,
#    'ma': 2,
#    'city': 1,
#    'la': 1,
#    'dc': 1,
#    'co': 1,
#    'ut': 1,
#    'va': 1,
#    'carroll': 1,
#    'popular': 1,
#    'his': 2,
#    'pa': 1,
#    'washington': 1,
#    'meeting': 1,
#    'nh': 1,
#    'sc': 1,
#    'il': 1,
#    'fl': 1,
#    'lecture': 1,
#    'confer': 1},
#   'right': {'in': 3,
#    'of': 4,
#    'the': 3,
#    'is': 1,
#    'hazardous': 3,
#    'quality': 2,
#    'update': 1,
#    'information': 1,
#    'chemtrec': 1,
#    'epas': 1,
#    'salt': 1,
#    'at': 2,
#    'trends': 1,
#    'cma': 1,
#    'emergency': 1,
#    'chemtrechazardous': 1,
#    'relationship': 1,
#    'degree': 1,
#    'francisco': 1}},
#  'chromium': {'left': {'response': 1,
#    'list': 1,
#    'hexavalent': 1,
#    'of': 1,
#    'the': 1},
#   'right': {'comments': 1, 'and': 1, 'as': 1, 'in': 1, 'emissions': 1}},
#  'agencys': {'left': {'the': 32, 'protection': 3, 'that': 1},
#   'right': {'notice': 1,
#    'november': 1,
#    'carcinogen': 1,
#    'questions': 1,
#    'respect': 1,
#    'discretion': 1,
#    'generic': 1,
#    'interpretation': 1,
#    'collection': 1,
#    'budget': 1,
#    'implementation': 1,
#    'followup': 1,
#    'failure': 1,
#    'choice': 1,
#    'intent': 1,
#    'unbending': 1,
#    'jurisdiction': 1,
#    'proposed': 2,
#    'general': 1,
#    'testing': 1,
#    'draft': 2,
#    'existing': 1,
#    'increasingly': 1,
#    'plans': 4,
#    'epa': 1,
#    'revision': 1,
#    'authority': 1,
#    'hazardous': 2,
#    'actions': 1,
#    'administration': 1}},
#  'notice': {'left': {'agencys': 1,
#    'published': 1,
#    'ferc': 1,
#    'commissions': 1,
#    'advanced': 2,
#    'premanufacture': 2,
#    'july': 1,
#    'served': 1,
#    'oshas': 1,
#    'lawsuit': 1,
#    'advance': 8,
#    'days': 1,
#    'no': 2,
#    'short': 2,
#    'arbitrary': 2,
#    'disease': 1,
#    'register': 8,
#    'its': 1,
#    'the': 2,
#    'membership': 1,
#    'written': 2,
#    'prompt': 1,
#    'give': 1,
#    'public': 1,
#    'of': 1,
#    'issued': 1,
#    'proper': 1},
#   'right': {'of': 23,
#    'in': 2,
#    'and': 4,
#    'that': 1,
#    'is': 2,
#    'by': 1,
#    'involved': 1,
#    'as': 1,
#    'for': 1,
#    'stating': 1,
#    'news': 1,
#    'announcing': 2,
#    'thereof': 2,
#    'comes': 1,
#    'has': 1,
#    'published': 1,
#    'was': 1,
#    'on': 1,
#    'to': 1}},
#  'intent': {'left': {'of': 2,
#    'original': 1,
#    'the': 13,
#    'epas': 1,
#    'agencys': 1,
#    'their': 1,
#    'congressional': 1,
#    'elas': 1,
#    'my': 1,
#    'clarify': 1,
#    'an': 2,
#    'recent': 1,
#    'its': 1,
#    'his': 1},
#   'right': {'to': 12,
#    'negotiated': 1,
#    'of': 11,
#    'that': 1,
#    'and': 1,
#    'nor': 1,
#    'at': 1}},
#  'hexavalent': {'left': {'and': 1}, 'right': {'chromium': 1}},
#  'pollutants': {'left': {'air': 13,
#    'priority': 2,
#    'of': 3,
#    'hazardous': 2,
#    'criteria': 1,
#    'organic': 4,
#    'reduced': 1,
#    'toxic': 2},
#   'right': {'cmas': 1,
#    'the': 2,
#    'control': 1,
#    'groundwater': 2,
#    'or': 1,
#    'occupational': 1,
#    'are': 1,
#    'in': 4,
#    'controlled': 1,
#    'section': 1,
#    'by': 2,
#    'from': 2,
#    'area': 1,
#    'as': 1,
#    'until': 1,
#    'also': 1,
#    'dated': 1,
#    'nesbap': 1,
#    'since': 1,
#    'federal': 1,
#    'porgram': 1}},
#  'adequacy': {'left': {'technical': 2,
#    'the': 18,
#    'on': 1,
#    'increased': 1,
#    'revenue': 1,
#    'tha': 1,
#    'substantive': 1,
#    'cha': 1},
#   'right': {'of': 23, 'and': 2, 'on': 1}},
#  'exposure': {'left': {'of': 14,
#    'worker': 4,
#    'chloride': 1,
#    'environmental': 1,
#    'occupational': 5,
#    'committees': 1,
#    'the': 14,
#    'by': 1,
#    'and': 9,
#    'arsenic': 1,
#    'rabbits': 2,
#    'use': 2,
#    'with': 2,
#    'ether': 1,
#    'cpscs': 1,
#    'pcb': 1,
#    'significant': 2,
#    'from': 6,
#    'employees': 1,
#    'place': 1,
#    'widespread': 1,
#    'limited': 1,
#    'between': 2,
#    'waste': 1,
#    'actual': 1,
#    'workplace': 1,
#    'including': 1,
#    'last': 1,
#    'chemical': 1,
#    'maximum': 1,
#    'wide': 1,
#    'regarding': 1,
#    'control': 2,
#    'engine': 1,
#    'more': 1,
#    'dermal': 2,
#    'that': 2,
#    'potential': 2,
#    'toxicology': 1,
#    'cpsc': 1,
#    'an': 1,
#    'acceptable': 1,
#    'pmn': 1,
#    'human': 3,
#    'considers': 1,
#    'existing': 1,
#    'new': 1,
#    'term': 1,
#    'reducing': 1,
#    'permissible': 1,
#    'animal': 1,
#    'specific': 1,
#    'subchronle': 1,
#    'shortterm': 1,
#    'developing': 2,
#    'toward': 1,
#    'phosgeneonly': 1,
#    'where': 1},
#   'right': {'assessments': 3,
#    'to': 34,
#    'as': 1,
#    'data': 8,
#    'the': 2,
#    'assessment': 8,
#    'methods': 1,
#    'and': 10,
#    'below': 1,
#    'environmental': 1,
#    'levels': 2,
#    'studies': 2,
#    'should': 1,
#    'but': 1,
#    'in': 2,
#    'substantial': 1,
#    'small': 1,
#    'problem': 1,
#    'from': 2,
#    'these': 1,
#    'two': 1,
#    'information': 5,
#    'occurred': 1,
#    'statement': 1,
#    'industry': 1,
#    'tv': 1,
#    'chamber': 1,
#    'limit': 3,
#    'potentials': 1,
#    'might': 1,
#    'study': 1,
#    'continue': 1,
#    'failed': 1,
#    'epa': 1,
#    'work': 2,
#    'limits': 1,
#    'of': 2,
#    'standard': 2,
#    'level': 1,
#    'incidents': 1,
#    'cma': 1,
#    'tb': 1,
#    'model': 1,
#    'is': 1}},
#  'assessments': {'left': {'exposure': 3,
#    'and': 2,
#    'risk': 3,
#    'dispersion': 1,
#    'epas': 1,
#    'the': 1,
#    'technology': 1,
#    'impact': 1,
#    'realistic': 1},
#   'right': {'conducted': 1,
#    'cma': 1,
#    'information': 1,
#    'and': 1,
#    'particularly': 1,
#    'evaluation': 1,
#    'done': 1,
#    'that': 1,
#    'required': 1,
#    'hazardous': 1,
#    'very': 1,
#    'of': 2,
#    'the': 1}},
#  'conducted': {'left': {'assessments': 1,
#    'was': 7,
#    'programs': 1,
#    'procedures': 1,
#    'inspections': 1,
#    'be': 12,
#    'has': 3,
#    'being': 5,
#    'are': 6,
#    'have': 1,
#    'chlorobenzenes': 1,
#    'director': 4,
#    'staff': 2,
#    'course': 1,
#    'study': 6,
#    'had': 1,
#    'efforts': 1,
#    'surveys': 1,
#    'been': 5,
#    'committee': 3,
#    'oregon': 1,
#    'survey': 1,
#    'industry': 2,
#    'group': 3,
#    'ings': 1,
#    'workshop': 1,
#    'briefing': 1,
#    'were': 2,
#    'recently': 1,
#    'and': 1,
#    'to': 2,
#    'program': 1,
#    'as': 1,
#    'we': 1,
#    'not': 2,
#    'yet': 1,
#    'oic': 1,
#    'studies': 1,
#    'also': 1,
#    'companies': 1,
#    'panel': 2,
#    'each': 1,
#    'butadiene': 1,
#    'harvey': 1},
#   'right': {'by': 21,
#    'for': 6,
#    'in': 14,
#    'two': 3,
#    'with': 2,
#    'on': 4,
#    'these': 1,
#    'media': 5,
#    'oversight': 1,
#    'study': 2,
#    'based': 1,
#    'under': 3,
#    'within': 1,
#    'ts': 1,
#    'its': 2,
#    'at': 4,
#    'benefits': 1,
#    'year': 1,
#    'six': 1,
#    'twoday': 1,
#    'third': 1,
#    'seven': 1,
#    'trichloroethylene': 1,
#    'national': 1,
#    'and': 1,
#    'seminar': 1,
#    'radio': 1,
#    'or': 1,
#    'review': 2,
#    'as': 1,
#    'an': 1,
#    'vinyl': 1,
#    'caer': 1,
#    'because': 1,
#    'their': 1,
#    'advocacy': 1,
#    'thirdparty': 1,
#    'inhouse': 1,
#    'also': 1}},
#  'cooling': {'left': {'in': 1}, 'right': {'towers': 1}},
#  'towers': {'left': {'cooling': 1}, 'right': {'and': 1}},
#  'result': {'left': {'emissions': 1,
#    'likely': 1,
#    'also': 2,
#    'as': 62,
#    'well': 1,
#    'will': 15,
#    'the': 12,
#    'and': 1,
#    'direct': 4,
#    'primary': 1,
#    'not': 2,
#    'negotiations': 1,
#    'could': 2,
#    'to': 1,
#    'final': 1,
#    'net': 2,
#    'increases': 1,
#    'would': 8,
#    'in': 1,
#    'can': 1,
#    'should': 1,
#    'natural': 1,
#    'cma': 1,
#    'are': 1,
#    'soon': 1,
#    'ably': 1,
#    'capabilitiesas': 1,
#    'probably': 1,
#    'positive': 1,
#    'ic': 1,
#    'end': 1,
#    'primarily': 1},
#   'right': {'in': 38,
#    'of': 60,
#    'primarily': 1,
#    'materially': 1,
#    'may': 1,
#    'will': 1,
#    'priority': 1,
#    'survey': 1,
#    'spend': 1,
#    'public': 1,
#    'is': 1,
#    'ing': 1,
#    'being': 1,
#    'from': 3,
#    'the': 5,
#    'nine': 1,
#    'one': 1,
#    'we': 3,
#    'was': 2,
#    'congress': 1,
#    'final': 1,
#    'cma': 1,
#    'our': 1,
#    'parliamentary': 1,
#    'epa': 1,
#    'ofan': 1,
#    'it': 1}},
#  'ambient': {'left': {'in': 1,
#    'new': 1,
#    'meeting': 1,
#    'chan': 1,
#    'on': 1,
#    'enforceable': 1,
#    'possible': 1,
#    'than': 1,
#    'and': 1,
#    'national': 3,
#    'to': 1,
#    'data': 2,
#    'analyze': 1,
#    'of': 1,
#    'primary': 1,
#    'an': 1,
#    'set': 1},
#   'right': {'problems': 1,
#    'air': 12,
#    'exposures': 1,
#    'emissions': 1,
#    'numbers': 1,
#    'monitoring': 1,
#    'standardsetting': 1,
#    'ozone': 1,
#    'limits': 1}},
#  'problems': {'left': {'ambient': 1,
#    'technical': 2,
#    'outlining': 1,
#    'various': 2,
#    'workplace': 1,
#    'continuing': 1,
#    'industrys': 1,
#    'particular': 1,
#    'numerous': 2,
#    'practical': 2,
#    'contamination': 1,
#    'the': 10,
#    'these': 1,
#    'of': 4,
#    'its': 1,
#    'trade': 6,
#    'tax': 1,
#    'impending': 1,
#    'relationship': 1,
#    'industry': 2,
#    'explore': 1,
#    'and': 4,
#    'lacards': 1,
#    'significant': 1,
#    'identified': 1,
#    'competition': 1,
#    'current': 2,
#    'economic': 1,
#    'communications': 2,
#    'relations': 3,
#    'resolve': 1,
#    'hazards': 1,
#    'chemical': 1,
#    'regulatory': 1,
#    'compliance': 2,
#    'few': 1,
#    'waste': 1,
#    'solve': 1,
#    'confidentiality': 1,
#    'larger': 1,
#    'lurking': 1,
#    'their': 1,
#    'longrange': 1,
#    'supply': 1,
#    'dustry': 1,
#    'are': 1,
#    'environmental': 1,
#    'two': 1,
#    'many': 2,
#    'siting': 1,
#    'claim': 1,
#    'our': 2,
#    'regional': 1,
#    'mentioned': 1,
#    'to': 2,
#    'tion': 1,
#    'pollution': 2,
#    'manpower': 1,
#    'todays': 2,
#    'that': 1,
#    'potential': 1,
#    'serious': 1,
#    'investment': 1,
#    'has': 1,
#    'on': 3,
#    'staff': 1,
#    'related': 1,
#    'future': 1,
#    'causing': 1,
#    'for': 1,
#    'import': 1,
#    'substantive': 1,
#    'scientific': 1,
#    'common': 1,
#    'specific': 1,
#    'raise': 1,
#    'face': 1,
#    'any': 1,
#    'attendance': 1,
#    'quality': 1,
#    'tha': 1,
#    'policy': 1,
#    'control': 1,
#    'insurability': 1,
#    'where': 1,
#    'address': 1},
#   'right': {'emissions': 1,
#    'in': 7,
#    'the': 4,
#    'being': 1,
#    'industry': 1,
#    'with': 9,
#    'andor': 1,
#    'raised': 2,
#    'posed': 1,
#    'by': 1,
#    'changes': 1,
#    'is': 2,
#    'this': 2,
#    'faced': 2,
#    'encountered': 1,
#    'clair': 1,
#    'however': 2,
#    'what': 1,
#    'and': 8,
#    'of': 7,
#    'for': 3,
#    'regional': 1,
#    'which': 3,
#    'high': 1,
#    'our': 2,
#    'can': 1,
#    'cma': 2,
#    'that': 2,
#    'other': 1,
#    'we': 3,
#    'including': 1,
#    'involving': 2,
#    'at': 1,
#    'confronting': 1,
#    'another': 1,
#    'through': 1,
#    'but': 1,
#    'like': 1,
#    'are': 4,
#    'as': 2,
#    'principally': 1,
#    'created': 2,
#    'before': 1,
#    'occupational': 1,
#    'top': 1,
#    'such': 1,
#    'arising': 1,
#    'occuring': 1,
#    'resulting': 1,
#    'associated': 3,
#    'because': 1,
#    'accomplishments': 1,
#    'particularly': 1,
#    'upon': 1,
#    'none': 1,
#    'having': 1,
#    'recommend': 1,
#    'on': 2,
#    'remain': 1,
#    'observed': 1,
#    'they': 2,
#    'similar': 1,
#    'facing': 1,
#    'or': 1,
#    'could': 1,
#    'from': 1,
#    'experienced': 1,
#    'involved': 2}},
#  'trading': {'left': {'emissions': 5,
#    'insider': 1,
#    'export': 5,
#    'major': 3,
#    'state': 1,
#    'prasant': 1,
#    'largest': 1,
#    'the': 1,
#    'controlled': 1,
#    'ec': 1,
#    'our': 1,
#    'by': 1,
#    'of': 1,
#    'european': 1,
#    'international': 2,
#    'sound': 1},
#   'right': {'policy': 5,
#    'chemical': 1,
#    'company': 5,
#    'partners': 7,
#    'companies': 1,
#    'systam': 1,
#    'partner': 2,
#    'day': 1,
#    'and': 2,
#    'rules': 2}},
#  'petition': {'left': {'policy': 1,
#    'industry': 1,
#    'cmas': 5,
#    'railroads': 1,
#    'remedy': 1,
#    'this': 2,
#    'citizen': 1,
#    'the': 11,
#    'joint': 1,
#    'cma': 1,
#    'its': 1,
#    'example': 1,
#    'filed': 2,
#    'after': 1,
#    'deny': 1,
#    'must': 1,
#    'aar': 1,
#    'exemption': 1,
#    'exemptions': 2,
#    'api': 1,
#    'received': 1,
#    'situations': 1,
#    'to': 1,
#    'also': 1,
#    'supplemental': 1,
#    'through': 1,
#    'section': 2,
#    'teamsters': 2,
#    'citizens': 1,
#    'september': 1,
#    'denied': 1},
#   'right': {'cma': 1,
#    'is': 2,
#    'was': 5,
#    'for': 7,
#    'filed': 4,
#    'contested': 1,
#    'with': 1,
#    'reflects': 1,
#    'future': 1,
#    'to': 6,
#    'where': 1,
#    'extension': 1,
#    'by': 1,
#    'or': 1,
#    'circuit': 1,
#    'section': 1,
#    'third': 1,
#    'from': 1,
#    'the': 2,
#    'process': 1,
#    'must': 1,
#    'within': 1,
#    'fluorocarbons': 2,
#    'asked': 1,
#    'on': 1,
#    'requesting': 1,
#    'that': 1,
#    'claims': 1,
#    'of': 1}},
#  'conjunction': {'left': {'in': 26}, 'right': {'with': 26}},
#  'petitioned': {'left': {'has': 4, 'jointly': 1},
#   'right': {'epa': 1, 'for': 1, 'the': 3}},
#  ...}

# %%
def get_Pr_context_correction(cand, left, right,method):
    """
   
    """
    # r_left = freq of left appearing, r_right = freq of right appearing
    r_left, r_right = 0, 0
    if cand:
        if left in neighbor_dict[cand]['left'].keys():
            r_left = neighbor_dict[cand]['left'][left]
        if right in neighbor_dict[cand]['right'].keys():
            r_right = neighbor_dict[cand]['right'][right]
        if method == 'MLE':
            return r_left*r_right
        elif method == 'ELE':
            return  (r_left+0.5)*(r_right+0.5)
        else:
            return  
    else:
        return 0

# %%
result = Create_Word_Pair()
word_pairs = result[:-1]
num_corrections_found_tesseract, sum_letters = result[-1][0], result[-1][1]

# %%
start = timeit.default_timer()
detected_error_tuples2 = []

for t in detected_error_tuples:
    for pair in word_pairs:
        if t[0] == pair[1]:
            detected_error_tuples2.append((t[0], pair[0], t[1], t[2]))
            break
stop = timeit.default_timer() 
print('Time:', stop - start, 'seconds')
# Out:
# Time: 6.722171888999583 seconds

# %%
#####################################
#here i compute pc * ptc
#mle_p/ele_p/gt_p corresponds to each case by using 4 methods

#what do we need to do next
#1.for each candidate, store the best(max) mle_p/ele_p/gt_p under different methods
#2.store all best p 

#problem I met is after loops, the storing list gets empty. 
#I think paying more attention to nested loops might solve it


def get_final_Pr_correction(cand, typo, pre,cur,error_type, left, right, method):
    return get_Pr_c(cand,method) * get_Pr_tc(pre,cur,error_type) \
           * get_Pr_context_correction(cand, left, right)

err_type = [ 'add','del', 'sub', 'rev']
# A dictionary of the form: typo:(ground_truth, MLE_correction, ELE_correction)
result = {}

for typo, truth, left, right in detected_error_tuples2:
    cand_poss_mle, cand_poss_ele,cand_poss_gt = [], [], []
    for e in range(4):
        if len(all_candidates[typo])>0:
            for cand,pre,cur in all_candidates[typo][e]:
                mle_p = get_Pr_c(cand,'MLE')*get_Pr_tc(pre,cur,err_type[e])
                ele_p = get_Pr_c(cand,'ELE')*get_Pr_tc(pre,cur,err_type[e])
                gt_p = get_Pr_c(cand,'GT')*get_Pr_tc(pre,cur,err_type[e])
                
                cand_poss_ele.append((cand, mle_p))
                cand_poss_mle.append((cand, ele_p))
                cand_poss_gt.append((cand, gt_p))
                
    
    mle_best_cand = max(cand_poss_mle, key=lambda x: x[1])[0] if cand_poss_mle else ''
    ele_best_cand = max(cand_poss_ele, key=lambda x: x[1])[0] if cand_poss_ele else ''
    gt_best_cand = max(cand_poss_gt, key=lambda x: x[1])[0] if cand_poss_gt else ''
    result[typo] = (truth, mle_best_cand, ele_best_cand,gt_best_cand)
 
   
                
  # ele_best_cand = max(cand_poss_ele, key=lambda x: x[1])[0] if cand_poss_ele else ''
  #  gt_best_cand = max(cand_poss_gt, key=lambda x: x[1])[0] if cand_poss_gt else ''
  #  result[typo] = (truth, mle_best_cand, ele_best_cand,gt_best_cand)

# %%
result
# Out:
# {'aaju': ('aar', '', '', ''),
#  'abbrevlated': ('abbreviated', 'abbreviated', 'abbreviated', 'abbreviated'),
#  'accldental': ('accidental', 'accidental', 'accidental', 'accidental'),
#  'accldents': ('accidents', 'accidents', 'accidents', 'accidents'),
#  'accompanled': ('accompanied', 'accompanied', 'accompanied', 'accompanied'),
#  'accompllsh': ('accomplish', 'accomplish', 'accomplish', 'accomplish'),
#  'accompllshed': ('accomplished',
#   'accomplished',
#   'accomplished',
#   'accomplished'),
#  'accompllshments': ('accomplishments',
#   'accomplishments',
#   'accomplishments',
#   'accomplishments'),
#  'accompllstazents': ('accomplistazents',
#   'accomplistazents',
#   'accomplistazents',
#   'accomplistazents'),
#  'accordlng': ('according', 'according', 'according', 'according'),
#  'accordlngly': ('accordingly', 'accordingly', 'accordingly', 'accordingly'),
#  'accountlng': ('accounting', '', '', ''),
#  'aces': ('acrs', '', '', ''),
#  'achlevement': ('achievement', 'achievement', 'achievement', 'achievement'),
#  'achlevlng': ('achieving', '', '', ''),
#  'acqualnted': ('acquainted', '', '', ''),
#  'acqulsltlon': ('acquisition', '', '', ''),
#  'acrylonltrll': ('acrylonitrile', '', '', ''),
#  'actlng': ('acting', 'acting', 'acting', 'acting'),
#  'actlvlt': ('activity', '', '', ''),
#  'actlvltles': ('activities', '', '', ''),
#  'actlvlty': ('activity', '', '', ''),
#  'addltlonal': ('additional', '', '', ''),
#  'addltlonally': ('additionally', '', '', ''),
#  'addltlves': ('additives', '', '', ''),
#  'addresslng': ('addressing', 'addressing', 'addressing', 'addressing'),
#  'admlnlsi': ('adminis', '', '', ''),
#  'admlnlsratlon': ('administration', '', '', ''),
#  'admlnlster': ('administer', '', '', ''),
#  'admlnlstered': ('administered', '', '', ''),
#  'admlnlstratlbn': ('administration', '', '', ''),
#  'admlnlstratln': ('administration', '', '', ''),
#  'admlnlstratlon': ('administration', '', '', ''),
#  'admlnlstratlons': ('administrations', '', '', ''),
#  'admlnlstratlve': ('administrative', '', '', ''),
#  'adulteratlon': ('adulteration',
#   'adulteration',
#   'adulteration',
#   'adulteration'),
#  'advertlslng': ('advertising', '', '', ''),
#  'advlsement': ('advisement', 'advisement', 'advisement', 'advisement'),
#  'advlslng': ('advising', '', '', ''),
#  'advocatd': ('advocated', 'advocated', 'advocated', 'advocated'),
#  'advocatlng': ('advocating', 'advocating', 'advocating', 'advocating'),
#  'affalrs': ('affairs', 'affairs', 'affairs', 'affairs'),
#  'affalrsemc': ('affairsemc', '', '', ''),
#  'affectlng': ('affecting', 'affecting', 'affecting', 'affecting'),
#  'afflllate': ('affiliate', '', '', ''),
#  'afflllated': ('affiliated', '', '', ''),
#  'afflllates': ('affiliates', '', '', ''),
#  'agencles': ('agencies', 'agencies', 'agencies', 'agencies'),
#  'aggresslvely': ('aggressively',
#   'aggressively',
#   'aggressively',
#   'aggressively'),
#  'agrlcultural': ('agricultural',
#   'agricultural',
#   'agricultural',
#   'agricultural'),
#  'agrlculture': ('agriculture', 'agriculture', 'agriculture', 'agriculture'),
#  'alllerkslgnal': ('alliedsignal', '', '', ''),
#  'allocatlon': ('allocation', '', '', ''),
#  'allowlng': ('allowing', 'allowing', 'allowing', 'allowing'),
#  'alternatlve': ('alternative', 'alternative', 'alternative', 'alternative'),
#  'alternatlves': ('alternatives',
#   'alternatives',
#   'alternatives',
#   'alternatives'),
#  'althugh': ('although', 'although', 'although', 'although'),
#  'analysls': ('analysis', 'analysis', 'analysis', 'analysis'),
#  'analytlcal': ('analytical', 'analytical', 'analytical', 'analytical'),
#  'analyzlng': ('analyzing', 'analyzing', 'analyzing', 'analyzing'),
#  'anlysls': ('analysis', '', '', ''),
#  'annlversary': ('anniversary', 'anniversary', 'anniversary', 'anniversary'),
#  'antlclpated': ('anticipated', '', '', ''),
#  'antlclpates': ('anticipates', '', '', ''),
#  'antlclpatlng': ('anticipating', '', '', ''),
#  'antlelpatlon': ('anticipation', '', '', ''),
#  'antltrust': ('antitrust', 'antitrust', 'antitrust', 'antitrust'),
#  'antltrutcompetltlve': ('antitrustcompetitive', '', '', ''),
#  'appendlx': ('appendix', '', '', ''),
#  'appllcable': ('applicable', '', '', ''),
#  'appllcablllty': ('applicability', '', '', ''),
#  'appllcants': ('applicants', '', '', ''),
#  'appllcatlons': ('applications',
#   'applicatlons',
#   'applicatlons',
#   'applicatlons'),
#  'appolntment': ('appointment', 'appointment', 'appointment', 'appointment'),
#  'appolntments': ('appointments',
#   'appointments',
#   'appointments',
#   'appointments'),
#  'apportlonment': ('apportionment',
#   'apportionment',
#   'apportionment',
#   'apportionment'),
#  'apprehenslon': ('apprehension',
#   'apprehension',
#   'apprehension',
#   'apprehension'),
#  'approplate': ('appropriate', '', '', ''),
#  'approprlate': ('appropriate', 'appropriate', 'appropriate', 'appropriate'),
#  'approprlatlons': ('appropriations', '', '', ''),
#  'approvd': ('approved', '', '', ''),
#  'approxlmate': ('approximate', 'approximate', 'approximate', 'approximate'),
#  'approxlmately': ('approximately',
#   'approximately',
#   'approximately',
#   'approximately'),
#  'arbltrarlly': ('arbitrarily', '', '', ''),
#  'arcdchemlcal': ('arcochemical', '', '', ''),
#  'arsenlc': ('arsenic', 'arsenic', 'arsenic', 'arsenic'),
#  'artlcle': ('article', '', '', ''),
#  'artlcles': ('articles', 'articles', 'articles', 'articles'),
#  'artlcular': ('articular', 'articular', 'articular', 'articular'),
#  'artlculate': ('articulate', 'articulate', 'articulate', 'articulate'),
#  'artlculated': ('articulated', 'articulated', 'articulated', 'articulated'),
#  'aslan': ('asian', '', '', ''),
#  'assembllng': ('assembling', 'assembling', 'assembling', 'assembling'),
#  'assessmnts': ('assessments', 'assessments', 'assessments', 'assessments'),
#  'asslglwaats': ('assigiwaats', '', '', ''),
#  'asslgned': ('assigned', 'assigned', 'assigned', 'assigned'),
#  'asslgnlng': ('assigning', '', '', ''),
#  'asslgnments': ('assignments', 'assignments', 'assignments', 'assignments'),
#  'asslstance': ('assistance', 'assistance', 'assistance', 'assistance'),
#  'asslsted': ('assisted', 'assisted', 'assisted', 'assisted'),
#  'asslstlng': ('assisting', '', '', ''),
#  'assoclatlons': ('associations', '', '', ''),
#  'asuptoidate': ('asuptodate', 'asuptodate', 'asuptodate', 'asuptodate'),
#  'athcked': ('attacked', '', '', ''),
#  'atlantlc': ('atlantic', '', '', ''),
#  'atlng': ('ating', 'ating', 'ating', 'ating'),
#  'attalnment': ('attainment', 'attainment', 'attainment', 'attainment'),
#  'attemptlng': ('attempting', 'attempting', 'attempting', 'attempting'),
#  'attentlon': ('attention', 'attention', 'attention', 'attention'),
#  'attrlbuted': ('attributed', 'attributed', 'attributed', 'attributed'),
#  'audltlng': ('auditing', '', '', ''),
#  'australlas': ('australias', '', '', ''),
#  'authorlzatlons': ('authorizations', '', '', ''),
#  'authorlzed': ('authorized', 'authorized', 'authorized', 'authorized'),
#  'authorlzes': ('authorizes', 'authorizes', 'authorizes', 'authorizes'),
#  'automatlcally': ('automatically',
#   'automatically',
#   'automatically',
#   'automatically'),
#  'avaliablllty': ('availability', '', '', ''),
#  'avallable': ('technology', '', '', ''),
#  'avallablllty': ('availability', '', '', ''),
#  'backlng': ('backing', 'backing', 'backing', 'backing'),
#  'bacomlng': ('bacoming', 'bacoming', 'bacoming', 'bacoming'),
#  'bagln': ('bagin', 'bagin', 'bagin', 'bagin'),
#  'baldrlge': ('baldrige', '', '', ''),
#  'ballotlng': ('balloting', 'balloting', 'balloting', 'balloting'),
#  'bannlng': ('banning', 'banning', 'banning', 'banning'),
#  'bargalnlng': ('bargaining', '', '', ''),
#  'barrlng': ('barring', '', '', ''),
#  'baslc': ('basic', 'basic', 'basic', 'basic'),
#  'becomlng': ('becoming', 'becoming', 'becoming', 'becoming'),
#  'begln': ('begin', 'begin', 'begin', 'begin'),
#  'beglnnlng': ('beginning', '', '', ''),
#  'beglns': ('begins', 'begins', 'begins', 'begins'),
#  'behlnd': ('behind', 'behind', 'behind', 'behind'),
#  'belng': ('being', 'being', 'being', 'being'),
#  'beneflclal': ('beneficial', '', '', ''),
#  'beneflclary': ('beneficiary', '', '', ''),
#  'beneflts': ('benefits', 'benefits', 'benefits', 'benefits'),
#  'benzothlazolesul': ('benzothazolesul',
#   'benzothazolesul',
#   'benzothazolesul',
#   'benzothazolesul'),
#  'bfgoodrlch': ('bfgoodrich', '', '', ''),
#  'blamedlcal': ('biomedical', '', '', ''),
#  'bllaterally': ('bilaterally', 'bilaterally', 'bilaterally', 'bilaterally'),
#  'bllllon': ('billion', '', '', ''),
#  'blndlng': ('binding', '', '', ''),
#  'blologlcal': ('biological', '', '', ''),
#  'blomonltorlng': ('biomonitoring', '', '', ''),
#  'bloresearch': ('bioresearch', '', '', ''),
#  'blotechnology': ('biotechnology', '', '', ''),
#  'blphenyls': ('biphenyls', '', '', ''),
#  'blrthlng': ('birthing', '', '', ''),
#  'bonsaipassed': ('housepassed', '', '', ''),
#  'bonsaisenate': ('housesenate', '', '', ''),
#  'borrowlng': ('borrowing', 'borrowing', 'borrowing', 'borrowing'),
#  'brazll': ('brazil', '', '', ''),
#  'brazlllan': ('brazilian', '', '', ''),
#  'brazlls': ('brazils', '', '', ''),
#  'brlef': ('brief', 'brief', 'brief', 'brief'),
#  'brleflng': ('briefing', '', '', ''),
#  'brleflngs': ('briefings', '', '', ''),
#  'brlefs': ('briefs', 'briefs', 'briefs', 'briefs'),
#  'brlng': ('bring', 'bring', 'bring', 'bring'),
#  'broadenlng': ('broadening', 'broadening', 'broadening', 'broadening'),
#  'broadibased': ('broadbased', 'broadbased', 'broadbased', 'broadbased'),
#  'broadlng': ('broading', 'broading', 'broading', 'broading'),
#  'budgetisettlng': ('budgetsetting', '', '', ''),
#  'bulldlng': ('building', '', '', ''),
#  'bulldlngs': ('buildings', '', '', ''),
#  'bulletln': ('bulletin', 'bulletin', 'bulletin', 'bulletin'),
#  'burnlng': ('burning', '', '', ''),
#  'buslness': ('business', '', '', ''),
#  'callfornlay': ('california', '', '', ''),
#  'calllng': ('calling', 'calling', 'calling', 'calling'),
#  'cambrldge': ('cambridge', '', '', ''),
#  'cancellatlon': ('cancellation',
#   'cancellation',
#   'cancellation',
#   'cancellation'),
#  'candldates': ('candidates', 'candidates', 'candidates', 'candidates'),
#  'caohgprty': ('chohgprt', '', '', ''),
#  'capabllltles': ('capabilities', '', '', ''),
#  'capablllty': ('capability', '', '', ''),
#  'capplng': ('capping', '', '', ''),
#  'carclnogenlclty': ('carcinogenicity', '', '', ''),
#  'carclnogens': ('carcinogens', 'carcinogens', 'carcinogens', 'carcinogens'),
#  'carrylng': ('carrying', 'carrying', 'carrying', 'carrying'),
#  'castlgated': ('castigated', 'castigated', 'castigated', 'castigated'),
#  'castlng': ('casting', 'casting', 'casting', 'casting'),
#  'categorlcal': ('categorical', 'categorical', 'categorical', 'categorical'),
#  'categorles': ('categories', 'categories', 'categories', 'categories'),
#  'categorlzatlon': ('categorization', '', '', ''),
#  'certalnly': ('certainly', 'certainly', 'certainly', 'certainly'),
#  'certlflcatlon': ('certification', '', '', ''),
#  'challenglng': ('challenging', 'challenging', 'challenging', 'challenging'),
#  'changlng': ('changing', 'changing', 'changing', 'changing'),
#  'characterlstlc': ('characteristic', '', '', ''),
#  'characterlze': ('characterize', '', '', ''),
#  'checkllst': ('checklist', 'checklist', 'checklist', 'checklist'),
#  'chlefs': ('chiefs', 'chiefs', 'chiefs', 'chiefs'),
#  'chlorlde': ('chloride', 'chloride', 'chloride', 'chloride'),
#  'chlorlne': ('chlorine', 'chlorine', 'chlorine', 'chlorine'),
#  'chlorobnzenes': ('chlorobenzenes', '', '', ''),
#  'chlpplng': ('chipping', '', '', ''),
#  'chmlcal': ('chemical', 'chmical', 'chmical', 'chmical'),
#  'chromlum': ('chromium', 'chromium', 'chromium', 'chromium'),
#  'chronlc': ('chronic', 'chronic', 'chronic', 'chronic'),
#  'cicsy': ('cics', '', '', ''),
#  'clalm': ('claim', 'calm', 'calm', 'calm'),
#  'clalms': ('claims', 'claims', 'claims', 'claims'),
#  'clalr': ('clair', '', '', ''),
#  'clarlfy': ('clarify', 'clarify', 'clarify', 'clarify'),
#  'clarlfylng': ('clarifying', '', '', ''),
#  'cleanlng': ('cleaning', 'cleaning', 'cleaning', 'cleaning'),
#  'clearlng': ('clearing', 'clearing', 'clearing', 'clearing'),
#  'clnclnnatl': ('cincinnati', '', '', ''),
#  'closediloop': ('closedloop', 'closedloop', 'closedloop', 'closedloop'),
#  'clothlng': ('clothing', '', '', ''),
#  'clrculatlng': ('circulating', '', '', ''),
#  'clrculatlon': ('circulation', '', '', ''),
#  'clrcumstances': ('circumstances',
#   'circumstances',
#   'circumstances',
#   'circumstances'),
#  'cltlng': ('citing', '', '', ''),
#  'cltlzen': ('citizen', '', '', ''),
#  'cmngress': ('congress', '', '', ''),
#  'cncealed': ('concealed', 'concealed', 'concealed', 'concealed'),
#  'cnemacology': ('chemecology', '', '', ''),
#  'coalltlon': ('coalition', '', '', ''),
#  'coalltlons': ('coalitions', '', '', ''),
#  'coasldarlng': ('coasidarlng', 'coasidarlng', 'coasidarlng', 'coasidarlng'),
#  'codlflcatlon': ('codification', '', '', ''),
#  'codlfylng': ('codifying', '', '', ''),
#  'codlng': ('coding', 'coding', 'coding', 'coding'),
#  'collectlve': ('collective', 'collective', 'collective', 'collective'),
#  'collectlvely': ('collectively',
#   'collectively',
#   'collectively',
#   'collectively'),
#  'colllns': ('collins', '', '', ''),
#  'colmnlsslon': ('coimnission', '', '', ''),
#  'comblnatlon': ('combination', '', '', ''),
#  'comlng': ('coming', 'coming', 'coming', 'coming'),
#  'comltteerecommended': ('comitteerecommended', '', '', ''),
#  'commerclal': ('commercial', 'commercial', 'commercial', 'commercial'),
#  'comml': ('commit', '', '', ''),
#  'commlsslned': ('commissioned', '', '', ''),
#  'commlsslon': ('commission', '', '', ''),
#  'commlssloner': ('commissioner', '', '', ''),
#  'commlsslons': ('commissions', '', '', ''),
#  'commltments': ('commitments', 'commitments', 'commitments', 'commitments'),
#  'commlttaa': ('committaa', '', '', ''),
#  'commltteeboard': ('committeeboard', '', '', ''),
#  'communlcate': ('communicate', '', '', ''),
#  'communlcated': ('communicated',
#   'communicated',
#   'communicated',
#   'communicated'),
#  'communlcatlng': ('communicating', '', '', ''),
#  'communlcatlon': ('communication', '', '', ''),
#  'communlcator': ('communicator',
#   'communicator',
#   'communicator',
#   'communicator'),
#  'communltles': ('communities', '', '', ''),
#  'comnunlcata': ('comnunicata', 'comnunicata', 'comnunicata', 'comnunicata'),
#  'comnunlcatlon': ('comnunication', '', '', ''),
#  'companyy': ('company', 'companys', 'companys', 'companys'),
#  'compenltors': ('competitors', '', '', ''),
#  'compensatlon': ('compensation',
#   'compensation',
#   'compensation',
#   'compensation'),
#  'compenstlon': ('compensation', '', '', ''),
#  'competltlve': ('competitive', '', '', ''),
#  'competltlveness': ('competitiveness', '', '', ''),
#  'compllcated': ('complicated', 'complicated', 'complicated', 'complicated'),
#  'compllcatlon': ('complication', '', '', ''),
#  'compllmentary': ('complimentary',
#   'complimentary',
#   'complimentary',
#   'complimentary'),
#  'compny': ('company', 'company', 'company', 'company'),
#  'comprehenslve': ('comprehensive',
#   'comprehensive',
#   'comprehensive',
#   'comprehensive'),
#  'comprlse': ('comprise', 'comprise', 'comprise', 'comprise'),
#  'comprlsed': ('comprised', 'comprised', 'comprised', 'comprised'),
#  'compromlses': ('compromises', 'compromises', 'compromises', 'compromises'),
#  'comptlng': ('competing', '', '', ''),
#  'computerlzed': ('computerized',
#   'computerized',
#   'computerized',
#   'computerized'),
#  'concentratlons': ('concentrations',
#   'concentrations',
#   'concentrations',
#   'concentrations'),
#  'concernlng': ('concerning', 'concerning', 'concerning', 'concerning'),
#  'concluslon': ('conclusion', 'conclusion', 'conclusion', 'conclusion'),
#  'condltlons': ('conditions', '', '', ''),
#  'conductlng': ('conducting', 'conducting', 'conducting', 'conducting'),
#  'conervatlve': ('conservative', '', '', ''),
#  'confldantlallty': ('confidantiality', '', '', ''),
#  'confldentlal': ('confidential', '', '', ''),
#  'confldentlallty': ('confidentiality', '', '', ''),
#  'congreslonal': ('congressional', '', '', ''),
#  'congresslonal': ('congressional',
#   'congressional',
#   'congressional',
#   'congressional'),
#  'congrsslonal': ('congressional', '', '', ''),
#  'conservatlon': ('conservation',
#   'conservation',
#   'conservation',
#   'conservation'),
#  'conservatlve': ('conservative',
#   'conservative',
#   'conservative',
#   'conservative'),
#  'conslderable': ('considerable',
#   'considerable',
#   'considerable',
#   'considerable'),
#  'conslderatlon': ('consideration', '', '', ''),
#  'conslderatlons': ('considerations', '', '', ''),
#  'conslderd': ('considered', '', '', ''),
#  'consldered': ('considered', 'considered', 'considered', 'considered'),
#  'conslderlng': ('considering', '', '', ''),
#  'conslstency': ('consistency', 'consistency', 'consistency', 'consistency'),
#  'conslstently': ('consistently',
#   'consistently',
#   'consistently',
#   'consistently'),
#  'conslstlng': ('consisting', '', '', ''),
#  'consolldatlng': ('consolidating', '', '', ''),
#  'consolldatlon': ('consolidation', '', '', ''),
#  'constltuent': ('constituent', 'constituent', 'constituent', 'constituent'),
#  'constltuents': ('constituents',
#   'constituents',
#   'constituents',
#   'constituents'),
#  'constltute': ('constitute', 'constitute', 'constitute', 'constitute'),
#  'constructlon': ('construction',
#   'construction',
#   'construction',
#   'construction'),
#  'constructlve': ('alternatives',
#   'constructive',
#   'constructive',
#   'constructive'),
#  'consultatlon': ('consultation',
#   'consultation',
#   'consultation',
#   'consultation'),
#  'consultatlons': ('consultations',
#   'consultations',
#   'consultations',
#   'consultations'),
#  'consultlng': ('consulting', 'consulting', 'consulting', 'consulting'),
#  'contalned': ('contained', 'contained', 'contained', 'contained'),
#  'contalner': ('container', '', '', ''),
#  'contalnlng': ('containing', '', '', ''),
#  'contalnment': ('containment', '', '', ''),
#  'contalns': ('contains', 'contains', 'contains', 'contains'),
#  'contamlnant': ('contaminant', 'contaminant', 'contaminant', 'contaminant'),
#  'contamlnants': ('contaminants',
#   'contaminants',
#   'contaminants',
#   'contaminants'),
#  'contamlnatlon': ('contamination', '', '', ''),
#  'contlngency': ('contingency', 'contingency', 'contingency', 'contingency'),
#  'contlnuatlon': ('continuation', '', '', ''),
#  'contlnud': ('continued', '', '', ''),
#  'contlnulng': ('continuing', '', '', ''),
#  'contractlng': ('contracting', 'contracting', 'contracting', 'contracting'),
#  'contrlbuted': ('contributed', 'contributed', 'contributed', 'contributed'),
#  'contrlbutlng': ('contributing', '', '', ''),
#  'contrlbutlon': ('contribution', '', '', ''),
#  'contrlbutlons': ('contributions', '', '', ''),
#  'contrlbutors': ('contributors',
#   'contributors',
#   'contributors',
#   'contributors'),
#  'controverslal': ('controversial',
#   'controversial',
#   'controversial',
#   'controversial'),
#  'convenlent': ('convenient', 'convenient', 'convenient', 'convenient'),
#  'conventlon': ('convention', 'convention', 'convention', 'convention'),
#  'conventlons': ('conventions', 'conventions', 'conventions', 'conventions'),
#  'cooperatlve': ('cooperative', 'cooperative', 'cooperative', 'cooperative'),
#  'coordlnate': ('coordinate', 'coordinate', 'coordinate', 'coordinate'),
#  'coordlnates': ('coordinates', 'coordinates', 'coordinates', 'coordinates'),
#  'coordlnatlng': ('coordinating', '', '', ''),
#  'coordlnatlon': ('coordination', '', '', ''),
#  'coordlnator': ('coordinator', 'coordinator', 'coordinator', 'coordinator'),
#  'coranerclal': ('coranercial', 'coranercial', 'coranercial', 'coranercial'),
#  'cosmetlc': ('cosmetic', 'cosmetic', 'cosmetic', 'cosmetic'),
#  'costeffectlve': ('costeffective',
#   'costeffective',
#   'costeffective',
#   'costeffective'),
#  'costibenflt': ('costbenfit', '', '', ''),
#  'costieffectlve': ('costeffective', '', '', ''),
#  'costioverrun': ('costoverrun', 'costoverrun', 'costoverrun', 'costoverrun'),
#  'coverlng': ('covering', 'covering', 'covering', 'covering'),
#  'cozporatlon': ('corporation', '', '', ''),
#  'cozporatlons': ('corporations', '', '', ''),
#  'creatlng': ('creating', 'creating', 'creating', 'creating'),
#  'credlblllty': ('credibility', '', '', ''),
#  'crlmlnal': ('penalties', '', '', ''),
#  'crlsp': ('crisp', 'crisp', 'crisp', 'crisp'),
#  'crlterla': ('criteria', '', '', ''),
#  'crltlcal': ('critical', '', '', ''),
#  'crltlclsm': ('criticism', '', '', ''),
#  'crltlclzed': ('criticized', '', '', ''),
#  'crltlcs': ('critics', '', '', ''),
#  'crossdzuttlng': ('crosscutting', '', '', ''),
#  'crossexamnatlon': ('crossexamination', '', '', ''),
#  'crystalllzed': ('crystallized',
#   'crystallized',
#   'crystallized',
#   'crystallized'),
#  'ctlon': ('action', 'ction', 'ction', 'ction'),
#  'ctronc': ('service', '', '', ''),
#  'curlng': ('curing', 'curing', 'curing', 'curing'),
#  'cuttlng': ('cutting', '', '', ''),
#  'cy': ('was', 'by', 'by', 'by'),
#  'damaglng': ('damaging', 'damaging', 'damaging', 'damaging'),
#  'davld': ('david', '', '', ''),
#  'davls': ('davis', '', '', ''),
#  'dbjeclves': ('objectives', '', '', ''),
#  'dbjectlve': ('objective', '', '', ''),
#  'dbryan': ('obryan', '', '', ''),
#  'dccldental': ('occidental', '', '', ''),
#  'dccupatlonal': ('occupational', '', '', ''),
#  'dctylphenol': ('octylphenol', '', '', ''),
#  'deadllnes': ('deadlines', 'deadlines', 'deadlines', 'deadlines'),
#  'declaratlon': ('declaration', '', '', ''),
#  'decllne': ('decline', 'decline', 'decline', 'decline'),
#  'decllnlng': ('declining', '', '', ''),
#  'declslon': ('decision', '', '', ''),
#  'deconclnl': ('deconcini', '', '', ''),
#  'dedlcated': ('dedicated', 'dedicated', 'dedicated', 'dedicated'),
#  'deductlblllty': ('deductibility', '', '', ''),
#  'deductlon': ('deduction', 'deduction', 'deduction', 'deduction'),
#  'deflclt': ('deficit', '', '', ''),
#  'deflclts': ('deficits', '', '', ''),
#  'deflnlng': ('defining', '', '', ''),
#  'deflnltlon': ('definition', '', '', ''),
#  'deflnltlonal': ('definitional', '', '', ''),
#  'deflnltlons': ('definitions', '', '', ''),
#  'deflnltlve': ('definitive', '', '', ''),
#  'delegatlon': ('delegation', 'delegation', 'delegation', 'delegation'),
#  'dellberatlons': ('deliberations', '', '', ''),
#  'dellvered': ('delivered', 'delivered', 'delivered', 'delivered'),
#  'demonstratlon': ('demonstration',
#   'demonstration',
#   'demonstration',
#   'demonstration'),
#  'dentlfy': ('identify', '', '', ''),
#  'dependlng': ('depending', 'depending', 'depending', 'depending'),
#  'depreclatlon': ('depreciation', '', '', ''),
#  'deregulatlon': ('deregulation',
#   'deregulation',
#   'deregulation',
#   'deregulation'),
#  'derlvatlve': ('derivative', '', '', ''),
#  'descrlbe': ('describe', 'describe', 'describe', 'describe'),
#  'descrlbed': ('described', 'described', 'described', 'described'),
#  'deslgn': ('design', 'design', 'design', 'design'),
#  'deslgnated': ('designated', 'designated', 'designated', 'designated'),
#  'deslgnatlng': ('designating', '', '', ''),
#  'deslgnatlon': ('designation', '', '', ''),
#  'deslgned': ('designed', 'designed', 'designed', 'designed'),
#  'deslgnlng': ('designing', '', '', ''),
#  'deslrable': ('desirable', 'desirable', 'desirable', 'desirable'),
#  'detectlon': ('detection', 'detection', 'detection', 'detection'),
#  'deterloratlng': ('deteriorating', '', '', ''),
#  'deterloratlon': ('deterioration', '', '', ''),
#  'determlnatlon': ('determination', '', '', ''),
#  'determlned': ('determined', 'determined', 'determined', 'determined'),
#  'determlnlng': ('determining', '', '', ''),
#  'devaluatlon': ('devaluation', 'devaluation', 'devaluation', 'devaluation'),
#  'developlng': ('developing', 'developing', 'developing', 'developing'),
#  'distrlbutlon': ('distribution', '', '', ''),
#  'dlalkyl': ('dialkyl', 'dialkyl', 'dialkyl', 'dialkyl'),
#  'dlffer': ('differ', 'differ', 'differ', 'differ'),
#  'dlfference': ('difference', 'difference', 'difference', 'difference'),
#  'dlfferences': ('differences', 'differences', 'differences', 'differences'),
#  'dlfferent': ('different', 'different', 'different', 'different'),
#  'dlfferlng': ('differing', '', '', ''),
#  'dlfflcult': ('difficult', '', '', ''),
#  'dlfflcultles': ('difficulties', '', '', ''),
#  'dlfflculty': ('difficulty', '', '', ''),
#  'dlglycldyl': ('diglycidyl', '', '', ''),
#  'dlllgent': ('diligent', '', '', ''),
#  'dllver': ('oliver', '', '', ''),
#  'dlmlnlshlng': ('diminishing', '', '', ''),
#  'dlrect': ('direct', '', '', ''),
#  'dlrected': ('directed', 'directed', 'directed', 'directed'),
#  'dlrectlon': ('direction', '', '', ''),
#  'dlrectlve': ('directive', '', '', ''),
#  'dlrectly': ('directly', 'directly', 'directly', 'directly'),
#  'dlrector': ('director', '', '', ''),
#  'dlrectors': ('directors', 'directors', 'directors', 'directors'),
#  'dlsagreements': ('disagreements',
#   'disagreements',
#   'disagreements',
#   'disagreements'),
#  'dlsappolnted': ('disappointed', '', '', ''),
#  'dlsastrous': ('disastrous', 'disastrous', 'disastrous', 'disastrous'),
#  'dlsband': ('disband', 'disband', 'disband', 'disband'),
#  'dlsbandad': ('disbandad', 'disbandad', 'disbandad', 'disbandad'),
#  'dlschargers': ('dischargers', '', '', ''),
#  'dlscharges': ('discharges', 'discharges', 'discharges', 'discharges'),
#  'dlsclpllnes': ('disciplines', '', '', ''),
#  'dlscuss': ('discuss', 'discuss', 'discuss', 'discuss'),
#  'dlscussed': ('discussed', 'discussed', 'discussed', 'discussed'),
#  'dlscussl': ('discussi', '', '', ''),
#  'dlscusslng': ('discussing', '', '', ''),
#  'dlscusslon': ('discussion', '', '', ''),
#  'dlscusslons': ('discussions', '', '', ''),
#  'dlslncentlves': ('disincentives', '', '', ''),
#  'dlsplayed': ('displayed', 'displayed', 'displayed', 'displayed'),
#  'dlsposal': ('disposal', 'disposal', 'disposal', 'disposal'),
#  'dlsposed': ('disposed', 'disposed', 'disposed', 'disposed'),
#  'dlsruptlon': ('disruption', '', '', ''),
#  'dlssealnatlon': ('dlsseainatlon',
#   'dlsseainatlon',
#   'dlsseainatlon',
#   'dlsseainatlon'),
#  'dlssolved': ('dissolved', 'dissolved', 'dissolved', 'dissolved'),
#  'dlstlllates': ('distillates', '', '', ''),
#  'dlstlnctlon': ('distinction', '', '', ''),
#  'dlstractlons': ('distractions', '', '', ''),
#  'dlstrlbuted': ('distributed', '', '', ''),
#  'dlstrlbutlon': ('distribution', '', '', ''),
#  'dlstrlct': ('district', '', '', ''),
#  'dlsulflde': ('disulfide', '', '', ''),
#  'dltch': ('ditch', 'ditch', 'ditch', 'ditch'),
#  'dlverslty': ('diversity', '', '', ''),
#  'dlvldends': ('dividends', '', '', ''),
#  'dlvlslon': ('division', '', '', ''),
#  'dlvlslons': ('divisions', '', '', ''),
#  'dmnlbus': ('omnibus', '', '', ''),
#  'documentlng': ('documenting', 'documenting', 'documenting', 'documenting'),
#  'dolng': ('doing', 'doing', 'doing', 'doing'),
#  'domestlc': ('domestic', 'domestic', 'domestic', 'domestic'),
#  'doubllng': ('doubling', '', '', ''),
#  'dperatlons': ('operations', '', '', ''),
#  'drefflce': ('oreffice', '', '', ''),
#  'drganlzatlon': ('organization', '', '', ''),
#  'drganlzatlons': ('organizations', '', '', ''),
#  'drlglnal': ('original', '', '', ''),
#  'drlglnally': ('originally', '', '', ''),
#  'drln': ('orin', '', '', ''),
#  'drlnklng': ('drinking', '', '', ''),
#  'dshas': ('oshas', '', '', ''),
#  'dumplng': ('dumping', 'dumping', 'dumping', 'dumping'),
#  'dupllcatlve': ('duplicative', '', '', ''),
#  'durlng': ('during', 'during', 'during', 'during'),
#  'dustrlal': ('exposures', '', '', ''),
#  'dvocacy': ('advocacy', 'advocacy', 'advocacy', 'advocacy'),
#  'dwnstream': ('downstream', 'downstream', 'downstream', 'downstream'),
#  'dxld': ('oxide', '', '', ''),
#  'dxldant': ('oxidant', '', '', ''),
#  'earnlngs': ('earnings', 'earnings', 'earnings', 'earnings'),
#  'easlng': ('easing', '', '', ''),
#  'eatman': ('eastman', '', '', ''),
#  'economlc': ('economic', '', '', ''),
#  'economlcally': ('economically',
#   'economically',
#   'economically',
#   'economically'),
#  'economlctrade': ('economictrade',
#   'economictrade',
#   'economictrade',
#   'economictrade'),
#  'edltorlal': ('editorial', '', '', ''),
#  'educatlon': ('education', '', '', ''),
#  'educatlonal': ('educational', 'educational', 'educational', 'educational'),
#  'edwln': ('edwin', '', '', ''),
#  'effectlve': ('effective', 'effective', 'effective', 'effective'),
#  'effectlvely': ('effectively', 'effectively', 'effectively', 'effectively'),
#  'effectlveness': ('effectiveness',
#   'effectiveness',
#   'effectiveness',
#   'effectiveness'),
#  'efflclency': ('provisions', '', '', ''),
#  'efflclent': ('efficient', '', '', ''),
#  'efflclently': ('efficiently', '', '', ''),
#  'effrts': ('efforts', 'efforts', 'efforts', 'efforts'),
#  'electrlc': ('electric', 'electric', 'electric', 'electric'),
#  'electrlcal': ('electrical', 'electrical', 'electrical', 'electrical'),
#  'electrlclty': ('electricity', '', '', ''),
#  'eleld': ('field', '', '', ''),
#  'elght': ('eight', 'eight', 'eight', 'eight'),
#  'ellglble': ('eligible', '', '', ''),
#  'ellmlnated': ('eliminated', '', '', ''),
#  'ellmlnatln': ('elimination', '', '', ''),
#  'ellmlnatlng': ('eliminating', '', '', ''),
#  'ellmlnatlon': ('elimination', '', '', ''),
#  'elvestlture': ('divestiture', '', '', ''),
#  'embryotoxlc': ('embryotoxic', 'embryotoxic', 'embryotoxic', 'embryotoxic'),
#  'emergencles': ('emergencies', 'emergencies', 'emergencies', 'emergencies'),
#  'emerglng': ('emerging', 'emerging', 'emerging', 'emerging'),
#  'emlsslon': ('emission', '', '', ''),
#  'emlsslons': ('emissions', '', '', ''),
#  'emlsslonsdlscharge': ('emissionsdischarge', '', '', ''),
#  'emphasls': ('emphasis', 'emphasis', 'emphasis', 'emphasis'),
#  'emphaslze': ('emphasize', 'emphasize', 'emphasize', 'emphasize'),
#  'emphaslzed': ('emphasized', 'emphasized', 'emphasized', 'emphasized'),
#  'employeriselected': ('employerselected',
#   'employerselected',
#   'employerselected',
#   'employerselected'),
#  'encapsulatlng': ('encapsulating',
#   'encapsulating',
#   'encapsulating',
#   'encapsulating'),
#  'encompasslng': ('encompassing',
#   'encompassing',
#   'encompassing',
#   'encompassing'),
#  'encouraglng': ('encouraging', 'encouraging', 'encouraging', 'encouraging'),
#  'endlng': ('pending', 'ending', 'ending', 'ending'),
#  'endorslng': ('endorsing', 'endorsing', 'endorsing', 'endorsing'),
#  'energyiefflclency': ('energyefficiency', '', '', ''),
#  'englneerlng': ('engineering', '', '', ''),
#  'enqlneerlng': ('engineering', '', '', ''),
#  'enterlng': ('entering', 'entering', 'entering', 'entering'),
#  'enterprlse': ('enterprise', 'enterprise', 'enterprise', 'enterprise'),
#  'enthuslastlcally': ('enthusiastically', '', '', ''),
#  'entlng': ('final', '', '', ''),
#  'envlroni': ('environ', '', '', ''),
#  'envlronment': ('environment', 'environment', 'environment', 'environment'),
#  'envlronmentallst': ('environmentalist', '', '', ''),
#  'envlronmentallsts': ('environmentalists', '', '', ''),
#  'epldemlologlcal': ('epidemiological', '', '', ''),
#  'epldemlologlst': ('epidemiologist', '', '', ''),
#  'epldemlology': ('epidemiology', '', '', ''),
#  'equallzatlon': ('equalization', '', '', ''),
#  'equlpment': ('equipment', 'equipment', 'equipment', 'equipment'),
#  'equlvalent': ('equivalent', 'equivalent', 'equivalent', 'equivalent'),
#  'eridlng': ('erding', '', '', ''),
#  'erlef': ('brief', '', '', ''),
#  'erleflng': ('briefing', '', '', ''),
#  'ertlfled': ('ertified', '', '', ''),
#  'essentlal': ('essential', 'essential', 'essential', 'essential'),
#  'essentlally': ('essentially', 'essentially', 'essentially', 'essentially'),
#  'esslons': ('sessions', '', '', ''),
#  'establlsh': ('establish', 'establish', 'establish', 'establish'),
#  'establlshed': ('established', 'established', 'established', 'established'),
#  'establlshi': ('establish', '', '', ''),
#  'establlshlng': ('establishing', '', '', ''),
#  'establlshment': ('establishment',
#   'establishment',
#   'establishment',
#   'establishment'),
#  'establlshments': ('establishments',
#   'establishments',
#   'establishments',
#   'establishments'),
#  'estlmatlng': ('estimating', '', '', ''),
#  'evaluatlng': ('industrys', 'evaluating', 'evaluating', 'evaluating'),
#  'examlnatlon': ('examination', '', '', ''),
#  'examlner': ('examiner', '', '', ''),
#  'examlnlng': ('examining', '', '', ''),
#  'exceedlng': ('exceeding', 'exceeding', 'exceeding', 'exceeding'),
#  'exceptlon': ('exception', 'exception', 'exception', 'exception'),
#  'exceptlonally': ('exceptionally',
#   'exceptionally',
#   'exceptionally',
#   'exceptionally'),
#  'excltlng': ('exciting', '', '', ''),
#  'excluslon': ('exclusion', 'exclusion', 'exclusion', 'exclusion'),
#  'excluslvely': ('exclusively', 'exclusively', 'exclusively', 'exclusively'),
#  'executlve': ('executive', '', '', ''),
#  'exemptlon': ('exemption', 'exemption', 'exemption', 'exemption'),
#  'exemptlonlmport': ('exemptionimport', '', '', ''),
#  'exemptlons': ('exemptions', 'exemptions', 'exemptions', 'exemptions'),
#  'exhlblt': ('exhibit', '', '', ''),
#  'exhllt': ('exhibit', '', '', ''),
#  'exlst': ('exist', 'exist', 'exist', 'exist'),
#  'exlstlng': ('existing', '', '', ''),
#  'exlsts': ('exists', 'exists', 'exists', 'exists'),
#  'expandlng': ('expanding', 'expanding', 'expanding', 'expanding'),
#  'expanslon': ('expansion', 'expansion', 'expansion', 'expansion'),
#  'expendltures': ('expenditures',
#   'expenditures',
#   'expenditures',
#   'expenditures'),
#  'expenslve': ('expensive', 'expensive', 'expensive', 'expensive'),
#  'experlenced': ('experienced', 'experienced', 'experienced', 'experienced'),
#  'experlences': ('experiences', 'experiences', 'experiences', 'experiences'),
#  'experlments': ('experiments', '', '', ''),
#  'expertlse': ('expertise', 'expertise', 'expertise', 'expertise'),
#  'explalned': ('explained', 'explained', 'explained', 'explained'),
#  'extendlng': ('extending', 'extending', 'extending', 'extending'),
#  'extenslon': ('extension', 'extension', 'extension', 'extension'),
#  'extenslons': ('extensions', 'extensions', 'extensions', 'extensions'),
#  'extenslve': ('extensive', 'extensive', 'extensive', 'extensive'),
#  'facllltatlng': ('facilitating', '', '', ''),
#  'faclng': ('facing', 'facing', 'facing', 'facing'),
#  'facslmlle': ('facsimile', '', '', ''),
#  'falrly': ('fairly', 'fairly', 'fairly', 'fairly'),
#  'farreachlng': ('farreaching', 'farreaching', 'farreaching', 'farreaching'),
#  'fashlon': ('fashion', 'fashion', 'fashion', 'fashion'),
#  'fashlonlng': ('fashioning', '', '', ''),
#  'feaslblllty': ('feasibility', '', '', ''),
#  'feellng': ('feeling', 'feeling', 'feeling', 'feeling'),
#  'ffects': ('effects', 'effects', 'effects', 'effects'),
#  'flanlgan': ('flanigan', '', '', ''),
#  'flexlble': ('flexible', 'flexible', 'flexible', 'flexible'),
#  'flexlblllty': ('flexibility', '', '', ''),
#  'flfth': ('fifth', '', '', ''),
#  'flllng': ('filing', '', '', ''),
#  'flnal': ('final', 'final', 'final', 'final'),
#  'flnallzed': ('finalized', '', '', ''),
#  'flnanclal': ('financial', '', '', ''),
#  'flnanclng': ('financing', '', '', ''),
#  'flndlngs': ('findings', '', '', ''),
#  'flnlshlng': ('operations', '', '', ''),
#  'flourlsh': ('flourish', 'flourish', 'flourish', 'flourish'),
#  'flreflghters': ('firefighters', '', '', ''),
#  'flthlan': ('fithian', '', '', ''),
#  'fltzgerald': ('fitzgerald', '', '', ''),
#  'fluctuatlons': ('fluctuations',
#   'fluctuations',
#   'fluctuations',
#   'fluctuations'),
#  'fluld': ('fluid', 'fluid', 'fluid', 'fluid'),
#  'flxed': ('fixed', 'fixed', 'fixed', 'fixed'),
#  'flxlng': ('fixing', '', '', ''),
#  'focuslng': ('focusing', 'focusing', 'focusing', 'focusing'),
#  'followlng': ('following', 'following', 'following', 'following'),
#  'forelgners': ('foreigners', 'foreigners', 'foreigners', 'foreigners'),
#  'formatlon': ('formation', 'formation', 'formation', 'formation'),
#  'forthcomlng': ('forthcoming', 'forthcoming', 'forthcoming', 'forthcoming'),
#  'fortlgn': ('fortign', 'fortign', 'fortign', 'fortign'),
#  'fossll': ('fossil', '', '', ''),
#  'foundatlns': ('foundations', '', '', ''),
#  'foundatlons': ('foundations', 'foundations', 'foundations', 'foundations'),
#  'fouripolnt': ('fourpoint', '', '', ''),
#  'franclsco': ('francisco', '', '', ''),
#  'frelght': ('freight', '', '', ''),
#  'fueleurnlng': ('fuelburning', '', '', ''),
#  'fugltlve': ('fugitive', '', '', ''),
#  'fumlgant': ('fumigant', 'fumigant', 'fumigant', 'fumigant'),
#  'fumlng': ('fuming', 'fuming', 'fuming', 'fuming'),
#  'fundlng': ('funding', 'funding', 'funding', 'funding'),
#  'galnlng': ('gaining', '', '', ''),
#  'galns': ('gains', 'gains', 'gains', 'gains'),
#  'galthersburg': ('gaithersburg', '', '', ''),
#  'generallzatlon': ('generalization', '', '', ''),
#  'geraldlne': ('geraldine', '', '', ''),
#  'gestatlon': ('gestation', 'gestation', 'gestation', 'gestation'),
#  'gettlng': ('getting', 'getting', 'getting', 'getting'),
#  'glven': ('given', 'glen', 'glen', 'glen'),
#  'glycl': ('glycol', '', '', ''),
#  'golng': ('going', 'going', 'going', 'going'),
#  'governmentifunded': ('governmentfunded',
#   'governmentfunded',
#   'governmentfunded',
#   'governmentfunded'),
#  'grantlng': ('granting', 'granting', 'granting', 'granting'),
#  'growlng': ('growing', 'growing', 'growing', 'growing'),
#  'guldellnes': ('guidelines', '', '', ''),
#  'halfithat': ('halfthat', 'halfthat', 'halfthat', 'halfthat'),
#  'haltlng': ('halting', 'halting', 'halting', 'halting'),
#  'hamllton': ('hamilton', '', '', ''),
#  'handcufflng': ('handcuffing', 'handcuffing', 'handcuffing', 'handcuffing'),
#  'handllng': ('handling', 'handling', 'handling', 'handling'),
#  'hardipressed': ('hardpressed', 'hardpressed', 'hardpressed', 'hardpressed'),
#  'harmonlzatlon': ('harmonization', '', '', ''),
#  'harnlngs': ('warnings', '', '', ''),
#  'hartkeurke': ('hartkeburke', '', '', ''),
#  'havlng': ('reason', 'having', 'having', 'having'),
#  'hazrd': ('hazard', '', '', ''),
#  'headllnes': ('headlines', 'headlines', 'headlines', 'headlines'),
#  'healthibased': ('healthbased', 'healthbased', 'healthbased', 'healthbased'),
#  'healthirelated': ('healthrelated',
#   'healthrelated',
#   'healthrelated',
#   'healthrelated'),
#  'hearlng': ('hearings', 'hearing', 'hearing', 'hearing'),
#  'hithln': ('within', '', '', ''),
#  'hlgh': ('high', 'high', 'high', 'high'),
#  'hlgher': ('higher', 'higher', 'higher', 'higher'),
#  'hlghestiranklng': ('highestranking', '', '', ''),
#  'hlghllghted': ('highlighted', '', '', ''),
#  'hlghly': ('highly', 'highly', 'highly', 'highly'),
#  'hlghway': ('highway', 'highway', 'highway', 'highway'),
#  'hllton': ('hilton', '', '', ''),
#  'hlnge': ('hinge', 'hinge', 'hinge', 'hinge'),
#  'hlrlng': ('hiring', '', '', ''),
#  'hlsham': ('hisham', '', '', ''),
#  'hlstorlcal': ('historical', '', '', ''),
#  'hlstory': ('history', 'history', 'history', 'history'),
#  'hlth': ('with', '', '', ''),
#  'hlthln': ('within', '', '', ''),
#  'holdlng': ('holding', 'holding', 'holding', 'holding'),
#  'honorlng': ('honoring', 'honoring', 'honoring', 'honoring'),
#  'horlzonal': ('horizontal', '', '', ''),
#  'hs': ('has', 'has', 'has', 'has'),
#  'hypothesls': ('hypothesis', 'hypothesis', 'hypothesis', 'hypothesis'),
#  'identlflcatlon': ('identification', '', '', ''),
#  'identlfy': ('identify', '', '', ''),
#  'immedlate': ('immediate', '', '', ''),
#  'impalrment': ('impairment', '', '', ''),
#  'implementatlon': ('implementation', '', '', ''),
#  'implementlng': ('implementing', '', '', ''),
#  'impmrts': ('imports', 'imports', 'imports', 'imports'),
#  'imposltlln': ('imposition', '', '', ''),
#  'incentlve': ('incentive', 'incentive', 'incentive', 'incentive'),
#  'includlng': ('including', '', '', ''),
#  'indemnlfy': ('indemnify', '', '', ''),
#  'indlcated': ('indicated', '', '', ''),
#  'indlvldual': ('individual', '', '', ''),
#  'industryisponsored': ('industrysponsored', '', '', ''),
#  'inflatlonry': ('inflationary', '', '', ''),
#  'informatlon': ('information', '', '', ''),
#  'inhalatlon': ('inhalation', '', '', ''),
#  'injurles': ('injuries', '', '', ''),
#  'inltlated': ('initiated', '', '', ''),
#  'innovatlve': ('innovative', '', '', ''),
#  'inslght': ('insight', 'insight', 'insight', 'insight'),
#  'intrnatlonal': ('international', '', '', ''),
#  'introductlon': ('introduction', '', '', ''),
#  'invltatlon': ('invitation', '', '', ''),
#  'iranl': ('irani', '', '', ''),
#  'jeffrson': ('jefferson', '', '', ''),
#  'jenklns': ('jenkins', '', '', ''),
#  'jolnt': ('joint', 'joint', 'joint', 'joint'),
#  'judlclal': ('judicial', '', '', ''),
#  'judlclary': ('judiciary', '', '', ''),
#  'jurlsdlctlon': ('jurisdiction', '', '', ''),
#  'jurlsdlctlons': ('jurisdictions', '', '', ''),
#  'justlflcatlons': ('justifications', '', '', ''),
#  'justlfy': ('justify', 'justify', 'justify', 'justify'),
#  'kelth': ('keith', '', '', ''),
#  'klll': ('kill', 'kill', 'kill', 'kill'),
#  'klnds': ('kinds', 'kinds', 'kinds', 'kinds'),
#  'klngs': ('kings', '', '', ''),
#  'klrkpatrlck': ('kirkpatrick', '', '', ''),
#  'knlfe': ('knife', 'knife', 'knife', 'knife'),
#  'labellng': ('labeling', 'labeling', 'labeling', 'labeling'),
#  'laglslatlva': ('lagislativa', '', '', ''),
#  'landflll': ('landfill', 'landfill', 'landfill', 'landfill'),
#  'landfllls': ('landfills', 'landfills', 'landfills', 'landfills'),
#  'lapleaentatlon': ('iapleaentation', '', '', ''),
#  'latlv': ('lative', '', '', ''),
#  'lboratorles': ('laboratories', '', '', ''),
#  'lctober': ('october', 'october', 'october', 'october'),
#  'leachlng': ('leaching', '', '', ''),
#  'leaderhlp': ('leadership', '', '', ''),
#  'leadershlp': ('leadership', 'leadership', 'leadership', 'leadership'),
#  'leglslatlon': ('legislation', 'legislatlon', 'legislatlon', 'legislatlon'),
#  'leglslatlve': ('legislative', '', '', ''),
#  'leglslators': ('legislators', 'legislators', 'legislators', 'legislators'),
#  'leglslature': ('legislature', 'legislature', 'legislature', 'legislature'),
#  'legltlmate': ('legitimate', '', '', ''),
#  'lendlng': ('lending', 'lending', 'lending', 'lending'),
#  'leveraglng': ('leveraging', 'leveraging', 'leveraging', 'leveraging'),
#  'lfled': ('ified', '', '', ''),
#  'lhcentlve': ('incentive', '', '', ''),
#  'llable': ('liable', 'liable', 'liable', 'liable'),
#  'llablllty': ('liability', '', '', ''),
#  'llbrary': ('library', 'library', 'library', 'library'),
#  'lled': ('trade', 'led', 'led', 'led'),
#  'llght': ('light', 'light', 'light', 'light'),
#  'llkellhood': ('likelihood', '', '', ''),
#  'llkely': ('likely', 'likely', 'likely', 'likely'),
#  'llliconcelved': ('illconceived', '', '', ''),
#  'llluslon': ('illusion', '', '', ''),
#  'llmltatlon': ('limitation', '', '', ''),
#  'llmltatlons': ('limitations', '', '', ''),
#  'llmlted': ('limited', '', '', ''),
#  'llnes': ('lines', 'lines', 'lines', 'lines'),
#  'llquld': ('liquid', '', '', ''),
#  'llst': ('list', '', '', ''),
#  'llsted': ('listed', 'listed', 'listed', 'listed'),
#  'llterture': ('literature', '', '', ''),
#  'lltlgate': ('litigate', '', '', ''),
#  'lltlgatlon': ('litigation', '', '', ''),
#  'llttle': ('little', 'little', 'little', 'little'),
#  'llxon': ('nixon', '', '', ''),
#  'lngredlent': ('ingredient', '', '', ''),
#  'lngredlents': ('ingredients', '', '', ''),
#  'lngton': ('ington', 'ington', 'ington', 'ington'),
#  'lobbylng': ('lobbying', 'lobbying', 'lobbying', 'lobbying'),
#  'lobbylst': ('lobbyist', 'lobbyist', 'lobbyist', 'lobbyist'),
#  'locallzed': ('localized', 'localized', 'localized', 'localized'),
#  'loglcal': ('logical', 'logical', 'logical', 'logical'),
#  'longiterm': ('longterm', 'longterm', 'longterm', 'longterm'),
#  'lorporatlon': ('corporation', '', '', ''),
#  'lslon': ('issues', '', '', ''),
#  'lssuefocus': ('issuefocus', 'issuefocus', 'issuefocus', 'issuefocus'),
#  'lstrator': ('istrator', 'istrator', 'istrator', 'istrator'),
#  'ltems': ('items', 'lems', 'lems', 'lems'),
#  'luvplementatlon': ('implementation', '', '', ''),
#  'majorlty': ('majority', 'majority', 'majority', 'majority'),
#  'maklng': ('making', 'making', 'making', 'making'),
#  'malnly': ('mainly', 'mainly', 'mainly', 'mainly'),
#  'malntaln': ('maintain', '', '', ''),
#  'malntalned': ('maintained', '', '', ''),
#  'malntenance': ('maintenance', 'maintenance', 'maintenance', 'maintenance'),
#  'managlng': ('managing', 'managing', 'managing', 'managing'),
#  'maneuverlng': ('maneuvering', 'maneuvering', 'maneuvering', 'maneuvering'),
#  'manlfested': ('manifested', 'manifested', 'manifested', 'manifested'),
#  'manufacturlng': ('manufacturing',
#   'manufacturing',
#   'manufacturing',
#   'manufacturing'),
#  'margln': ('margin', 'margin', 'margin', 'margin'),
#  'marketlng': ('marketing', 'marketing', 'marketing', 'marketing'),
#  'marklng': ('marking', 'marking', 'marking', 'marking'),
#  'marltlme': ('maritime', '', '', ''),
#  'massenglll': ('massengill', '', '', ''),
#  'materlal': ('material', 'material', 'material', 'material'),
#  'matrlx': ('matrix', 'matrix', 'matrix', 'matrix'),
#  'maxlmlze': ('maximize', '', '', ''),
#  'maxlmum': ('judicial', 'maximum', 'maximum', 'maximum'),
#  'mba': ('mda', '', '', ''),
#  'meanlng': ('meaning', 'meaning', 'meaning', 'meaning'),
#  'meanlngful': ('meaningful', 'meaningful', 'meaningful', 'meaningful'),
#  'meanwhlle': ('meanwhile', '', '', ''),
#  'mechanlsm': ('mechanism', 'mechanism', 'mechanism', 'mechanism'),
#  'mechanlsms': ('mechanisms', 'mechanisms', 'mechanisms', 'mechanisms'),
#  'medlclne': ('medicine', '', '', ''),
#  'meetlng': ('meeting', 'meeting', 'meeting', 'meeting'),
#  'meetlns': ('meetings', '', '', ''),
#  'meetng': ('meeting', '', '', ''),
#  'membershlp': ('membership', 'membership', 'membership', 'membership'),
#  'membr': ('member', 'member', 'member', 'member'),
#  'memorandumiof': ('memorandumof', '', '', ''),
#  'merlchem': ('merichem', '', '', ''),
#  'methodologles': ('methodologies',
#   'methodologies',
#   'methodologies',
#   'methodologies'),
#  'methylenedlanlllne': ('methylenedianiline', '', '', ''),
#  'mlchlgan': ('illinois', '', '', ''),
#  'mlcronucleus': ('micronucleus',
#   'micronucleus',
#   'micronucleus',
#   'micronucleus'),
#  'mldiseptember': ('midseptember', '', '', ''),
#  'mldland': ('midland', '', '', ''),
#  'mlght': ('might', 'might', 'might', 'might'),
#  'mlgratlon': ('migration', '', '', ''),
#  'mllestone': ('milestone', 'milestone', 'milestone', 'milestone'),
#  'mllllans': ('millions', '', '', ''),
#  'mllllon': ('million', '', '', ''),
#  'mlnlmlzatlon': ('minimization', '', '', ''),
#  'mlnlmlze': ('minimize', '', '', ''),
#  'mlnlsters': ('ministers', '', '', ''),
#  'mlnnesota': ('minnesota', '', '', ''),
#  'mlnor': ('minor', 'minor', 'minor', 'minor'),
#  'mlnorlty': ('minority', '', '', ''),
#  'mlscellaneous': ('miscellaneous',
#   'miscellaneous',
#   'miscellaneous',
#   'miscellaneous'),
#  'mlsslon': ('mission', '', '', ''),
#  'mlxed': ('mixed', '', '', ''),
#  'mlxtures': ('mixtures', 'mixtures', 'mixtures', 'mixtures'),
#  'mmedlate': ('immediate', '', '', ''),
#  'mmedlately': ('immediately', '', '', ''),
#  'mnths': ('months', 'months', 'months', 'months'),
#  'moblllzed': ('mobilized', '', '', ''),
#  'modellng': ('modeling', 'modeling', 'modeling', 'modeling'),
#  'modlflcatlon': ('modification', '', '', ''),
#  'modlflcatlons': ('modifications', '', '', ''),
#  'modlfled': ('modified', '', '', ''),
#  'monltored': ('monitored', 'monitored', 'monitored', 'monitored'),
#  'monltors': ('monitors', 'monitors', 'monitors', 'monitors'),
#  'montanarl': ('montanari', '', '', ''),
#  'mornlng': ('morning', 'morning', 'morning', 'morning'),
#  'movlng': ('rapidly', 'moving', 'moving', 'moving'),
#  'mp': ('imp', 'mr', 'mr', 'mr'),
#  'mplantatlon': ('implantation', '', '', ''),
#  'mple': ('imple', 'ample', 'ample', 'ample'),
#  'mplement': ('implement', 'plement', 'plement', 'plement'),
#  'mplementatlon': ('implementation', '', '', ''),
#  'mplemented': ('implemented', 'implemented', 'implemented', 'implemented'),
#  'mplementng': ('californias', '', '', ''),
#  'mpllcatlons': ('implications', '', '', ''),
#  'mplled': ('implied', '', '', ''),
#  'mply': ('imple', 'amply', 'amply', 'amply'),
#  'mportant': ('important', 'portant', 'portant', 'portant'),
#  'mported': ('imported', 'imported', 'imported', 'imported'),
#  'mposltlon': ('imposition', '', '', ''),
#  'mpresslon': ('impression', '', '', ''),
#  'mproved': ('improved', 'proved', 'proved', 'proved'),
#  'mprovements': ('improvements',
#   'improvements',
#   'improvements',
#   'improvements'),
#  'mtters': ('matters', 'matters', 'matters', 'matters'),
#  'mu': ('un', 'mr', 'mr', 'mr'),
#  'multliphase': ('multiphase', 'multiphase', 'multiphase', 'multiphase'),
#  'multlnatlonals': ('multinationals', '', '', ''),
#  'multlple': ('multiple', 'multiple', 'multiple', 'multiple'),
#  'munlcatlons': ('munications', '', '', ''),
#  'munlclpaltype': ('municipaltype', '', '', ''),
#  'mutagenlclty': ('mutagenicity', '', '', ''),
#  'nagotlatlons': ('nagotiations', '', '', ''),
#  'napproprlate': ('inappropriate', '', '', ''),
#  'napproprlately': ('inappropriately', '', '', ''),
#  'natlns': ('nations', '', '', ''),
#  'natlonallzed': ('nationalized', '', '', ''),
#  'natlonwlde': ('nationwide', '', '', ''),
#  'nclude': ('include', 'include', 'include', 'include'),
#  'ncluded': ('included', 'included', 'included', 'included'),
#  'ncludes': ('includes', 'includes', 'includes', 'includes'),
#  'ncludng': ('certain', '', '', ''),
#  'ncomplete': ('incomplete', 'complete', 'complete', 'complete'),
#  'ncorrectly': ('incorrectly', 'incorrectly', 'incorrectly', 'incorrectly'),
#  'ncrease': ('increase', 'increase', 'increase', 'crease'),
#  'ncreased': ('increased', 'creased', 'increased', 'creased'),
#  'ncreases': ('increases', 'creases', 'creases', 'creases'),
#  'ncreaslng': ('increasing', '', '', ''),
#  'ncreaslngly': ('increasingly', '', '', ''),
#  'ndependent': ('independent', 'dependent', 'dependent', 'dependent'),
#  'ndependently': ('independently',
#   'independently',
#   'independently',
#   'independently'),
#  'ndex': ('index', 'index', 'index', 'index'),
#  'ndus': ('indus', 'indus', 'indus', 'indus'),
#  'ndustres': ('present', '', '', ''),
#  'ndustrlal': ('industrial', '', '', ''),
#  'ndustryibyilndustry': ('industrybyindustry', '', '', ''),
#  'ndustryigovernment': ('industrygovernment', '', '', ''),
#  'ndustrys': ('industrys', 'ndustry', 'ndustry', 'ndustry'),
#  'ndvdual': ('states', '', '', ''),
#  'negotlated': ('negotiated', 'negotiated', 'negotiated', 'negotiated'),
#  'negotlatlons': ('negotiations', '', '', ''),
#  'nelghborhood': ('neighborhood',
#   'neighborhood',
#   'neighborhood',
#   'neighborhood'),
#  'nflatlon': ('inflation', '', '', ''),
#  'nflatlonary': ('inflationary', '', '', ''),
#  'nflatloni': ('inflation', '', '', ''),
#  'nfluence': ('influence', 'influence', 'influence', 'influence'),
#  'nfluenced': ('influenced', 'influenced', 'influenced', 'influenced'),
#  'nfluentlal': ('influential', '', '', ''),
#  'nfomatlon': ('developed', '', '', ''),
#  'nformal': ('informal', 'formal', 'formal', 'formal'),
#  'nformatlon': ('information', '', '', ''),
#  'nformed': ('informed', 'formed', 'formed', 'formed'),
#  'nght': ('right', 'night', 'night', 'night'),
#  'njectlon': ('injection', '', '', ''),
#  'njunctlon': ('injunction', '', '', ''),
#  'njury': ('injury', 'jury', 'jury', 'jury'),
#  'nlckelicontalnlng': ('nickelcontaining', '', '', ''),
#  'nlflcant': ('nificant', '', '', ''),
#  'nlstratlon': ('continues', '', '', ''),
#  'nltrlc': ('nitric', '', '', ''),
#  'nnovatlon': ('innovation', '', '', ''),
#  'nnovatlons': ('innovations', '', '', ''),
#  'nnquantlflable': ('nonquantifiable', '', '', ''),
#  'nonichemlcal': ('nonchemical', '', '', ''),
#  'nonieconomlc': ('noneconomic', '', '', ''),
#  'noniemergency': ('nonemergency',
#   'nonemergency',
#   'nonemergency',
#   'nonemergency'),
#  'nonifulflllment': ('nonfulfillment', '', '', ''),
#  'nonilltlgatlon': ('nonlitigation', '', '', ''),
#  'nonimetalllc': ('nonmetalllc', '', '', ''),
#  'nonitarlff': ('nontariff', '', '', ''),
#  'nothlng': ('nothing', 'nothing', 'nothing', 'nothing'),
#  'notlflcatlon': ('notification', '', '', ''),
#  'nplace': ('inplace', 'place', 'place', 'place'),
#  'nput': ('input', 'put', 'put', 'put'),
#  'nspected': ('inspected', 'inspected', 'inspected', 'inspected'),
#  'nspectlon': ('inspection', '', '', ''),
#  'nstallatlon': ('installation', '', '', ''),
#  'nstance': ('instance', 'stance', 'stance', 'stance'),
#  'nstances': ('instances', 'stances', 'stances', 'stances'),
#  'nstructors': ('instructors', 'instructors', 'instructors', 'instructors'),
#  'nstrumental': ('instrumental',
#   'instrumental',
#   'instrumental',
#   'instrumental'),
#  'nsurance': ('insurance', 'insurance', 'insurance', 'insurance'),
#  'ntarnatlonal': ('intarnational',
#   'intarnatlonal',
#   'intarnatlonal',
#   'intarnatlonal'),
#  'ntegratlon': ('integration', '', '', ''),
#  'ntellectual': ('intellectual',
#   'intellectual',
#   'intellectual',
#   'intellectual'),
#  'ntended': ('intended', 'tended', 'tended', 'tended'),
#  'ntends': ('intends', 'tends', 'tends', 'tends'),
#  'ntenslfy': ('intensify', '', '', ''),
#  'ntenslve': ('intensive', '', '', ''),
#  'ntentlon': ('intention', '', '', ''),
#  'nteractlon': ('interaction', '', '', ''),
#  'nteragency': ('interagency', 'interagency', 'interagency', 'interagency'),
#  'nterest': ('interest', 'interest', 'interest', 'interest'),
#  'nterested': ('interested', 'interested', 'interested', 'interested'),
#  'nterests': ('interests', 'interests', 'interests', 'interests'),
#  'nterface': ('interface', 'interface', 'interface', 'interface'),
#  'nterfuel': ('interfuel', 'interfuel', 'interfuel', 'interfuel'),
#  'ntermedlates': ('intermediates', '', '', ''),
#  'nternal': ('internal', 'ternal', 'ternal', 'ternal'),
#  'nternally': ('internally', 'internally', 'internally', 'internally'),
#  'nternatlonal': ('international', '', '', ''),
#  'nterpretatlon': ('interpretation', '', '', ''),
#  'nterstate': ('interstate', 'interstate', 'interstate', 'interstate'),
#  'nterventlon': ('intervention', '', '', ''),
#  'ntervlewed': ('interviewed', '', '', ''),
#  'ntervlews': ('interviews', '', '', ''),
#  'ntezpretatlon': ('interpretation', '', '', ''),
#  'ntlally': ('affect', '', '', ''),
#  'ntrastate': ('intrastate', 'intrastate', 'intrastate', 'intrastate'),
#  'ntroduce': ('introduce', 'introduce', 'introduce', 'introduce'),
#  'ntroduced': ('introduced', 'introduced', 'introduced', 'introduced'),
#  'ntroductlon': ('introduction', '', '', ''),
#  'nventlons': ('inventions', '', '', ''),
#  'nventors': ('inventors', 'inventors', 'inventors', 'inventors'),
#  'nventory': ('inventory', 'inventory', 'inventory', 'inventory'),
#  'nventoryemlsslons': ('inventoryemissions', '', '', ''),
#  'nvestment': ('investment', 'investment', 'investment', 'investment'),
#  'nvestments': ('investments', 'investments', 'investments', 'investments'),
#  'nvestors': ('investors', 'investors', 'investors', 'investors'),
#  'nvolve': ('involve', 'involve', 'involve', 'involve'),
#  'nvolved': ('involved', 'involved', 'involved', 'volved'),
#  'nvolvement': ('involvement', 'involvement', 'involvement', 'involvement'),
#  'nvolves': ('involves', 'involves', 'involves', 'involves'),
#  'objectlons': ('objections', 'objections', 'objections', 'objections'),
#  'objectlve': ('objective', 'objective', 'objective', 'objective'),
#  'objectlves': ('objectives', 'objectives', 'objectives', 'objectives'),
#  'obllgatlon': ('obligation', '', '', ''),
#  'obllgatlons': ('obligations', '', '', ''),
#  'observatlons': ('observations',
#   'observations',
#   'observations',
#   'observations'),
#  'obtalnlng': ('obtaining', '', '', ''),
#  'occupatlonal': ('occupational',
#   'occupational',
#   'occupational',
#   'occupational'),
#  'offenslve': ('offensive', 'offensive', 'offensive', 'offensive'),
#  'offerlng': ('offering', 'offering', 'offering', 'offering'),
#  'offlce': ('office', '', '', ''),
#  'offlcers': ('officers', 'officers', 'officers', 'officers'),
#  'offlclally': ('officially', '', '', ''),
#  'offlclals': ('officials', '', '', ''),
#  'ollcy': ('policy', '', '', ''),
#  'omlsslons': ('omissions', '', '', ''),
#  'omnlbus': ('omnibus', '', '', ''),
#  'onltorlng': ('monitoring', '', '', ''),
#  'operablllty': ('operability', '', '', ''),
#  'operatlonal': ('operational', 'operational', 'operational', 'operational'),
#  'opportunltles': ('opportunities', '', '', ''),
#  'opportunlty': ('opportunity', 'opportunity', 'opportunity', 'opportunity'),
#  ...}

# %%
N_tr = len(tr_word_list)

# %%
# Word-wise recalls and precisions
num_corrections_found_MLE = num_corrections_found_tesseract\
                            + len(dict((k, v) for k, v in result.items() if v[0] == v[1]))
num_corrections_found_ELE = num_corrections_found_tesseract\
                            + len(dict((k, v) for k, v in result.items() if v[0] == v[2]))
num_corrections_found_GT = num_corrections_found_tesseract\
                            + len(dict((k, v) for k, v in result.items() if v[0] == v[3]))
wordwise_precision_tesseract = num_corrections_found_tesseract / N
wordwise_precision_MLE = num_corrections_found_MLE / N
wordwise_precision_ELE = num_corrections_found_ELE / N
wordwise_precision_GT = num_corrections_found_GT / N

# print(wordwise_precision_tesseract, wordwise_precision_MLE, wordwise_precision_ELE)

wordwise_recall_tesseract = num_corrections_found_tesseract / N_tr
wordwise_recall_MLE = num_corrections_found_MLE / N_tr
wordwise_recall_ELE = num_corrections_found_ELE / N_tr
wordwise_recall_GT = num_corrections_found_GT / N_tr
# print(wordwise_recall_tesseract, wordwise_recall_MLE, wordwise_recall_ELE)

# %%
# Character-wise recalls and precisions
def get_100tage_per_word_pair(w1, w2):
    max_len, min_len = max(len(w1), len(w2)), min(len(w1), len(w2))
    score = 0
    for i in range(min_len):
        if w1[i] == w2[i]:
            score +=1
    return(score / max_len)
# print(get_100tage_per_word_pair('cors', 'car'))
    
# len(result) is denominator
sum_tesseract, sum_mle, sum_ele, sum_gt = 0, 0, 0, 0
for k, v in result.items():
    sum_tesseract += get_100tage_per_word_pair(v[0], k)
    sum_mle += get_100tage_per_word_pair(v[0], v[1])
    sum_ele += get_100tage_per_word_pair(v[0], v[2])
    sum_gt += get_100tage_per_word_pair(v[0], v[3])
# Total numbers of letters in ground truth and in tesseract
sum_all_truth, sum_all_tesseract = 0, 0
for w in word_list:
    sum_all_truth += len(w)
for w in tr_word_list:
    sum_all_tesseract += len(w)

charwise_precision_tesseract = sum_letters[1] / sum_all_truth
charwise_precision_MLE = (sum_letters[1] + sum_mle) / sum_all_truth
charwise_precision_ELE = (sum_letters[1] + sum_ele) / sum_all_truth
charwise_precision_GT = (sum_letters[1] + sum_gt) / sum_all_truth
# print(charwise_precision_tesseract, charwise_precision_MLE, charwise_precision_ELE)

charwise_recall_tesseract = sum_letters[1] / sum_all_tesseract
charwise_recall_MLE = (sum_letters[1] + sum_mle) / sum_all_tesseract
charwise_recall_ELE = (sum_letters[1] + sum_ele) / sum_all_tesseract
charwise_recall_GT = (sum_letters[1] + sum_gt) / sum_all_tesseract
# print(charwise_recall_tesseract, charwise_recall_MLE, charwise_recall_ELE)

# %%
idxs = pd.Index(["Word-wise recall", "Word-wise precision", \
              "Character-wise recall ", "Character-wise precision"])
cols = pd.Index(["Tesseract", "Tesseract with Post-Processing (MLE)",\
              "Tesseract with Post-Processing (ELE)","Tesseract with Post-Processing (GT)"])
df = pd.DataFrame(data=np.array([\
     [wordwise_precision_tesseract, wordwise_precision_MLE, wordwise_precision_ELE,wordwise_precision_GT],\
     [wordwise_recall_tesseract, wordwise_recall_MLE, wordwise_recall_ELE, wordwise_recall_GT],\
     [charwise_precision_tesseract, charwise_precision_MLE, charwise_precision_ELE, charwise_precision_GT],\
     [charwise_recall_tesseract, charwise_recall_MLE, charwise_recall_ELE, charwise_recall_GT]]),\
     index=idxs, columns=cols)
display(df)
# Out:
#                           Tesseract  Tesseract with Post-Processing (MLE)  \
# Word-wise recall           0.627530                              0.627566
# Word-wise precision       57.647273                             57.650579
# Character-wise recall      0.894004                              0.894045
# Character-wise precision  53.010643                             53.013068
#
#                           Tesseract with Post-Processing (ELE)  \
# Word-wise recall                                      0.627566
# Word-wise precision                                  57.650579
# Character-wise recall                                 0.894045
# Character-wise precision                             53.013068
#
#                           Tesseract with Post-Processing (GT)
# Word-wise recall                                     0.627569
# Word-wise precision                                 57.650909
# Character-wise recall                                0.894044
# Character-wise precision                            53.013024
