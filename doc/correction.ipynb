# %%
import correction_lib as corr
from word_dict import Create_Words_Dictionary, Create_Word_Pair
import string
import glob
import os
import itertools
import collections
import timeit
import random
import pandas as pd
import numpy as np

# %%
def clean_word(w):
    out = []
    for c in w:
        c = c.lower()
        # Searching set is faster than list: O(1) vs. O(n=26)
        if c in set(string.ascii_lowercase):
            out.append(c)
    return(''.join(out))

def char_to_index(c):
    if c=="{":
        return(26)
    else:
        return(ord(c) - ord('a'))

# %%
word_list = []
gt_filenames = glob.glob(os.path.join(os.getcwd(), '../data', 'ground_truth', '*.txt'))

count = 0
for gt_f in gt_filenames:
    with open(gt_f) as file:
        raw = file.read()
        # Split file content into words (by '\n', '\t', ' ', etc.)
        uncleaned_words = raw.split()
        # Clean up words, leave only all-alpha chars of length > 1 (function programming)
        word_list += list(filter(lambda x: 1 < len(x) < 21, map(clean_word, uncleaned_words)))
        
word_set=set(word_list)

# %%
group_by_len = collections.defaultdict(list)
for w in word_set:
    group_by_len[len(w)].append(w)

# A dictionary of positional binary digrams (matrices),
# ordered by word length and then by binary positions
digrams_by_len = collections.defaultdict(dict)
for length in group_by_len:
    for i, j in itertools.combinations(range(length), 2):
        key = (i, j)
        matrix = [[0] * 26 for _ in range(26)]
        for w in group_by_len[length]:
            matrix[char_to_index(w[i])][char_to_index(w[j])] = 1
        digrams_by_len[length][key] = matrix

# %%
#####need to.be change
# Create a list of words from tesseract text; regard repeatition and order of words
tr_word_list = []
tr_filenames = glob.glob(os.path.join(os.getcwd(), 'data', 'tesseract', '*.txt'))
for tr_f in tr_filenames:
    with open(tr_f) as file:
        raw = file.read()
        uncleaned_words = raw.split()
        tr_word_list += list(filter(lambda x: 1 < len(x) < 21, map(clean_word, uncleaned_words)))
N_tr = len(tr_word_list)
# print(N_tr, '\n', tr_word_list[:30])

# %%
detected_error_tuples = []
for idx, w in enumerate(tr_word_list):
    error = False
    for i, j in itertools.combinations(range(len(w)), 2):
#         print(i, j, w[i], w[j], len(digrams_by_len[len(w)][(i, j)]), len(digrams_by_len[len(w)][(i, j)][0]))
        if not digrams_by_len[len(w)][(i, j)][char_to_index(w[i])][char_to_index(w[j])]:
            error = True
    if error:
        left = tr_word_list[i-1] if i > 0 else ''
        right = tr_word_list[i+1] if i < len(tr_word_list)-1 else ''
        detected_error_tuples.append((w, left, right))

# A list of detected error words
detected_error_words = [x[0] for x in detected_error_tuples]

# %%
# read Confusion matrix
add_matrix=np.array(pd.read_csv("../data/confusion_matrix/add_matrix.csv",index_col=0))
del_matrix=np.array(pd.read_csv("../data/confusion_matrix/del_matrix.csv",index_col=0))
rev_matrix=np.array(pd.read_csv("../data/confusion_matrix/rev_matrix.csv",index_col=0))
sub_matrix=np.array(pd.read_csv("../data/confusion_matrix/sub_matrix.csv",index_col=0))

# Useful values from section 3 of paper C-4.
N = len(word_list)
V = len(word_set)
denominator = N + V/2

# %%
def get_correction_candidates(w):
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    candidate_list = [[] for _ in range(4)]
    
    ### 4 kinds of correction candidates (see Table 2, C-4)
    # 0. Deletion
    for i in range(len(w) + 1):
        for c in alphabet:
            correction = w[:i] + c + w[i:]
            if correction in word_set:
                diff = corr.find_deletion_letters(correction, w) 
                candidate_list[0].append((correction, diff['pre_letter'], diff['delete_letter']))
            
    # 1. Insertion
    for i in range(len(w)):
        correction = w[:i] + w[i+1:]
        if correction in word_set:
            diff = corr.find_insertion_letters(correction, w) 
            candidate_list[1].append((correction, diff['pre_letter'], diff['insert_letter']))
    
    # 2. Substitution
    for i in range(len(w)):
        for c in alphabet:
            if c != w[i]:
                correction = w[:i] + c + w[i+1:]
                if correction in word_set:
                    diff = corr.find_sub_rev_letters(correction, w) 
                    if diff['tag'] == 'sub':
                        candidate_list[2].append((correction, diff['pre_letter'], diff['changed_letter']))
    
    # 3. Reversal
    for i in range(len(w) - 1):
        correction = w[:i] + w[i+1] + w[i] + w[i+2:]
        if correction in word_set:
            diff = corr.find_sub_rev_letters(correction, w) 
            if diff['tag'] == 'rev':
                candidate_list[3].append((correction, diff['pre_letter'], diff['changed_letter']))
    
    return(candidate_list)

# %%
get_correction_candidates('responder')
# Out:
# [[('responders', 'r', 's')], [], [('responded', 'd', 'r')], []]

# %%
#read detected words from detection
import re
detection=pd.read_excel('detection.xlsx')
detected_error_words=[str(i) for i in np.array(detection['tokens_tesseract'])]
detected_error_words=[''.join(re.findall('[a-z]+',i)) for i in detected_error_words]
# detection.info()

# %%
start = timeit.default_timer()

all_candidates = collections.defaultdict(list)
for word in detected_error_words:
    all_candidates[word] = get_correction_candidates(word)
    
stop = timeit.default_timer()
print('Time:', stop - start, 'seconds')
# Out:
# Time: 1.755324236999968 seconds

# %%
# all_candidates = collections.defaultdict(list)
temp=['admlnlstratlon','responder','responder']
# for word in temp:
#     all_candidates[word] = get_correction_candidates(word)
# all_candidates
print(detected_error_words[0:10])
print(temp)
# Out:
# ['admlnlstratlon', 'exemptlons', 'ommlttee', 'closediloop', 'n', 'whlch', 'responder', 'authorlty', 'sso', 'olunteers']
# ['admlnlstratlon', 'responder', 'responder']

# %%
all_candidates
# Out:
# defaultdict(list,
#             {'admlnlstratlon': [[], [], [], []],
#              'exemptlons': [[], [], [('exemptions', 'i', 'l')], []],
#              'ommlttee': [[('commlttee', '{', 'c')], [], [], []],
#              'closediloop': [[], [('closedloop', 'd', 'i')], [], []],
#              'n': [[('an', '{', 'a'),
#                ('bn', '{', 'b'),
#                ('cn', '{', 'c'),
#                ('en', '{', 'e'),
#                ('in', '{', 'i'),
#                ('ln', '{', 'l'),
#                ('mn', '{', 'm'),
#                ('nn', 'n', 'n'),
#                ('on', '{', 'o'),
#                ('tn', '{', 't'),
#                ('un', '{', 'u'),
#                ('wn', '{', 'w'),
#                ('xn', '{', 'x'),
#                ('zn', '{', 'z'),
#                ('nc', 'n', 'c'),
#                ('nd', 'n', 'd'),
#                ('ne', 'n', 'e'),
#                ('ng', 'n', 'g'),
#                ('nh', 'n', 'h'),
#                ('nj', 'n', 'j'),
#                ('nl', 'n', 'l'),
#                ('nn', 'n', 'n'),
#                ('no', 'n', 'o'),
#                ('ns', 'n', 's'),
#                ('nt', 'n', 't'),
#                ('nw', 'n', 'w'),
#                ('nx', 'n', 'x'),
#                ('ny', 'n', 'y')],
#               [],
#               [],
#               []],
#              'whlch': [[],
#               [('wlch', 'w', 'h')],
#               [('which', 'i', 'l'), ('whleh', 'e', 'c')],
#               []],
#              'responder': [[('responders', 'r', 's')],
#               [],
#               [('responded', 'd', 'r')],
#               []],
#              'authorlty': [[], [], [('authority', 'i', 'l')], []],
#              'sso': [[('asso', '{', 'a'), ('soso', 'o', 's')],
#               [('so', '{', 's'), ('so', '{', 's'), ('ss', 's', 'o')],
#               [('iso', 'i', 's'), ('sao', 'a', 's'), ('sst', 't', 'o')],
#               []],
#              'olunteers': [[('volunteers', '{', 'v')], [], [], []],
#              'ndustry': [[('industry', '{', 'i')],
#               [('dustry', '{', 'n')],
#               [],
#               []],
#              'a': [[('aa', 'a', 'a'),
#                ('ba', '{', 'b'),
#                ('ca', '{', 'c'),
#                ('da', '{', 'd'),
#                ('ea', '{', 'e'),
#                ('fa', '{', 'f'),
#                ('ga', '{', 'g'),
#                ('ha', '{', 'h'),
#                ('ia', '{', 'i'),
#                ('la', '{', 'l'),
#                ('ma', '{', 'm'),
#                ('oa', '{', 'o'),
#                ('pa', '{', 'p'),
#                ('qa', '{', 'q'),
#                ('ra', '{', 'r'),
#                ('ta', '{', 't'),
#                ('va', '{', 'v'),
#                ('wa', '{', 'w'),
#                ('aa', 'a', 'a'),
#                ('ab', 'a', 'b'),
#                ('ac', 'a', 'c'),
#                ('ad', 'a', 'd'),
#                ('ag', 'a', 'g'),
#                ('ai', 'a', 'i'),
#                ('ak', 'a', 'k'),
#                ('al', 'a', 'l'),
#                ('am', 'a', 'm'),
#                ('an', 'a', 'n'),
#                ('ap', 'a', 'p'),
#                ('ar', 'a', 'r'),
#                ('as', 'a', 's'),
#                ('at', 'a', 't'),
#                ('au', 'a', 'u'),
#                ('av', 'a', 'v'),
#                ('ay', 'a', 'y'),
#                ('az', 'a', 'z')],
#               [],
#               [],
#               []],
#              'presented': [[], [], [('prevented', 'v', 's')], []],
#              'slmllar': [[], [], [], []],
#              'ssoclatlons': [[], [], [], []],
#              'slgnature': [[], [], [('signature', 'i', 'l')], []],
#              'posslble': [[], [], [('possible', 'i', 'l')], []],
#              'research': [[], [], [], []],
#              'formatlon': [[], [], [('formation', 'i', 'l')], []],
#              'restrlctlons': [[], [], [], []],
#              'submlsslon': [[], [], [], []],
#              '': [[], [], [], []],
#              'leglslatlve': [[], [], [], []],
#              'nfomatlon': [[], [], [], []],
#              'maxlmum': [[], [], [('maximum', 'i', 'l')], []],
#              'hearlng': [[], [], [('hearing', 'i', 'l')], []],
#              'staff': [[('stafff', 'f', 'f'),
#                ('stafff', 'f', 'f'),
#                ('stafff', 'f', 'f'),
#                ('staffs', 'f', 's')],
#               [],
#               [('scaff', 'c', 't'), ('staft', 't', 'f')],
#               []],
#              'posslblllty': [[], [], [], []],
#              'rullng': [[], [], [('ruling', 'i', 'l')], []],
#              'handllng': [[], [], [('handling', 'i', 'l')], []],
#              'calllng': [[], [], [('calling', 'i', 'l')], []],
#              'epartment': [[('department', '{', 'd')],
#               [('partment', '{', 'e')],
#               [],
#               []],
#              'ssoc': [[('assoc', '{', 'a')], [], [], []],
#              'study': [[('studys', 'y', 's')], [], [], []],
#              'publlc': [[],
#               [],
#               [('dubllc', 'd', 'p'), ('public', 'i', 'l')],
#               []],
#              'thls': [[],
#               [('ths', 'h', 'l')],
#               [('thes', 'e', 'l'),
#                ('this', 'i', 'l'),
#                ('thos', 'o', 'l'),
#                ('thus', 'u', 'l'),
#                ('thla', 'a', 's')],
#               []],
#              'nnovatlon': [[], [], [], []],
#              'publlshed': [[], [], [('published', 'i', 'l')], []],
#              'onsultatlons': [[], [], [], []],
#              'actlvlty': [[], [], [], []],
#              'manufacturers': [[],
#               [('manufactures', 'e', 'r'), ('manufacturer', 'r', 's')],
#               [('manufaccurers', 'c', 't')],
#               []],
#              'sollclted': [[], [], [], []],
#              'ongress': [[('congress', '{', 'c')], [], [], []],
#              'grows': [[],
#               [('grow', 'w', 's')],
#               [('gross', 's', 'w'), ('grown', 'n', 's')],
#               []],
#              'inspection': [[('inspections', 'n', 's')], [], [], []],
#              'thelr': [[], [('ther', 'e', 'l')], [('their', 'i', 'l')], []],
#              'ollcy': [[], [], [], []],
#              'ozporatlon': [[], [], [], []],
#              'h': [[('ch', '{', 'c'),
#                ('eh', '{', 'e'),
#                ('nh', '{', 'n'),
#                ('oh', '{', 'o'),
#                ('sh', '{', 's'),
#                ('th', '{', 't'),
#                ('wh', '{', 'w'),
#                ('ha', 'h', 'a'),
#                ('hb', 'h', 'b'),
#                ('hc', 'h', 'c'),
#                ('he', 'h', 'e'),
#                ('hi', 'h', 'i'),
#                ('hm', 'h', 'm'),
#                ('ho', 'h', 'o'),
#                ('hr', 'h', 'r'),
#                ('ht', 'h', 't'),
#                ('hy', 'h', 'y')],
#               [],
#               [],
#               []],
#              'lets': [[],
#               [('ets', '{', 'l'), ('let', 't', 's')],
#               [('gets', 'g', 'l'),
#                ('sets', 's', 'l'),
#                ('wets', 'w', 'l'),
#                ('lots', 'o', 'e'),
#                ('leas', 'a', 't'),
#                ('lems', 'm', 't'),
#                ('less', 's', 't'),
#                ('lews', 'w', 't')],
#               [('lest', 's', 't')]],
#              'regulatlon': [[], [], [('regulation', 'i', 'l')], []],
#              'v': [[('av', '{', 'a'),
#                ('bv', '{', 'b'),
#                ('iv', '{', 'i'),
#                ('ov', '{', 'o'),
#                ('tv', '{', 't'),
#                ('wv', '{', 'w'),
#                ('va', 'v', 'a'),
#                ('vc', 'v', 'c'),
#                ('vd', 'v', 'd'),
#                ('ve', 'v', 'e'),
#                ('vi', 'v', 'i'),
#                ('vs', 'v', 's')],
#               [],
#               [],
#               []],
#              'prof': [[('proof', 'o', 'o'), ('proof', 'o', 'o')],
#               [('pro', 'o', 'f')],
#               [('prob', 'b', 'f'),
#                ('proc', 'c', 'f'),
#                ('proe', 'e', 'f'),
#                ('proj', 'j', 'f'),
#                ('prom', 'm', 'f'),
#                ('pros', 's', 'f')],
#               []],
#              'commlttee': [[],
#               [],
#               [('conmlttee', 'n', 'm'),
#                ('comtlttee', 't', 'm'),
#                ('committee', 'i', 'l'),
#                ('commlttae', 'a', 'e')],
#               []],
#              'guldellnes': [[], [], [], []],
#              'effects': [[],
#               [('effect', 't', 's')],
#               [('affects', 'a', 'e')],
#               []],
#              'nvolved': [[('involved', '{', 'i')],
#               [('volved', '{', 'n')],
#               [('evolved', 'e', 'n')],
#               []],
#              'ompensatlon': [[], [], [], []],
#              'llttle': [[], [], [('little', 'i', 'l')], []],
#              'subrogatlon': [[], [], [('subrogation', 'i', 'l')], []],
#              'ncreaslng': [[], [], [], []],
#              'rovlslonal': [[], [], [], []],
#              'ollutant': [[('pollutant', '{', 'p')], [], [], []],
#              'produclng': [[], [], [('producing', 'i', 'l')], []],
#              'arch': [[('march', '{', 'm')],
#               [('rch', '{', 'a'), ('ach', 'a', 'r'), ('arc', 'c', 'h')],
#               [('aach', 'a', 'r'), ('auch', 'u', 'r'), ('arco', 'o', 'h')],
#               []],
#              'posltlons': [[], [], [], []],
#              'qulpment': [[], [], [], []],
#              'ntlates': [[], [], [], []],
#              'systems': [[], [('system', 'm', 's')], [], []],
#              'le': [[('ale', '{', 'a'),
#                ('ble', '{', 'b'),
#                ('gle', '{', 'g'),
#                ('lee', 'e', 'e'),
#                ('lie', 'l', 'i'),
#                ('lve', 'l', 'v'),
#                ('lea', 'e', 'a'),
#                ('led', 'e', 'd'),
#                ('lee', 'e', 'e'),
#                ('leg', 'e', 'g'),
#                ('lem', 'e', 'm'),
#                ('leo', 'e', 'o'),
#                ('let', 'e', 't')],
#               [],
#               [('be', 'b', 'l'),
#                ('ce', 'c', 'l'),
#                ('de', 'd', 'l'),
#                ('ee', 'e', 'l'),
#                ('fe', 'f', 'l'),
#                ('ge', 'g', 'l'),
#                ('he', 'h', 'l'),
#                ('ie', 'i', 'l'),
#                ('me', 'm', 'l'),
#                ('ne', 'n', 'l'),
#                ('oe', 'o', 'l'),
#                ('pe', 'p', 'l'),
#                ('re', 'r', 'l'),
#                ('se', 's', 'l'),
#                ('te', 't', 'l'),
#                ('ve', 'v', 'l'),
#                ('we', 'w', 'l'),
#                ('la', 'a', 'e'),
#                ('li', 'i', 'e'),
#                ('ll', 'l', 'e'),
#                ('ln', 'n', 'e'),
#                ('lp', 'p', 'e'),
#                ('lt', 't', 'e'),
#                ('ly', 'y', 'e')],
#               [('el', 'e', 'l')]],
#              'objectlves': [[], [], [('objectives', 'i', 'l')], []],
#              'xhlblt': [[], [], [], []],
#              'unlts': [[], [], [('units', 'i', 'l')], []],
#              'qulckly': [[], [], [('quickly', 'i', 'l')], []],
#              'asuptoidate': [[], [('asuptodate', 'o', 'i')], [], []],
#              'precursor': [[('precursors', 'r', 's')], [], [], []],
#              'dentlflcatlon': [[], [], [], []],
#              'envlronmental': [[], [], [('environmental', 'i', 'l')], []],
#              'lth': [[('vlth', '{', 'v')],
#               [('th', '{', 'l'), ('lt', 't', 'h')],
#               [('oth', 'o', 'l'), ('ltd', 'd', 'h'), ('ltl', 'l', 'h')],
#               []],
#              'chlorlde': [[], [], [('chloride', 'i', 'l')], []],
#              'penaltles': [[], [], [('penalties', 'i', 'l')], []],
#              'ubllc': [[('dubllc', '{', 'd')], [], [], []],
#              'dlscusslons': [[], [], [], []],
#              'onsaipassed': [[], [], [], []],
#              'addltlon': [[],
#               [],
#               [('jddltlon', 'j', 'a'), ('addlelon', 'e', 't')],
#               []],
#              'establlshlng': [[], [], [], []],
#              'phthalate': [[('phthalates', 'e', 's')],
#               [('phthalat', 't', 'e')],
#               [('fhthalate', 'f', 'p'), ('phthaiate', 'i', 'l')],
#               []],
#              'tests': [[],
#               [('test', 't', 's')],
#               [('rests', 'r', 't'), ('texts', 'x', 's'), ('testi', 'i', 's')],
#               []],
#              'nformatlon': [[], [], [], []],
#              'stud': [[('study', 'd', 'y')], [], [], []],
#              'dlstrlbutlon': [[], [], [], []],
#              'understandlng': [[], [], [('understanding', 'i', 'l')], []],
#              'mportant': [[('important', '{', 'i')],
#               [('portant', '{', 'm')],
#               [],
#               []],
#              'ountrles': [[], [], [], []],
#              'reductlon': [[], [], [('reduction', 'i', 'l')], []],
#              'recelpts': [[], [], [('receipts', 'i', 'l')], []],
#              'beneflts': [[], [], [('benefits', 'i', 'l')], []],
#              'consultant': [[('consultants', 't', 's')], [], [], []],
#              'problems': [[],
#               [('problem', 'm', 's')],
#               [('probleas', 'a', 'm')],
#               []],
#              'provlslons': [[], [], [], []],
#              'assoclatlon': [[], [], [], []],
#              'procurement': [[], [], [], []],
#              'hearlngs': [[], [], [('hearings', 'i', 'l')], []],
#              'emlsslon': [[], [], [], []],
#              'ommlsslon': [[], [], [], []],
#              'demonstratlon': [[], [], [('demonstration', 'i', 'l')], []],
#              'dvocacy': [[('advocacy', '{', 'a')],
#               [('vocacy', '{', 'd')],
#               [],
#               []],
#              'hlpplng': [[], [], [], []],
#              'communlcatlons': [[],
#               [],
#               [('comaunlcatlons', 'a', 'm'), ('communlcations', 'i', 'l')],
#               []],
#              'funds': [[], [('fund', 'd', 's')], [('finds', 'i', 'u')], []],
#              'mergency': [[('emergency', '{', 'e')], [], [], []],
#              'dlbromlde': [[],
#               [],
#               [('dibromlde', 'i', 'l'), ('dlbroalde', 'a', 'm')],
#               []],
#              'elevlslon': [[], [], [], []],
#              'chemlcal': [[], [], [('chemical', 'i', 'l')], []],
#              'facslmlle': [[], [], [], []],
#              'ernandez': [[('fernandez', '{', 'f'), ('hernandez', '{', 'h')],
#               [],
#               [],
#               []],
#              'feaslblllty': [[], [], [], []],
#              'proposals': [[], [('proposal', 'l', 's')], [], []],
#              'crltlcal': [[], [], [], []],
#              'egulatlons': [[], [('gulatlons', '{', 'e')], [], []],
#              'efforts': [[], [('effort', 't', 's')], [], []],
#              'attentlon': [[], [], [('attention', 'i', 'l')], []],
#              'regulatlons': [[], [], [('regulations', 'i', 'l')], []],
#              'products': [[],
#               [('product', 't', 's')],
#               [('produits', 'i', 'c'), ('produces', 'e', 't')],
#               []],
#              'sectlons': [[], [], [('sections', 'i', 'l')], []],
#              'system': [[('systems', 'm', 's')],
#               [],
#               [('systam', 'a', 'e')],
#               []],
#              'halrman': [[],
#               [('harman', 'a', 'l')],
#               [('harrman', 'r', 'l')],
#               []],
#              'programs': [[],
#               [('progrms', 'r', 'a'), ('program', 'm', 's')],
#               [('procrams', 'c', 'g'), ('prograas', 'a', 'm')],
#               [('progrmas', 'm', 'a')]],
#              'start': [[('stuart', 't', 'u'), ('starts', 't', 's')],
#               [('stat', 'a', 'r')],
#               [('smart', 'm', 't'), ('staft', 'f', 'r'), ('stars', 's', 't')],
#               []],
#              'supportlng': [[], [], [('supporting', 'i', 'l')], []],
#              'testlng': [[], [], [('testing', 'i', 'l')], []],
#              'roundwater': [[('groundwater', '{', 'g')], [], [], []],
#              'successful': [[], [], [('luccessful', 'l', 's')], []],
#              'lst': [[('last', 'l', 'a'),
#                ('lest', 'l', 'e'),
#                ('list', 'l', 'i'),
#                ('lost', 'l', 'o'),
#                ('lust', 'l', 'u')],
#               [('st', '{', 'l'), ('lt', 'l', 's')],
#               [('ast', 'a', 'l'),
#                ('est', 'e', 'l'),
#                ('gst', 'g', 'l'),
#                ('nst', 'n', 'l'),
#                ('sst', 's', 'l'),
#                ('let', 'e', 's'),
#                ('lot', 'o', 's'),
#                ('lsw', 'w', 't')],
#               []],
#              'xports': [[('axports', '{', 'a'), ('exports', '{', 'e')],
#               [('ports', '{', 'x')],
#               [],
#               []],
#              'p': [[('ap', '{', 'a'),
#                ('bp', '{', 'b'),
#                ('ep', '{', 'e'),
#                ('lp', '{', 'l'),
#                ('op', '{', 'o'),
#                ('sp', '{', 's'),
#                ('up', '{', 'u'),
#                ('pa', 'p', 'a'),
#                ('pe', 'p', 'e'),
#                ('pl', 'p', 'l'),
#                ('pm', 'p', 'm'),
#                ('po', 'p', 'o'),
#                ('pq', 'p', 'q'),
#                ('pr', 'p', 'r'),
#                ('ps', 'p', 's')],
#               [],
#               [],
#               []],
#              'uperfund': [[('auperfund', '{', 'a'), ('superfund', '{', 's')],
#               [],
#               [],
#               []],
#              'partlcularly': [[], [], [('particularly', 'i', 'l')], []],
#              'ndustrlal': [[], [], [], []],
#              'congratulated': [[], [], [], []],
#              'nternatlonal': [[], [], [], []],
#              'subchronlc': [[],
#               [],
#               [('subchronic', 'i', 'l'), ('subchronle', 'e', 'c')],
#               []],
#              'x': [[('ex', '{', 'e'),
#                ('ix', '{', 'i'),
#                ('nx', '{', 'n'),
#                ('ox', '{', 'o'),
#                ('tx', '{', 't'),
#                ('xx', 'x', 'x'),
#                ('xi', 'x', 'i'),
#                ('xl', 'x', 'l'),
#                ('xm', 'x', 'm'),
#                ('xn', 'x', 'n'),
#                ('xt', 'x', 't'),
#                ('xx', 'x', 'x')],
#               [],
#               [],
#               []],
#              'establlshed': [[], [], [('established', 'i', 'l')], []],
#              'unportant': [[], [], [], []],
#              'ct': [[('act', '{', 'a'),
#                ('ect', '{', 'e'),
#                ('oct', '{', 'o'),
#                ('rct', '{', 'r'),
#                ('cut', 'c', 'u'),
#                ('ctf', 't', 'f')],
#               [],
#               [('at', 'a', 'c'),
#                ('bt', 'b', 'c'),
#                ('et', 'e', 'c'),
#                ('ft', 'f', 'c'),
#                ('ht', 'h', 'c'),
#                ('it', 'i', 'c'),
#                ('lt', 'l', 'c'),
#                ('mt', 'm', 'c'),
#                ('nt', 'n', 'c'),
#                ('rt', 'r', 'c'),
#                ('st', 's', 'c'),
#                ('tt', 't', 'c'),
#                ('ut', 'u', 'c'),
#                ('xt', 'x', 'c'),
#                ('ca', 'a', 't'),
#                ('cb', 'b', 't'),
#                ('cc', 'c', 't'),
#                ('ce', 'e', 't'),
#                ('cf', 'f', 't'),
#                ('cg', 'g', 't'),
#                ('ch', 'h', 't'),
#                ('cl', 'l', 't'),
#                ('cm', 'm', 't'),
#                ('cn', 'n', 't'),
#                ('co', 'o', 't'),
#                ('cq', 'q', 't'),
#                ('cs', 's', 't')],
#               [('tc', 't', 'c')]],
#              'twoithlrds': [[], [], [], []],
#              'property': [[], [], [('properly', 'l', 't')], []],
#              'lvlslon': [[], [], [], []],
#              'neutrallty': [[], [], [('neutrality', 'i', 'l')], []],
#              'lngredlent': [[], [], [], []],
#              'nergy': [[('energy', '{', 'e')], [], [], []],
#              'jolnt': [[], [], [('joint', 'i', 'l')], []],
#              'ocuments': [[('documents', '{', 'd')], [], [], []],
#              'lxed': [[], [('led', 'l', 'x')], [], []],
#              'c': [[('ac', '{', 'a'),
#                ('cc', 'c', 'c'),
#                ('dc', '{', 'd'),
#                ('ec', '{', 'e'),
#                ('fc', '{', 'f'),
#                ('hc', '{', 'h'),
#                ('ic', '{', 'i'),
#                ('jc', '{', 'j'),
#                ('mc', '{', 'm'),
#                ('nc', '{', 'n'),
#                ('oc', '{', 'o'),
#                ('sc', '{', 's'),
#                ('tc', '{', 't'),
#                ('vc', '{', 'v'),
#                ('wc', '{', 'w'),
#                ('ca', 'c', 'a'),
#                ('cb', 'c', 'b'),
#                ('cc', 'c', 'c'),
#                ('ce', 'c', 'e'),
#                ('cf', 'c', 'f'),
#                ('cg', 'c', 'g'),
#                ('ch', 'c', 'h'),
#                ('cl', 'c', 'l'),
#                ('cm', 'c', 'm'),
#                ('cn', 'c', 'n'),
#                ('co', 'c', 'o'),
#                ('cq', 'c', 'q'),
#                ('cs', 'c', 's'),
#                ('ct', 'c', 't')],
#               [],
#               [],
#               []],
#              'ongs': [[('longs', '{', 'l')],
#               [],
#               [('ings', 'i', 'o'), ('ones', 'e', 'g')],
#               []],
#              'flrst': [[], [], [('first', 'i', 'l'), ('flrat', 'a', 's')], []],
#              'asslglwaats': [[], [], [], []],
#              'dlrectly': [[], [], [('directly', 'i', 'l')], []],
#              'establlsh': [[], [], [('establish', 'i', 'l')], []],
#              'knows': [[], [('know', 'w', 's')], [('known', 'n', 's')], []],
#              'comlng': [[], [], [('coming', 'i', 'l')], []],
#              's': [[('as', '{', 'a'),
#                ('bs', '{', 'b'),
#                ('cs', '{', 'c'),
#                ('es', '{', 'e'),
#                ('gs', '{', 'g'),
#                ('is', '{', 'i'),
#                ('js', '{', 'j'),
#                ('ks', '{', 'k'),
#                ('ms', '{', 'm'),
#                ('ns', '{', 'n'),
#                ('os', '{', 'o'),
#                ('ps', '{', 'p'),
#                ('rs', '{', 'r'),
#                ('ss', 's', 's'),
#                ('ts', '{', 't'),
#                ('us', '{', 'u'),
#                ('vs', '{', 'v'),
#                ('sb', 's', 'b'),
#                ('sc', 's', 'c'),
#                ('sd', 's', 'd'),
#                ('se', 's', 'e'),
#                ('sf', 's', 'f'),
#                ('sh', 's', 'h'),
#                ('si', 's', 'i'),
#                ('sk', 's', 'k'),
#                ('sm', 's', 'm'),
#                ('so', 's', 'o'),
#                ('sp', 's', 'p'),
#                ('sr', 's', 'r'),
#                ('ss', 's', 's'),
#                ('st', 's', 't'),
#                ('sw', 's', 'w'),
#                ('sy', 's', 'y')],
#               [],
#               [],
#               []],
#              'generally': [[], [], [], []],
#              'effectlveness': [[], [], [('effectiveness', 'i', 'l')], []],
#              'ncentlves': [[], [], [], []],
#              'bllaterally': [[], [], [('bilaterally', 'i', 'l')], []],
#              'etlng': [[], [], [], []],
#              'approprlate': [[], [], [('appropriate', 'i', 'l')], []],
#              'llton': [[], [], [], []],
#              'llbur': [[], [], [], []],
#              'polnt': [[], [('pont', 'o', 'l')], [('point', 'i', 'l')], []],
#              'groundwater': [[],
#               [],
#               [('groundweter', 'e', 'a'), ('groundwatar', 'a', 'e')],
#               []],
#              'dlvldends': [[], [], [], []],
#              'lssues': [[], [], [('issues', 'i', 'l')], []],
#              'rlnklng': [[], [], [], []],
#              'lthough': [[('although', '{', 'a')],
#               [('though', '{', 'l')],
#               [],
#               []],
#              'rulemaklng': [[], [], [('rulemaking', 'i', 'l')], []],
#              'competltlve': [[], [], [], []],
#              'ommltee': [[], [], [], []],
#              'constltute': [[], [], [('constitute', 'i', 'l')], []],
#              'rallroads': [[], [], [('railroads', 'i', 'l')], []],
#              'mprovements': [[('improvements', '{', 'i')], [], [], []],
#              'lstrlbutlon': [[], [], [], []],
#              'efflclently': [[], [], [], []],
#              'perspectlve': [[], [], [('perspective', 'i', 'l')], []],
#              'flscal': [[], [], [('fiscal', 'i', 'l')], []],
#              'eetlng': [[], [], [], []],
#              'ongresslonal': [[], [], [], []],
#              'markets': [[],
#               [('market', 't', 's')],
#               [('markats', 'a', 'e')],
#               []],
#              'reduclng': [[], [], [('reducing', 'i', 'l')], []],
#              'yanamld': [[('cyanamld', '{', 'c')], [], [], []],
#              'stats': [[('starts', 'a', 'r'),
#                ('statas', 't', 'a'),
#                ('states', 't', 'e'),
#                ('statis', 't', 'i'),
#                ('statss', 's', 's'),
#                ('status', 't', 'u'),
#                ('statss', 's', 's')],
#               [('stat', 't', 's')],
#               [('seats', 'e', 't'),
#                ('stars', 'r', 't'),
#                ('stays', 'y', 't'),
#                ('stata', 'a', 's'),
#                ('state', 'e', 's')],
#               []],
#              'represents': [[],
#               [('represent', 't', 's')],
#               [('representa', 'a', 's')],
#               []],
#              'requlrement': [[], [], [('requirement', 'i', 'l')], []],
#              'ehlcles': [[], [], [], []],
#              'avld': [[], [], [], []],
#              'admlnlstratlve': [[], [], [], []],
#              'ssoclatlon': [[], [], [], []],
#              'routlnely': [[], [], [('routinely', 'i', 'l')], []],
#              'redacted': [[], [('reacted', 'e', 'd')], [], []],
#              'rograms': [[('programs', '{', 'p')], [], [], []],
#              'factors': [[], [('factor', 'r', 's')], [], []],
#              'ctlvlty': [[], [], [], []],
#              'estlmatlng': [[], [], [], []],
#              'scrutlny': [[], [], [('scrutiny', 'i', 'l')], []],
#              'clrcumstances': [[], [], [('circumstances', 'i', 'l')], []],
#              'toxlc': [[], [], [('toxic', 'i', 'l')], []],
#              'prlmary': [[], [], [('primary', 'i', 'l')], []],
#              'synthetlc': [[], [], [('synthetic', 'i', 'l')], []],
#              'spokesmen': [[], [], [('spokesman', 'a', 'e')], []],
#              'sharlng': [[], [], [('sharing', 'i', 'l')], []],
#              'ollutlon': [[], [], [], []],
#              'comments': [[],
#               [('coments', 'o', 'm'),
#                ('coments', 'o', 'm'),
#                ('comment', 't', 's')],
#               [('conments', 'n', 'm'),
#                ('comnents', 'n', 'm'),
#                ('commants', 'a', 'e'),
#                ('commends', 'd', 't')],
#               []],
#              'whlte': [[], [], [('white', 'i', 'l')], []],
#              'arlff': [[], [], [], []],
#              'manufacturlng': [[], [], [('manufacturing', 'i', 'l')], []],
#              'clalms': [[], [], [('claims', 'i', 'l')], []],
#              'lr': [[('clr', '{', 'c')],
#               [],
#               [('ar', 'a', 'l'),
#                ('dr', 'd', 'l'),
#                ('er', 'e', 'l'),
#                ('fr', 'f', 'l'),
#                ('gr', 'g', 'l'),
#                ('hr', 'h', 'l'),
#                ('ir', 'i', 'l'),
#                ('jr', 'j', 'l'),
#                ('mr', 'm', 'l'),
#                ('or', 'o', 'l'),
#                ('pr', 'p', 'l'),
#                ('sr', 's', 'l'),
#                ('tr', 't', 'l'),
#                ('ur', 'u', 'l'),
#                ('yr', 'y', 'l'),
#                ('la', 'a', 'r'),
#                ('le', 'e', 'r'),
#                ('li', 'i', 'r'),
#                ('ll', 'l', 'r'),
#                ('ln', 'n', 'r'),
#                ('lp', 'p', 'r'),
#                ('lt', 't', 'r'),
#                ('ly', 'y', 'r')],
#               []],
#              'dlsposal': [[], [], [('disposal', 'i', 'l')], []],
#              'declded': [[], [], [('decided', 'i', 'l')], []],
#              'nvestment': [[('investment', '{', 'i')],
#               [('vestment', '{', 'n')],
#               [],
#               []],
#              'shown': [[],
#               [('show', 'w', 'n')],
#               [('showa', 'a', 'n'), ('shows', 's', 'n')],
#               []],
#              'necessary': [[], [], [('neoessary', 'o', 'c')], []],
#              'rogrms': [[('progrms', '{', 'p')], [], [], []],
#              'crcuttng': [[], [], [], []],
#              'taly': [[('italy', '{', 'i'),
#                ('tally', 'l', 'l'),
#                ('tally', 'l', 'l')],
#               [('tal', 'l', 'y')],
#               [('tary', 'r', 'l'), ('talk', 'k', 'y')],
#               []],
#              'golng': [[], [], [('going', 'i', 'l')], []],
#              'overslght': [[], [], [('oversight', 'i', 'l')], []],
#              'contract': [[('contracts', 't', 's')],
#               [('contact', 't', 'r'), ('contrac', 'c', 't')],
#               [('contrast', 's', 'c')],
#               []],
#              'dlrectors': [[], [], [('directors', 'i', 'l')], []],
#              'represented': [[], [], [], []],
#              'deslgnated': [[], [], [('designated', 'i', 'l')], []],
#              'operatlons': [[], [], [('operations', 'i', 'l')], []],
#              'lothlng': [[], [], [], []],
#              'responded': [[], [], [('responder', 'r', 'd')], []],
#              'so': [[('iso', '{', 'i'), ('sao', 's', 'a'), ('sox', 'o', 'x')],
#               [],
#               [('co', 'c', 's'),
#                ('do', 'd', 's'),
#                ('eo', 'e', 's'),
#                ('fo', 'f', 's'),
#                ('go', 'g', 's'),
#                ('ho', 'h', 's'),
#                ('jo', 'j', 's'),
#                ('mo', 'm', 's'),
#                ('no', 'n', 's'),
#                ('po', 'p', 's'),
#                ('ro', 'r', 's'),
#                ('to', 't', 's'),
#                ('sb', 'b', 'o'),
#                ('sc', 'c', 'o'),
#                ('sd', 'd', 'o'),
#                ('se', 'e', 'o'),
#                ('sf', 'f', 'o'),
#                ('sh', 'h', 'o'),
#                ('si', 'i', 'o'),
#                ('sk', 'k', 'o'),
#                ('sm', 'm', 'o'),
#                ('sp', 'p', 'o'),
#                ('sr', 'r', 'o'),
#                ('ss', 's', 'o'),
#                ('st', 't', 'o'),
#                ('sw', 'w', 'o'),
#                ('sy', 'y', 'o')],
#               [('os', 'o', 's')]],
#              'embershlp': [[], [], [], []],
#              'grlculture': [[], [], [], []],
#              'proposal': [[('proposals', 'l', 's')],
#               [],
#               [('proposad', 'd', 'l')],
#               []],
#              'communltles': [[], [], [], []],
#              'sltus': [[], [], [('situs', 'i', 'l')], []],
#              'speclflc': [[], [], [], []],
#              'ransportatlon': [[], [], [], []],
#              'fundlng': [[], [], [('funding', 'i', 'l')], []],
#              'upifront': [[], [('upfront', 'p', 'i')], [], []],
#              'malntalned': [[], [], [], []],
#              'admlnlstered': [[], [], [], []],
#              'transportatlon': [[], [], [('transportation', 'i', 'l')], []],
#              'dmlnlstratlons': [[], [], [], []],
#              'hemcology': [[], [], [], []],
#              'upport': [[('support', '{', 's')], [], [], []],
#              'costs': [[],
#               [('cost', 't', 's')],
#               [('posts', 'p', 'c'), ('custs', 'u', 'o'), ('costa', 'a', 's')],
#               []],
#              'lthln': [[], [], [], []],
#              'leglslatlon': [[], [], [('legislatlon', 'i', 'l')], []],
#              'underestlmated': [[], [], [('underestimated', 'i', 'l')], []],
#              'dentlfyng': [[], [], [], []],
#              'correspondents': [[], [], [], []],
#              'mllllon': [[], [], [], []],
#              'llliconcelved': [[], [], [], []],
#              'emlsslons': [[], [], [], []],
#              'sectors': [[], [('sector', 'r', 's')], [], []],
#              'partlcular': [[], [], [('particular', 'i', 'l')], []],
#              'development': [[('developments', 't', 's')],
#               [],
#               [('developaent', 'a', 'm')],
#               []],
#              'cycle': [[], [], [('cyele', 'e', 'c')], []],
#              'foundatlns': [[], [], [], []],
#              'compensatlon': [[], [], [('compensation', 'i', 'l')], []],
#              'attempts': [[], [('attempt', 't', 's')], [], []],
#              'enterprlse': [[], [], [('enterprise', 'i', 'l')], []],
#              'etrochemlcal': [[], [], [], []],
#              'mendments': [[('amendments', '{', 'a')],
#               [],
#               [('wendments', 'w', 'm')],
#               []],
#              'envlronment': [[], [], [('environment', 'i', 'l')], []],
#              'whlla': [[], [], [('whila', 'i', 'l'), ('whola', 'o', 'l')], []],
#              'onltorlng': [[], [], [], []],
#              'compounds': [[], [('compound', 'd', 's')], [], []],
#              'prellmlnary': [[], [], [], []],
#              'amendments': [[],
#               [('mendments', '{', 'a'), ('amendment', 't', 's')],
#               [],
#               []],
#              'eslns': [[], [], [], []],
#              'tandard': [[('standard', '{', 's')], [], [], []],
#              'organlzatlon': [[], [], [], []],
#              'hemlcal': [[], [], [('hemical', 'i', 'l')], []],
#              'developlng': [[], [], [('developing', 'i', 'l')], []],
#              'plants': [[('plaints', 'a', 'i')],
#               [('plans', 'n', 't'), ('plant', 't', 's')],
#               [],
#               []],
#              'declslon': [[], [], [], []],
#              'offlclals': [[], [], [], []],
#              'conducted': [[], [], [], []],
#              'conslstently': [[], [], [('consistently', 'i', 'l')], []],
#              'recommended': [[],
#               [('ecommended', '{', 'r'),
#                ('recomended', 'o', 'm'),
#                ('recomended', 'o', 'm')],
#               [('reconmended', 'n', 'm'), ('recomnended', 'n', 'm')],
#               []],
#              'ommlttees': [[], [], [], []],
#              'durlng': [[], [], [('during', 'i', 'l')], []],
#              'representatlves': [[],
#               [('representatves', 't', 'l')],
#               [('representatives', 'i', 'l')],
#               []],
#              'presently': [[], [], [], []],
#              'prograsts': [[], [], [], []],
#              'dlalkyl': [[('dlnalkyl', 'l', 'n')],
#               [],
#               [('dialkyl', 'i', 'l')],
#               []],
#              'chronlc': [[], [], [('chronic', 'i', 'l')], []],
#              'b': [[('ab', '{', 'a'),
#                ('cb', '{', 'c'),
#                ('eb', '{', 'e'),
#                ('hb', '{', 'h'),
#                ('mb', '{', 'm'),
#                ('ob', '{', 'o'),
#                ('sb', '{', 's'),
#                ('tb', '{', 't'),
#                ('ba', 'b', 'a'),
#                ('bd', 'b', 'd'),
#                ('be', 'b', 'e'),
#                ('bf', 'b', 'f'),
#                ('bg', 'b', 'g'),
#                ('bn', 'b', 'n'),
#                ('bp', 'b', 'p'),
#                ('bs', 'b', 's'),
#                ('bt', 'b', 't'),
#                ('bu', 'b', 'u'),
#                ('bv', 'b', 'v'),
#                ('by', 'b', 'y')],
#               [],
#               [],
#               []],
#              'mg': [[('img', '{', 'i'), ('mag', 'm', 'a')],
#               [],
#               [('ag', 'a', 'm'),
#                ('bg', 'b', 'm'),
#                ('cg', 'c', 'm'),
#                ('eg', 'e', 'm'),
#                ('gg', 'g', 'm'),
#                ('ng', 'n', 'm'),
#                ('tg', 't', 'm'),
#                ('ma', 'a', 'g'),
#                ('mb', 'b', 'g'),
#                ('mc', 'c', 'g'),
#                ('md', 'd', 'g'),
#                ('me', 'e', 'g'),
#                ('mi', 'i', 'g'),
#                ('mm', 'm', 'g'),
#                ('mn', 'n', 'g'),
#                ('mo', 'o', 'g'),
#                ('mr', 'r', 'g'),
#                ('ms', 's', 'g'),
#                ('mt', 't', 'g'),
#                ('my', 'y', 'g')],
#               [('gm', 'g', 'm')]],
#              'lnners': [[], [], [('liners', 'i', 'n')], []],
#              'portlons': [[], [], [('portions', 'i', 'l')], []],
#              'sult': [[], [], [('salt', 'a', 'u'), ('suit', 'i', 'l')], []],
#              'performance': [[], [], [], []],
#              'arrh': [[('karrh', '{', 'k')], [], [('arch', 'c', 'r')], []],
#              'osnlttee': [[('cosnlttee', '{', 'c')], [], [], []],
#              'echnologles': [[], [], [], []],
#              'currently': [[], [], [('currantly', 'a', 'e')], []],
#              'examlners': [[], [], [('examiners', 'i', 'l')], []],
#              'evertheless': [[('nevertheless', '{', 'n')], [], [], []],
#              'recognlzlng': [[], [], [], []],
#              'dmlnlstratlon': [[], [], [], []],
#              'petrochemlcal': [[], [], [('petrochemical', 'i', 'l')], []],
#              'nvlronmental': [[('envlronmental', '{', 'e')], [], [], []],
#              'm': [[('am', '{', 'a'),
#                ('cm', '{', 'c'),
#                ('em', '{', 'e'),
#                ('gm', '{', 'g'),
#                ('hm', '{', 'h'),
#                ('im', '{', 'i'),
#                ('mm', 'm', 'm'),
#                ('pm', '{', 'p'),
#                ('rm', '{', 'r'),
#                ('sm', '{', 's'),
#                ('wm', '{', 'w'),
#                ('xm', '{', 'x'),
#                ('ma', 'm', 'a'),
#                ('mb', 'm', 'b'),
#                ('mc', 'm', 'c'),
#                ('md', 'm', 'd'),
#                ('me', 'm', 'e'),
#                ('mg', 'm', 'g'),
#                ('mi', 'm', 'i'),
#                ('mm', 'm', 'm'),
#                ('mn', 'm', 'n'),
#                ('mo', 'm', 'o'),
#                ('mr', 'm', 'r'),
#                ('ms', 'm', 's'),
#                ('mt', 'm', 't'),
#                ('my', 'm', 'y')],
#               [],
#               [],
#               []],
#              'couldnt': [[], [], [('wouldnt', 'w', 'c')], []],
#              'hlorlde': [[], [], [], []],
#              'llllon': [[], [], [], []],
#              'forestall': [[], [], [], []],
#              'roceedlngs': [[], [], [], []],
#              'unplementlng': [[], [], [], []],
#              'estrlcted': [[], [], [], []],
#              'coordlnate': [[], [], [('coordinate', 'i', 'l')], []],
#              'prosecutlon': [[], [], [('prosecution', 'i', 'l')], []],
#              'lled': [[],
#               [('led', '{', 'l'), ('led', '{', 'l')],
#               [('pled', 'p', 'l')],
#               []],
#              'equlpment': [[], [], [('equipment', 'i', 'l')], []],
#              'ntervlews': [[], [], [], []],
#              'lrector': [[], [], [], []],
#              'statements': [[], [('statement', 't', 's')], [], []],
#              'owp': [[],
#               [('op', 'o', 'w')],
#               [('qwp', 'q', 'o'), ('own', 'n', 'p')],
#               []],
#              'membershlp': [[], [], [('membership', 'i', 'l')], []],
#              'short': [[],
#               [('sort', 's', 'h')],
#               [('shoot', 'o', 'r'), ('shora', 'a', 't'), ('shore', 'e', 't')],
#               []],
#              'meanlngful': [[], [], [('meaningful', 'i', 'l')], []],
#              'attrlbuted': [[], [], [('attributed', 'i', 'l')], []],
#              'actlvltles': [[], [], [], []],
#              'k': [[('ak', '{', 'a'),
#                ('kk', 'k', 'k'),
#                ('ok', '{', 'o'),
#                ('rk', '{', 'r'),
#                ('sk', '{', 's'),
#                ('uk', '{', 'u'),
#                ('kk', 'k', 'k'),
#                ('ks', 'k', 's'),
#                ('ky', 'k', 'y')],
#               [],
#               [],
#               []],
#              'llmlted': [[], [], [], []],
#              'agreements': [[], [('agreement', 't', 's')], [], []],
#              'collected': [[], [], [], []],
#              'complete': [[('completed', 'e', 'd'), ('completes', 'e', 's')],
#               [('comlete', 'm', 'p'), ('compete', 'p', 'l')],
#               [],
#               []],
#              'anufacturers': [[('manufacturers', '{', 'm')], [], [], []],
#              'yron': [[('byron', '{', 'b'), ('myron', '{', 'm')],
#               [('ron', '{', 'y')],
#               [('iron', 'i', 'y'), ('yoon', 'o', 'r')],
#               []],
#              'hlle': [[], [], [], []],
#              'substantlal': [[], [], [('substantial', 'i', 'l')], []],
#              'testlfy': [[], [], [('testify', 'i', 'l')], []],
#              'ntends': [[('intends', '{', 'i')],
#               [('tends', '{', 'n')],
#               [],
#               []],
#              'lanchard': [[('blanchard', '{', 'b')], [], [], []],
#              'nonitarlff': [[], [], [], []],
#              'prtcularly': [[], [], [], []],
#              'coordlnates': [[], [], [('coordinates', 'i', 'l')], []],
#              'convlnced': [[], [], [('convinced', 'i', 'l')], []],
#              'contlnued': [[], [], [('continued', 'i', 'l')], []],
#              'unprovement': [[], [], [], []],
#              'retalned': [[], [], [('retained', 'i', 'l')], []],
#              'xecutlve': [[], [], [], []],
#              'overnment': [[('government', '{', 'g')], [], [], []],
#              'tarlffs': [[], [], [('tariffs', 'i', 'l')], []],
#              'llterture': [[], [], [], []],
#              'effectlve': [[], [], [('effective', 'i', 'l')], []],
#              'draft': [[('drafts', 't', 's')], [], [], []],
#              'authorlzed': [[], [], [('authorized', 'i', 'l')], []],
#              'obllgatlon': [[], [], [], []],
#              'recommendatlons': [[], [], [('recommendations', 'i', 'l')], []],
#              'promlses': [[], [], [('promises', 'i', 'l')], []],
#              'contacts': [[('contracts', 't', 'r')],
#               [('contact', 't', 's')],
#               [('coatacts', 'a', 'n')],
#               []],
#              'concerns': [[], [('concern', 'n', 's')], [], []],
#              'pllls': [[], [], [('polls', 'o', 'l')], []],
#              'hlte': [[], [], [], []],
#              'mmedlate': [[], [], [], []],
#              'merlcan': [[], [], [], []],
#              'preparatlon': [[], [], [('preparation', 'i', 'l')], []],
#              'alternatlve': [[], [], [('alternative', 'i', 'l')], []],
#              'nd': [[('and', '{', 'a'),
#                ('dnd', '{', 'd'),
#                ('end', '{', 'e'),
#                ('ind', '{', 'i'),
#                ('rnd', '{', 'r'),
#                ('snd', '{', 's'),
#                ('und', '{', 'u'),
#                ('nad', 'n', 'a'),
#                ('ned', 'n', 'e')],
#               [],
#               [('ad', 'a', 'n'),
#                ('bd', 'b', 'n'),
#                ('ed', 'e', 'n'),
#                ('fd', 'f', 'n'),
#                ('id', 'i', 'n'),
#                ('jd', 'j', 'n'),
#                ('md', 'm', 'n'),
#                ('rd', 'r', 'n'),
#                ('sd', 's', 'n'),
#                ('td', 't', 'n'),
#                ('vd', 'v', 'n'),
#                ('nc', 'c', 'd'),
#                ('ne', 'e', 'd'),
#                ('ng', 'g', 'd'),
#                ('nh', 'h', 'd'),
#                ('nj', 'j', 'd'),
#                ('nl', 'l', 'd'),
#                ('nn', 'n', 'd'),
#                ('no', 'o', 'd'),
#                ('ns', 's', 'd'),
#                ('nt', 't', 'd'),
#                ('nw', 'w', 'd'),
#                ('nx', 'x', 'd'),
#                ('ny', 'y', 'd')],
#               []],
#              'rlghts': [[], [], [('rights', 'i', 'l')], []],
#              't': [[('at', '{', 'a'),
#                ('bt', '{', 'b'),
#                ('ct', '{', 'c'),
#                ('et', '{', 'e'),
#                ('ft', '{', 'f'),
#                ('ht', '{', 'h'),
#                ('it', '{', 'i'),
#                ('lt', '{', 'l'),
#                ('mt', '{', 'm'),
#                ('nt', '{', 'n'),
#                ('rt', '{', 'r'),
#                ('st', '{', 's'),
#                ('tt', 't', 't'),
#                ('ut', '{', 'u'),
#                ('xt', '{', 'x'),
#                ('ta', 't', 'a'),
#                ('tb', 't', 'b'),
#                ('tc', 't', 'c'),
#                ('td', 't', 'd'),
#                ('te', 't', 'e'),
#                ('tg', 't', 'g'),
#                ('th', 't', 'h'),
#                ('ti', 't', 'i'),
#                ('tl', 't', 'l'),
#                ('tn', 't', 'n'),
#                ('to', 't', 'o'),
#                ('tr', 't', 'r'),
#                ('ts', 't', 's'),
#                ('tt', 't', 't'),
#                ('tv', 't', 'v'),
#                ('tx', 't', 'x'),
#                ('ty', 't', 'y')],
#               [],
#               [],
#               []],
#              'sort': [[('short', 's', 'h')],
#               [],
#               [('cort', 'c', 's'),
#                ('fort', 'f', 's'),
#                ('port', 'p', 's'),
#                ('tort', 't', 's'),
#                ('sore', 'e', 't')],
#               []],
#              'g': [[('ag', '{', 'a'),
#                ('bg', '{', 'b'),
#                ('cg', '{', 'c'),
#                ('eg', '{', 'e'),
#                ('gg', 'g', 'g'),
#                ('mg', '{', 'm'),
#                ('ng', '{', 'n'),
#                ('tg', '{', 't'),
#                ('ga', 'g', 'a'),
#                ('ge', 'g', 'e'),
#                ('gf', 'g', 'f'),
#                ('gg', 'g', 'g'),
#                ('gm', 'g', 'm'),
#                ('go', 'g', 'o'),
#                ('gr', 'g', 'r'),
#                ('gs', 'g', 's')],
#               [],
#               [],
#               []],
#              'nvlronment': [[], [], [], []],
#              'verslght': [[], [], [], []],
#              'ncludes': [[('includes', '{', 'i')], [], [], []],
#              'cooperatlon': [[], [], [('cooperation', 'i', 'l')], []],
#              'slmpllclty': [[], [], [], []],
#              'purchased': [[],
#               [('purchase', 'e', 'd')],
#               [('purchases', 's', 'd')],
#               []],
#              'task': [[('tasks', 'k', 's')],
#               [('ask', '{', 't'), ('tsk', 't', 'a')],
#               [('cask', 'c', 't'),
#                ('talk', 'l', 's'),
#                ('tank', 'n', 's'),
#                ('tasa', 'a', 'k'),
#                ('tasi', 'i', 'k'),
#                ('tast', 't', 'k')],
#               []],
#              'ystem': [[('system', '{', 's')], [('stem', '{', 'y')], [], []],
#              'workers': [[], [('worker', 'r', 's')], [], []],
#              'communlcatlng': [[], [], [], []],
#              'expertlse': [[], [], [('expertise', 'i', 'l')], []],
#              'process': [[], [], [], []],
#              'chloroethylene': [[], [], [], []],
#              'nstances': [[('instances', '{', 'i')],
#               [('stances', '{', 'n')],
#               [],
#               []],
#              'dlfferlng': [[], [], [], []],
#              'penallzed': [[], [], [('penalized', 'i', 'l')], []],
#              'ntroductlon': [[], [], [], []],
#              'facllltatlng': [[], [], [], []],
#              'provlded': [[], [], [('provided', 'i', 'l')], []],
#              'pertlnent': [[], [], [('pertinent', 'i', 'l')], []],
#              'd': [[('ad', '{', 'a'),
#                ('bd', '{', 'b'),
#                ('ed', '{', 'e'),
#                ('fd', '{', 'f'),
#                ('id', '{', 'i'),
#                ('jd', '{', 'j'),
#                ('md', '{', 'm'),
#                ('nd', '{', 'n'),
#                ('rd', '{', 'r'),
#                ('sd', '{', 's'),
#                ('td', '{', 't'),
#                ('vd', '{', 'v'),
#                ('da', 'd', 'a'),
#                ('dc', 'd', 'c'),
#                ('de', 'd', 'e'),
#                ('di', 'd', 'i'),
#                ('dl', 'd', 'l'),
#                ('do', 'd', 'o'),
#                ('dr', 'd', 'r'),
#                ('du', 'd', 'u')],
#               [],
#               [],
#               []],
#              'posslbly': [[],
#               [],
#               [('poaslbly', 'a', 's'), ('possibly', 'i', 'l')],
#               []],
#              'appearances': [[], [('appearance', 'e', 's')], [], []],
#              'passlng': [[], [], [('passing', 'i', 'l')], []],
#              'imposltlln': [[], [], [], []],
#              'an': [[('ban', '{', 'b'),
#                ('can', '{', 'c'),
#                ('dan', '{', 'd'),
#                ('jan', '{', 'j'),
#                ('man', '{', 'm'),
#                ('ran', '{', 'r'),
#                ('san', '{', 's'),
#                ('tan', '{', 't'),
#                ('van', '{', 'v'),
#                ('ann', 'n', 'n'),
#                ('ana', 'n', 'a'),
#                ('and', 'n', 'd'),
#                ('ann', 'n', 'n'),
#                ('ano', 'n', 'o'),
#                ('ant', 'n', 't'),
#                ('anv', 'n', 'v'),
#                ('any', 'n', 'y')],
#               [],
#               [('bn', 'b', 'a'),
#                ('cn', 'c', 'a'),
#                ('en', 'e', 'a'),
#                ('in', 'i', 'a'),
#                ('ln', 'l', 'a'),
#                ('mn', 'm', 'a'),
#                ('nn', 'n', 'a'),
#                ('on', 'o', 'a'),
#                ('tn', 't', 'a'),
#                ('un', 'u', 'a'),
#                ('wn', 'w', 'a'),
#                ('xn', 'x', 'a'),
# ...
#              'examlnatlon': [[], [], [], []],
#              'sky': [[],
#               [('ky', '{', 's'), ('sy', 's', 'k'), ('sk', 'k', 'y')],
#               [('dky', 'd', 's'), ('say', 'a', 'k'), ('sty', 't', 'k')],
#               []],
#              'aterlals': [[], [], [], []],
#              'extenslons': [[], [], [('extensions', 'i', 'l')], []],
#              'know': [[('known', 'w', 'n'), ('knows', 'w', 's')],
#               [('now', '{', 'k')],
#               [('knew', 'e', 'o')],
#               []],
#              'standards': [[], [('standard', 'd', 's')], [], []],
#              'solld': [[],
#               [('sold', 'l', 'l'), ('sold', 'l', 'l')],
#               [('solid', 'i', 'l')],
#               []],
#              'success': [[], [], [], []],
#              'forth': [[('fourth', 'o', 'u')],
#               [('fort', 't', 'h')],
#               [('north', 'n', 'f'),
#                ('worth', 'w', 'f'),
#                ('furth', 'u', 'o'),
#                ('forts', 's', 'h'),
#                ('forty', 'y', 'h')],
#               []],
#              'standard': [[('standards', 'd', 's')],
#               [('standar', 'r', 'd')],
#               [],
#               []],
#              'boycotts': [[], [('boycott', 't', 's')], [], []],
#              'governments': [[], [('government', 't', 's')], [], []],
#              'dlglycldyl': [[], [], [], []],
#              'technology': [[], [], [], []],
#              'concepts': [[],
#               [('concept', 't', 's')],
#               [('concapts', 'a', 'e')],
#               []],
#              'polltlcal': [[], [], [], []],
#              'ssessment': [[('assessment', '{', 'a')],
#               [('sessment', '{', 's'), ('sessment', '{', 's')],
#               [],
#               []],
#              'assessment': [[('assessments', 't', 's')],
#               [],
#               [('assessaent', 'a', 'm')],
#               []],
#              'stateonly': [[], [], [], []],
#              'quallfled': [[], [], [], []],
#              'projects': [[],
#               [('project', 't', 's')],
#               [('protects', 't', 'j')],
#               []],
#              'reforms': [[], [('reform', 'm', 's')], [], []],
#              'epresentatlves': [[], [], [], []],
#              'carbons': [[],
#               [('carbon', 'n', 's')],
#               [('carboys', 'y', 'n')],
#               []],
#              'ithln': [[], [], [], []],
#              'ommunlcatlon': [[], [], [], []],
#              'days': [[],
#               [('ays', '{', 'd'), ('day', 'y', 's')],
#               [('hays', 'h', 'd'),
#                ('pays', 'p', 'd'),
#                ('says', 's', 'd'),
#                ('ways', 'w', 'd'),
#                ('dams', 'm', 'y')],
#               []],
#              'broadibased': [[], [('broadbased', 'd', 'i')], [], []],
#              'lrcult': [[], [], [], []],
#              'department': [[('departments', 't', 's')],
#               [],
#               [('departaent', 'a', 'm')],
#               []],
#              'dellberatlons': [[], [], [], []],
#              'grass': [[],
#               [('gras', 's', 's'), ('gras', 's', 's')],
#               [('prass', 'p', 'g'),
#                ('glass', 'l', 'r'),
#                ('gross', 'o', 'a'),
#                ('grams', 'm', 's')],
#               []],
#              'credlt': [[],
#               [],
#               [('cradlt', 'a', 'e'), ('credit', 'i', 'l')],
#               []],
#              'flnanclal': [[], [], [], []],
#              'llutants': [[], [], [], []],
#              'staffs': [[],
#               [('staff', 'f', 's')],
#               [('stafas', 'a', 'f'), ('stafff', 'f', 's')],
#               []],
#              'potentlal': [[], [], [('potential', 'i', 'l')], []],
#              'presentatlon': [[], [], [('presentation', 'i', 'l')], []],
#              'to': [[('pto', '{', 'p'),
#                ('qto', '{', 'q'),
#                ('too', 'o', 'o'),
#                ('two', 't', 'w'),
#                ('tom', 'o', 'm'),
#                ('ton', 'o', 'n'),
#                ('too', 'o', 'o'),
#                ('top', 'o', 'p'),
#                ('tor', 'o', 'r'),
#                ('toy', 'o', 'y')],
#               [],
#               [('co', 'c', 't'),
#                ('do', 'd', 't'),
#                ('eo', 'e', 't'),
#                ('fo', 'f', 't'),
#                ('go', 'g', 't'),
#                ('ho', 'h', 't'),
#                ('jo', 'j', 't'),
#                ('mo', 'm', 't'),
#                ('no', 'n', 't'),
#                ('po', 'p', 't'),
#                ('ro', 'r', 't'),
#                ('so', 's', 't'),
#                ('ta', 'a', 'o'),
#                ('tb', 'b', 'o'),
#                ('tc', 'c', 'o'),
#                ('td', 'd', 'o'),
#                ('te', 'e', 'o'),
#                ('tg', 'g', 'o'),
#                ('th', 'h', 'o'),
#                ('ti', 'i', 'o'),
#                ('tl', 'l', 'o'),
#                ('tn', 'n', 'o'),
#                ('tr', 'r', 'o'),
#                ('ts', 's', 'o'),
#                ('tt', 't', 'o'),
#                ('tv', 'v', 'o'),
#                ('tx', 'x', 'o'),
#                ('ty', 'y', 'o')],
#               []],
#              'constltuents': [[], [], [('constituents', 'i', 'l')], []],
#              'eorganlzatlon': [[], [], [], []],
#              'dlsruptlon': [[], [], [], []],
#              'tlon': [[], [('ton', 't', 'l')], [('tion', 'i', 'l')], []],
#              'hlnge': [[], [], [('hinge', 'i', 'l')], []],
#              'commltment': [[], [], [('commitment', 'i', 'l')], []],
#              'purvlew': [[], [], [('purview', 'i', 'l')], []],
#              'succeedlng': [[], [], [('succeeding', 'i', 'l')], []],
#              'stagnant': [[], [], [], []],
#              'justlfy': [[], [], [('justify', 'i', 'l')], []],
#              'publlcs': [[], [], [('publics', 'i', 'l')], []],
#              'rlghtitoiknow': [[], [], [], []],
#              'mphasls': [[], [], [], []],
#              'monltored': [[], [], [('monitored', 'i', 'l')], []],
#              'supplemental': [[], [], [], []],
#              'lngredlents': [[], [], [], []],
#              'reasslgned': [[], [], [('reassigned', 'i', 'l')], []],
#              'ommerce': [[('commerce', '{', 'c')], [], [], []],
#              'overnmental': [[('governmental', '{', 'g')], [], [], []],
#              'sters': [[('esters', '{', 'e')],
#               [('ters', '{', 's')],
#               [('stars', 'a', 'e'), ('steps', 'p', 'r')],
#               []],
#              'consolldatlon': [[], [], [], []],
#              'checkllst': [[], [], [('checklist', 'i', 'l')], []],
#              'ackground': [[('background', '{', 'b')], [], [], []],
#              'countrles': [[], [], [('countries', 'i', 'l')], []],
#              'flxed': [[], [], [('fixed', 'i', 'l')], []],
#              'in': [[('din', '{', 'd'),
#                ('min', '{', 'm'),
#                ('rin', '{', 'r'),
#                ('sin', '{', 's'),
#                ('win', '{', 'w'),
#                ('ign', 'i', 'g'),
#                ('ion', 'i', 'o'),
#                ('inc', 'n', 'c'),
#                ('ind', 'n', 'd'),
#                ('inf', 'n', 'f'),
#                ('ing', 'n', 'g'),
#                ('ink', 'n', 'k'),
#                ('int', 'n', 't'),
#                ('inv', 'n', 'v')],
#               [],
#               [('an', 'a', 'i'),
#                ('bn', 'b', 'i'),
#                ('cn', 'c', 'i'),
#                ('en', 'e', 'i'),
#                ('ln', 'l', 'i'),
#                ('mn', 'm', 'i'),
#                ('nn', 'n', 'i'),
#                ('on', 'o', 'i'),
#                ('tn', 't', 'i'),
#                ('un', 'u', 'i'),
#                ('wn', 'w', 'i'),
#                ('xn', 'x', 'i'),
#                ('zn', 'z', 'i'),
#                ('ia', 'a', 'n'),
#                ('ic', 'c', 'n'),
#                ('id', 'd', 'n'),
#                ('ie', 'e', 'n'),
#                ('if', 'f', 'n'),
#                ('ii', 'i', 'n'),
#                ('il', 'l', 'n'),
#                ('im', 'm', 'n'),
#                ('ir', 'r', 'n'),
#                ('is', 's', 'n'),
#                ('it', 't', 'n'),
#                ('iv', 'v', 'n'),
#                ('ix', 'x', 'n'),
#                ('iy', 'y', 'n')],
#               []],
#              'gencys': [[('agencys', '{', 'a')],
#               [('gency', 'y', 's')],
#               [],
#               []],
#              'mplemented': [[('implemented', '{', 'i')], [], [], []],
#              'luorocarbon': [[('fluorocarbon', '{', 'f')], [], [], []],
#              'pollutlonipreventlon': [[], [], [], []],
#              'ncontent': [[], [('content', '{', 'n')], [], []],
#              'analyzlng': [[], [], [('analyzing', 'i', 'l')], []],
#              'orks': [[('vorks', '{', 'v'), ('works', '{', 'w')],
#               [('rks', '{', 'o')],
#               [('ores', 'e', 'k')],
#               []],
#              'radlng': [[], [], [], []],
#              'carefully': [[], [], [], []],
#              'counterpart': [[('counterparts', 't', 's')], [], [], []],
#              'opportunlty': [[], [], [('opportunity', 'i', 'l')], []],
#              'consldered': [[], [], [('considered', 'i', 'l')], []],
#              'lssuas': [[],
#               [],
#               [('issuas', 'i', 'l'), ('lsauas', 'a', 's')],
#               []],
#              'shows': [[],
#               [('sows', 's', 'h'), ('show', 'w', 's')],
#               [('shops', 'p', 'w'),
#                ('shots', 't', 'w'),
#                ('showa', 'a', 's'),
#                ('shown', 'n', 's')],
#               []],
#              'partlclpate': [[], [], [], []],
#              'spectrum': [[], [], [], []],
#              'bulletln': [[], [], [('bulletin', 'i', 'l')], []],
#              'resldentlal': [[], [], [], []],
#              'subjects': [[], [('subject', 't', 's')], [], []],
#              'lslbly': [[], [], [], []],
#              'communlcatl': [[], [], [], []],
#              'ubsldlze': [[], [], [], []],
#              'approplate': [[], [], [], []],
#              'malntenance': [[], [], [('maintenance', 'i', 'l')], []],
#              'allfornla': [[], [], [], []],
#              'ashlngton': [[], [], [], []],
#              'eventles': [[], [], [], []],
#              'tandards': [[('standards', '{', 's')], [], [], []],
#              'atlng': [[], [], [('ating', 'i', 'l')], []],
#              'lass': [[('class', '{', 'c'), ('glass', '{', 'g')],
#               [('ass', '{', 'l'), ('las', 's', 's'), ('las', 's', 's')],
#               [('bass', 'b', 'l'),
#                ('fass', 'f', 'l'),
#                ('mass', 'm', 'l'),
#                ('pass', 'p', 'l'),
#                ('less', 'e', 'a'),
#                ('loss', 'o', 'a'),
#                ('labs', 'b', 's'),
#                ('lags', 'g', 's'),
#                ('laus', 'u', 's'),
#                ('lavs', 'v', 's'),
#                ('laws', 'w', 's'),
#                ('last', 't', 's')],
#               []],
#              'questlons': [[], [], [('questions', 'i', 'l')], []],
#              'stockholders': [[], [('stockholder', 'r', 's')], [], []],
#              'suggestlon': [[], [], [('suggestion', 'i', 'l')], []],
#              'protectlon': [[], [], [('protection', 'i', 'l')], []],
#              'sclentlflc': [[], [], [], []],
#              'constltuent': [[], [], [('constituent', 'i', 'l')], []],
#              'ommlsslons': [[], [], [], []],
#              'ross': [[('cross', '{', 'c'), ('gross', '{', 'g')],
#               [],
#               [('boss', 'b', 'r'),
#                ('loss', 'l', 'r'),
#                ('moss', 'm', 'r'),
#                ('roes', 'e', 's'),
#                ('rose', 'e', 's')],
#               []],
#              'slces': [[], [], [('sices', 'i', 'l')], []],
#              'reporters': [[], [('reporter', 'r', 's')], [], []],
#              'faclng': [[], [], [('facing', 'i', 'l')], []],
#              'lrkpatrlck': [[], [], [], []],
#              'artlclpatlng': [[], [], [], []],
#              'onnlttee': [[('connlttee', '{', 'c')], [], [], []],
#              'sentencey': [[],
#               [('sentence', 'e', 'y')],
#               [('sentences', 's', 'y')],
#               []],
#              'tarlff': [[], [], [('tariff', 'i', 'l')], []],
#              'dlscuss': [[], [], [('discuss', 'i', 'l')], []],
#              'teleconference': [[('teleconferences', 'e', 's')], [], [], []],
#              'laglslatlva': [[], [], [], []],
#              'mlgratlon': [[], [], [], []],
#              'teelworkers': [[('steelworkers', '{', 's')], [], [], []],
#              'relatlvly': [[], [], [], []],
#              'nell': [[('snell', '{', 's')],
#               [('ell', '{', 'n')],
#               [('bell', 'b', 'n'),
#                ('cell', 'c', 'n'),
#                ('fell', 'f', 'n'),
#                ('hell', 'h', 'n'),
#                ('sell', 's', 'n'),
#                ('tell', 't', 'n'),
#                ('well', 'w', 'n')],
#               []],
#              'expanslon': [[], [], [('expansion', 'i', 'l')], []],
#              'orlglnal': [[], [], [], []],
#              'fugltlve': [[], [], [], []],
#              'dvlsory': [[], [], [], []],
#              'urrently': [[('currently', '{', 'c')], [], [], []],
#              'strlkes': [[], [], [('strikes', 'i', 'l')], []],
#              'wlshes': [[], [], [('wishes', 'i', 'l')], []],
#              'extractlon': [[], [], [('extraction', 'i', 'l')], []],
#              'antlclpatlng': [[], [], [], []],
#              'coordlnator': [[], [], [('coordinator', 'i', 'l')], []],
#              'cosmetlc': [[], [], [('cosmetic', 'i', 'l')], []],
#              'ndvdual': [[], [], [], []],
#              'preempt': [[('preempts', 't', 's')],
#               [('reempt', '{', 'p')],
#               [],
#               []],
#              'months': [[], [('month', 'h', 's')], [('aonths', 'a', 'm')], []],
#              'tlnulng': [[], [], [], []],
#              'ltems': [[], [('lems', 'l', 't')], [('items', 'i', 'l')], []],
#              'submltted': [[],
#               [],
#               [('subaltted', 'a', 'm'), ('submitted', 'i', 'l')],
#               []],
#              'nterventlon': [[], [], [], []],
#              'ntarnatlonal': [[('intarnatlonal', '{', 'i')], [], [], []],
#              'survelllance': [[], [], [('surveillance', 'i', 'l')], []],
#              'partlc': [[],
#               [],
#               [('partic', 'i', 'l'), ('partly', 'y', 'c')],
#               []],
#              'professlon': [[], [], [('profession', 'i', 'l')], []],
#              'notlflcatlon': [[], [], [], []],
#              'prlmarlly': [[], [], [('prlaarlly', 'a', 'm')], []],
#              'consequences': [[], [('consequence', 'e', 's')], [], []],
#              'nlon': [[], [('non', 'n', 'l')], [('noon', 'o', 'l')], []],
#              'oalltlon': [[], [], [], []],
#              'ssoctlon': [[], [], [], []],
#              'nc': [[('dnc', '{', 'd'),
#                ('inc', '{', 'i'),
#                ('rnc', '{', 'r'),
#                ('nac', 'n', 'a'),
#                ('nbc', 'n', 'b'),
#                ('nec', 'n', 'e'),
#                ('noc', 'n', 'o'),
#                ('nrc', 'n', 'r'),
#                ('nci', 'c', 'i'),
#                ('ncp', 'c', 'p'),
#                ('ncy', 'c', 'y')],
#               [],
#               [('ac', 'a', 'n'),
#                ('cc', 'c', 'n'),
#                ('dc', 'd', 'n'),
#                ('ec', 'e', 'n'),
#                ('fc', 'f', 'n'),
#                ('hc', 'h', 'n'),
#                ('ic', 'i', 'n'),
#                ('jc', 'j', 'n'),
#                ('mc', 'm', 'n'),
#                ('oc', 'o', 'n'),
#                ('sc', 's', 'n'),
#                ('tc', 't', 'n'),
#                ('vc', 'v', 'n'),
#                ('wc', 'w', 'n'),
#                ('nd', 'd', 'c'),
#                ('ne', 'e', 'c'),
#                ('ng', 'g', 'c'),
#                ('nh', 'h', 'c'),
#                ('nj', 'j', 'c'),
#                ('nl', 'l', 'c'),
#                ('nn', 'n', 'c'),
#                ('no', 'o', 'c'),
#                ('ns', 's', 'c'),
#                ('nt', 't', 'c'),
#                ('nw', 'w', 'c'),
#                ('nx', 'x', 'c'),
#                ('ny', 'y', 'c')],
#               [('cn', 'c', 'n')]],
#              'nvestments': [[('investments', '{', 'i')], [], [], []],
#              'subcommlttee': [[], [], [('subcommittee', 'i', 'l')], []],
#              ...})

# %%
word_freqs = collections.defaultdict(int)
for word in word_list:
    word_freqs[word] += 1
# print(dict((k, v) for k, v in word_freqs.items() if v >= 2))

# Pr(c) of all possible corrections (all words from ground truth)
word_freqs_freqs = {}
for freqs in word_freqs.values():
    if freqs in word_freqs_freqs.keys():
        word_freqs_freqs[freqs] += 1
    else:
        word_freqs_freqs[freqs] = 1
word_freqsN = {}
for k in word_freqs_freqs.keys():
    if k + 1  in word_freqs_freqs.keys():
        word_freqsN[k+1] = word_freqs_freqs[k+1]
    else:
        word_freqsN[k+1] = 0.5
N1 = 0
for j in word_freqsN.keys():
    N1 = N1 + j*word_freqsN[j]
word_freqs_freqsfinal = {}
for k in word_freqs_freqs.keys():
    word_freqs_freqsfinal[k] = word_freqs_freqs[k]
    if k + 1  in word_freqs_freqs.keys():
        word_freqs_freqsfinal[k+1] = word_freqs_freqs[k+1]
    else:
        word_freqs_freqsfinal[k+1] = 0.5

corr_probs_mle = collections.defaultdict(float)
for word, freq in word_freqs.items():
    corr_probs_mle[word] =freq/N
corr_probs_ele = collections.defaultdict(float)
for word, freq in word_freqs.items():
    corr_probs_ele[word] = (freq + 0.5)/denominator
corr_probs_gt = collections.defaultdict(float)
for word, freq in word_freqs.items():
    corr_probs_gt[word] = (freq + 1)*word_freqs_freqsfinal[freqs + 1]/word_freqs_freqsfinal[freqs]/N1

# %%
def get_Pr_c(correction,method):
    if correction:
        if method == "MLe":
            return(corr_probs_mle[correction])
        elif method == "ELE":
            return(corr_probs_ele[correction])
        else:
            return(corr_probs_gt[correction])
    else:
        return 0

# %%
# chars[x] and chars[xy]
# word_list=['abcdefg','awses']
chars_x = np.zeros(26)
chars_xy = np.zeros([27,26])
print(chars_xy.shape)
for word in word_list:
    for i, c in enumerate(word):
        chars_x[char_to_index(c)] += 1
        if i==0:
            chars_xy[26][char_to_index(c)] += 1
        else:
            chars_xy[char_to_index(word[i-1])][char_to_index(c)] += 1
for i in range(len(chars_xy)):
    for j in range(len(chars_xy[0])):
        if not chars_xy[i][j]:
            chars_xy[i][j] = 0.5
# Out:
# (27, 26)

# %%
def get_Pr_tc(pre, cur, error_type):
    if error_type == 'del':
        return del_matrix[char_to_index(pre)][char_to_index(cur)] \
               / chars_xy[char_to_index(pre)][char_to_index(cur)]
    if error_type == 'ins':
        return ins_matrix[char_to_index(pre)][char_to_index(cur)] \
               / chars_x[char_to_index(pre)]
    if error_type == 'sub':
        return sub_matrix[char_to_index(pre)][char_to_index(cur)] \
               / chars_x[char_to_index(pre)]
    if error_type == 'rev':
        return rev_matrix[char_to_index(pre)][char_to_index(cur)] \
               / chars_xy[char_to_index(pre)][char_to_index(cur)]

# %%
def get_Pr_context_correction(cand, left, right):
    """
   
    """
    # r_left = freq of left appearing, r_right = freq of right appearing
    r_left, r_right = 0, 0
    if cand:
        if left in neighbor_dict[cand]['left']:
            r_left = neighbor_dict[cand]['left'][left]
        if right in neighbor_dict[cand]['right']:
            r_right = neighbor_dict[cand]['right'][right]
        return(r_left*r_right)/N^2
    else:
        return 0

# %%
result = Create_Word_Pair()
word_pairs = result[:-1]
num_corrections_found_tesseract, sum_letters = result[-1][0], result[-1][1]

# %%
start = timeit.default_timer()
detected_error_tuples2 = []

for t in detected_error_tuples:
    for pair in word_pairs:
        if t[0] == pair[1]:
            detected_error_tuples2.append((t[0], pair[0], t[1], t[2]))
            break
stop = timeit.default_timer() 
print('Time:', stop - start, 'seconds')
# Out:
# Time: 0.000114714999995158 seconds

# %%
def get_final_Pr_correction(cand, typo, pre,cur,error_type, left, right, method):
    return get_Pr_c(cand,method) * get_Pr_tc(pre,cur,error_type) \
           * get_Pr_context_correction(cand, left, right)

err_type = [ 'ins','del', 'sub', 'rev']
# A dictionary of the form: typo:(ground_truth, MLE_correction, ELE_correction)
result = {}
for typo, truth, left, right in detected_error_tuples2:
    cand_poss_mle, cand_poss_ele,cand_poss_gt = [], [], []
    for e in range(4):
        for cand,pre,cur in all_candidates[typo][e]:
            mle_p = get_final_Pr_correction(cand, typo,pre,cur, err_type[e], left, right, 'MLE')
            ele_p = get_final_Pr_correction(cand, typo,pre,cur, err_type[e], left, right, 'ELE')
            gt_p = get_final_Pr_correction(cand, typo, pre,cur,err_type[e], left, right, 'GT') 
            cand_poss_mle.append((cand, mle_p))
            cand_poss_ele.append((cand, ele_p))
            cand_poss_gt.append((cand, gte_p))
    mle_best_cand = max(cand_poss_mle, key=lambda x: x[1])[0] if cand_poss_mle else ''
    ele_best_cand = max(cand_poss_ele, key=lambda x: x[1])[0] if cand_poss_ele else ''
    gt_best_cand = max(cand_poss_gt, key=lambda x: x[1])[0] if cand_poss_gt else ''
    result[typo] = (truth, mle_best_cand, ele_best_cand,gt_best_cand)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-8c5f33be357f> in <module>()
#       8     cand_poss_mle, cand_poss_ele,cand_poss_gt = [], [], []
#       9     for e in range(4):
# ---> 10         for cand,pre,cur in all_candidates[typo][e]:
#      11             mle_p = get_final_Pr_correction(cand, typo,pre,cur, err_type[e], left, right, 'MLE')
#      12             ele_p = get_final_Pr_correction(cand, typo,pre,cur, err_type[e], left, right, 'ELE')
#
# IndexError: list index out of range

# %%
detected_error_tuples2
# Out:
# [('provlde', 'provide', 'are', 'encouraged'),
#  ('ncludng', 'certain', 'are', 'encouraged'),
#  ('heavlly', 'heavily', 'are', 'encouraged'),
#  ('nvolved', 'involved', 'are', 'encouraged'),
#  ('crltlcal', 'critical', 'strongly', 'to'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('leglslators', 'legislators', 'provlde', 'needed'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('contlnue', 'continue', 'strongly', 'to'),
#  ('toxlc', 'toxic', 'member', 'are'),
#  ('preventlon', 'prevention', 'to', 'thls'),
#  ('requlres', 'requires', 'strongly', 'to'),
#  ('reportlng', 'reporting', 'encouraged', 'provlde'),
#  ('nformatlon', 'information', 'to', 'thls'),
#  ('concernlng', 'concerning', 'to', 'thls'),
#  ('ndustrys', 'industrys', 'strongly', 'to'),
#  ('rlsk', 'risk', 'network', 'companles'),
#  ('reductlon', 'reduction', 'encouraged', 'provlde'),
#  ('cessatlon', 'cessation', 'encouraged', 'provlde'),
#  ('toxlc', 'toxic', 'member', 'are'),
#  ('unportant', 'important', 'encouraged', 'provlde'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('affalrs', 'affairs', 'are', 'encouraged'),
#  ('partlclpant', 'participant', 'provlde', 'needed'),
#  ('growlng', 'growing', 'are', 'encouraged'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('nsurance', 'insurance', 'strongly', 'to'),
#  ('affalrs', 'affairs', 'are', 'encouraged'),
#  ('partlclpatlng', 'participating', 'needed', 'the'),
#  ('coalltlon', 'coalition', 'encouraged', 'provlde'),
#  ('nterested', 'interested', 'encouraged', 'provlde'),
#  ('assoclatlons', 'associations', 'thls', 'support'),
#  ('ndvdual', 'states', 'are', 'encouraged'),
#  ('leglslatlve', 'legislative', 'provlde', 'needed'),
#  ('nvolved', 'involved', 'are', 'encouraged'),
#  ('materlal', 'material', 'strongly', 'to'),
#  ('transportatlon', 'transportation', 'support', 'state'),
#  ('compensatlon', 'compensation', 'thls', 'support'),
#  ('chronlc', 'chronic', 'are', 'encouraged'),
#  ('contlnue', 'continue', 'strongly', 'to'),
#  ('closmg', 'closing', 'companles', 'strongly'),
#  ('attentlon', 'attention', 'encouraged', 'provlde'),
#  ('annlversary', 'anniversary', 'provlde', 'needed'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('analysls', 'analysis', 'strongly', 'to'),
#  ('headllnes', 'headlines', 'encouraged', 'provlde'),
#  ('reauthoratlon', 'reauthoriation', 'needed', 'the'),
#  ('galned', 'gained', 'companles', 'strongly'),
#  ('attentlon', 'attention', 'encouraged', 'provlde'),
#  ('ntruslon', 'intrusion', 'strongly', 'to'),
#  ('reconclllatlon', 'reconciliation', 'support', 'state'),
#  ('attentlon', 'attention', 'encouraged', 'provlde'),
#  ('fom', 'form', 'communlcatlons', 'member'),
#  ('edltorlal', 'editorial', 'encouraged', 'provlde'),
#  ('mlght', 'might', 'member', 'are'),
#  ('antlclpated', 'anticipated', 'provlde', 'needed'),
#  ('followlng', 'following', 'encouraged', 'provlde'),
#  ('ntense', 'intense', 'companles', 'strongly'),
#  ('inltlal', 'initial', 'are', 'encouraged'),
#  ('nterest', 'interest', 'are', 'encouraged'),
#  ('potentlal', 'potential', 'encouraged', 'provlde'),
#  ('nadequacy', 'inadequacy', 'encouraged', 'provlde'),
#  ('exlstlng', 'existing', 'strongly', 'to'),
#  ('questlon', 'question', 'strongly', 'to'),
#  ('attentlon', 'attention', 'encouraged', 'provlde'),
#  ('thelr', 'their', 'member', 'are'),
#  ('retrospectlve', 'retrospective', 'needed', 'the'),
#  ('illlnols', 'illinois', 'strongly', 'to'),
#  ('dhlo', 'ohio', 'network', 'companles'),
#  ('pennsylvanla', 'pennsylvania', 'thls', 'support'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('deslgn', 'design', 'companles', 'strongly'),
#  ('attentlon', 'attention', 'encouraged', 'provlde'),
#  ('ncluded', 'included', 'are', 'encouraged'),
#  ('chronlc', 'chronic', 'are', 'encouraged'),
#  ('communltles', 'communities', 'provlde', 'needed'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('relatlng', 'relating', 'strongly', 'to'),
#  ('bhopalalr', 'bhopalair', 'encouraged', 'provlde'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('responslve', 'responsive', 'to', 'thls'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('thelr', 'their', 'member', 'are'),
#  ('llttle', 'little', 'companles', 'strongly'),
#  ('relatlonshlp', 'relationship', 'thls', 'support'),
#  ('marltlme', 'maritime', 'strongly', 'to'),
#  ('commlsslon', 'commission', 'to', 'thls'),
#  ('vlctory', 'victory', 'are', 'encouraged'),
#  ('brlefs', 'briefs', 'companles', 'strongly'),
#  ('affldavlts', 'affidavits', 'to', 'thls'),
#  ('admlnlstratlve', 'administrative', 'support', 'state'),
#  ('antltrust', 'antitrust', 'encouraged', 'provlde'),
#  ('declslon', 'decision', 'strongly', 'to'),
#  ('llkely', 'likely', 'companles', 'strongly'),
#  ('entlre', 'entire', 'companles', 'strongly'),
#  ('commlsslon', 'commission', 'to', 'thls'),
#  ('obtalnlng', 'obtaining', 'encouraged', 'provlde'),
#  ('antltrust', 'antitrust', 'encouraged', 'provlde'),
#  ('exemptlons', 'exemptions', 'to', 'thls'),
#  ('settlng', 'setting', 'are', 'encouraged'),
#  ('allocatlon', 'allocation', 'to', 'thls'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('mllllon', 'million', 'are', 'encouraged'),
#  ('ncreased', 'increased', 'strongly', 'to'),
#  ('unports', 'imports', 'are', 'encouraged'),
#  ('commlsslon', 'commission', 'to', 'thls'),
#  ('vlctoryl', 'victoryl', 'strongly', 'to'),
#  ('commlsslon', 'commission', 'to', 'thls'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('transportatlon', 'transportation', 'support', 'state'),
#  ('recommendatlons', 'recommendations', 'the', 'advocacy'),
#  ('ntended', 'intended', 'are', 'encouraged'),
#  ('facllltatlng', 'facilitating', 'thls', 'support'),
#  ('pipellnes', 'pipelines', 'encouraged', 'provlde'),
#  ('substantlal', 'substantial', 'provlde', 'needed'),
#  ('savlngs', 'savings', 'are', 'encouraged'),
#  ('ndustrlal', 'industrial', 'encouraged', 'provlde'),
#  ('savlngs', 'savings', 'are', 'encouraged'),
#  ('mllllon', 'million', 'are', 'encouraged'),
#  ('coalltlon', 'coalition', 'encouraged', 'provlde'),
#  ('ncluslon', 'inclusion', 'strongly', 'to'),
#  ('bllllng', 'billing', 'are', 'encouraged'),
#  ('mechanlsm', 'mechanism', 'encouraged', 'provlde'),
#  ('flnal', 'final', 'member', 'are'),
#  ('testlfled', 'testified', 'encouraged', 'provlde'),
#  ('bllllng', 'billing', 'are', 'encouraged'),
#  ('slgnlflcantly', 'significantly', 'needed', 'the'),
#  ('ndustrlal', 'industrial', 'encouraged', 'provlde'),
#  ('approxlmately', 'approximately', 'needed', 'the'),
#  ('vlctory', 'victory', 'are', 'encouraged'),
#  ('ndustrlal', 'industrial', 'encouraged', 'provlde'),
#  ('commlsslon', 'commission', 'to', 'thls'),
#  ('contlnulng', 'continuing', 'to', 'thls'),
#  ('dlsadvantages', 'disadvantages', 'needed', 'the'),
#  ('bllllng', 'billing', 'are', 'encouraged'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('ncrease', 'increase', 'are', 'encouraged'),
#  ('avaliable', 'available', 'encouraged', 'provlde'),
#  ('freezlng', 'freezing', 'strongly', 'to'),
#  ('unposlng', 'imposing', 'strongly', 'to'),
#  ('broadibased', 'broadbased', 'provlde', 'needed'),
#  ('exclse', 'excise', 'companles', 'strongly'),
#  ('miom', 'ror', 'network', 'companles'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('reconclllatlon', 'reconciliation', 'support', 'state'),
#  ('mu', 'un', '', 'network'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('reconclllatlon', 'reconciliation', 'support', 'state'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('agaln', 'again', 'member', 'are'),
#  ('conflmed', 'confirmed', 'strongly', 'to'),
#  ('broadibased', 'broadbased', 'provlde', 'needed'),
#  ('freezlng', 'freezing', 'strongly', 'to'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('reauthorlze', 'reauthorize', 'provlde', 'needed'),
#  ('slgnlflcantly', 'significantly', 'needed', 'the'),
#  ('ncreaslng', 'increasing', 'encouraged', 'provlde'),
#  ('broadibased', 'broadbased', 'provlde', 'needed'),
#  ('envlronmentallsts', 'environmentalists', 'advocacy', 'ncludng'),
#  ('coalltlon', 'coalition', 'encouraged', 'provlde'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('representatlves', 'representatives', 'the', 'advocacy'),
#  ('mimm', 'rmn', 'network', 'companles'),
#  ('bllllon', 'billion', 'are', 'encouraged'),
#  ('bllllon', 'billion', 'are', 'encouraged'),
#  ('bllllon', 'billion', 'are', 'encouraged'),
#  ('bllllon', 'billion', 'are', 'encouraged'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('transportatlon', 'transportation', 'support', 'state'),
#  ('nclude', 'include', 'companles', 'strongly'),
#  ('cltlzen', 'citizen', 'are', 'encouraged'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('ncludng', 'certain', 'are', 'encouraged'),
#  ('requlrement', 'requirement', 'provlde', 'needed'),
#  ('thelr', 'their', 'member', 'are'),
#  ('chronlc', 'chronic', 'are', 'encouraged'),
#  ('nelther', 'neither', 'are', 'encouraged'),
#  ('mu', 'un', '', 'network'),
#  ('contalns', 'contains', 'strongly', 'to'),
#  ('compensatlon', 'compensation', 'thls', 'support'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('prlorlty', 'priority', 'strongly', 'to'),
#  ('begln', 'begin', 'member', 'are'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('mechanlsm', 'mechanism', 'encouraged', 'provlde'),
#  ('mu', 'un', '', 'network'),
#  ('mu', 'un', '', 'network'),
#  ('attentlon', 'attention', 'encouraged', 'provlde'),
#  ('agresslvely', 'agressively', 'provlde', 'needed'),
#  ('provlde', 'provide', 'are', 'encouraged'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('reconclllatlon', 'reconciliation', 'support', 'state'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('mechanlsm', 'mechanism', 'encouraged', 'provlde'),
#  ('broadibased', 'broadbased', 'provlde', 'needed'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('bllllon', 'billion', 'are', 'encouraged'),
#  ('represenatlve', 'represenative', 'needed', 'the'),
#  ('rostenkowskl', 'rostenkowski', 'thls', 'support'),
#  ('strlke', 'strike', 'companles', 'strongly'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('broadibased', 'broadbased', 'provlde', 'needed'),
#  ('wlthout', 'without', 'are', 'encouraged'),
#  ('passlng', 'passing', 'are', 'encouraged'),
#  ('reconclllatlon', 'reconciliation', 'support', 'state'),
#  ('ncluded', 'included', 'are', 'encouraged'),
#  ('dlfferent', 'different', 'encouraged', 'provlde'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('dlfflcult', 'difficult', 'encouraged', 'provlde'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('prlorlty', 'priority', 'strongly', 'to'),
#  ('implementatlon', 'implementation', 'support', 'state'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('prlorlty', 'priority', 'strongly', 'to'),
#  ('llst', 'list', 'network', 'companles'),
#  ('retalnlng', 'retaining', 'encouraged', 'provlde'),
#  ('flexlblllty', 'flexibility', 'provlde', 'needed'),
#  ('requlrlng', 'requiring', 'encouraged', 'provlde'),
#  ('analytlcal', 'analytical', 'to', 'thls'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('contlngency', 'contingency', 'provlde', 'needed'),
#  ('authorlzed', 'authorized', 'to', 'thls'),
#  ('ntervene', 'intervene', 'strongly', 'to'),
#  ('lltlgatlon', 'litigation', 'to', 'thls'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('revlslons', 'revisions', 'encouraged', 'provlde'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('contlngency', 'contingency', 'provlde', 'needed'),
#  ('ncludng', 'certain', 'are', 'encouraged'),
#  ('healthibased', 'healthbased', 'thls', 'support'),
#  ('determlnlng', 'determining', 'provlde', 'needed'),
#  ('establlshlng', 'establishing', 'thls', 'support'),
#  ('costieffectlveness', 'costeffectiveness', 'program', 'the'),
#  ('crlterla', 'criteria', 'strongly', 'to'),
#  ('deflnlng', 'defining', 'strongly', 'to'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('servlce', 'service', 'are', 'encouraged'),
#  ('dlvlslons', 'divisions', 'encouraged', 'provlde'),
#  ('dedlcated', 'dedicated', 'encouraged', 'provlde'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('brleflngs', 'briefings', 'encouraged', 'provlde'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('washlngton', 'washington', 'to', 'thls'),
#  ('followlng', 'following', 'encouraged', 'provlde'),
#  ('organlzatlons', 'organizations', 'needed', 'the'),
#  ('servlce', 'service', 'are', 'encouraged'),
#  ('dttaway', 'ottaway', 'are', 'encouraged'),
#  ('servlce', 'service', 'are', 'encouraged'),
#  ('mch', 'mich', 'communlcatlons', 'member'),
#  ('chlcago', 'chicago', 'are', 'encouraged'),
#  ('chlcago', 'chicago', 'are', 'encouraged'),
#  ('sunitlmes', 'suntimes', 'encouraged', 'provlde'),
#  ('aongvasmnal', 'congsional', 'provlde', 'needed'),
#  ('servce', 'service', 'companles', 'strongly'),
#  ('servlce', 'service', 'are', 'encouraged'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('elght', 'eight', 'member', 'are'),
#  ('offlcers', 'officers', 'strongly', 'to'),
#  ('membericompany', 'membercompany', 'support', 'state'),
#  ('representatlves', 'representatives', 'the', 'advocacy'),
#  ('partlclpated', 'participated', 'thls', 'support'),
#  ('brleflngs', 'briefings', 'encouraged', 'provlde'),
#  ('televlslon', 'television', 'to', 'thls'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('ncreased', 'increased', 'strongly', 'to'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('extenslve', 'extensive', 'encouraged', 'provlde'),
#  ('alternatlve', 'alternative', 'provlde', 'needed'),
#  ('provldlng', 'providing', 'encouraged', 'provlde'),
#  ('speclally', 'specially', 'encouraged', 'provlde'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('ncluded', 'included', 'are', 'encouraged'),
#  ('economc', 'economic', 'are', 'encouraged'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('ndustres', 'present', 'strongly', 'to'),
#  ('contrlbuted', 'contributed', 'provlde', 'needed'),
#  ('dlstrlbuted', 'distributed', 'provlde', 'needed'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('dependlng', 'depending', 'encouraged', 'provlde'),
#  ('mllllon', 'million', 'are', 'encouraged'),
#  ('mllllon', 'million', 'are', 'encouraged'),
#  ('slmllar', 'similar', 'are', 'encouraged'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('asslsted', 'assisted', 'strongly', 'to'),
#  ('preparatlon', 'preparation', 'provlde', 'needed'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('advertlsement', 'advertisement', 'needed', 'the'),
#  ('washlngton', 'washington', 'to', 'thls'),
#  ('urglng', 'urging', 'companles', 'strongly'),
#  ('dlstrlbutlng', 'distributing', 'thls', 'support'),
#  ('cleanlng', 'cleaning', 'strongly', 'to'),
#  ('offlces', 'offices', 'are', 'encouraged'),
#  ('dlstrlbuted', 'distributed', 'provlde', 'needed'),
#  ('televlslon', 'television', 'to', 'thls'),
#  ('prlnts', 'prints', 'companles', 'strongly'),
#  ('infomatlon', 'information', 'to', 'thls'),
#  ('launchlng', 'launching', 'encouraged', 'provlde'),
#  ('dlstrlbutlon', 'distribution', 'thls', 'support'),
#  ('ncludes', 'includes', 'are', 'encouraged'),
#  ('nvolvement', 'involvement', 'to', 'thls'),
#  ('televlslon', 'television', 'to', 'thls'),
#  ('publlclty', 'publicity', 'encouraged', 'provlde'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('prohlblted', 'prohibited', 'to', 'thls'),
#  ('constltuents', 'constituents', 'thls', 'support'),
#  ('establlsh', 'establish', 'encouraged', 'provlde'),
#  ('constltuents', 'constituents', 'thls', 'support'),
#  ('avaliable', 'available', 'encouraged', 'provlde'),
#  ('unportant', 'important', 'encouraged', 'provlde'),
#  ('leachlng', 'leaching', 'strongly', 'to'),
#  ('flnal', 'final', 'member', 'are'),
#  ('adoptlng', 'adopting', 'strongly', 'to'),
#  ('leachlng', 'leaching', 'strongly', 'to'),
#  ('mlgratlon', 'migration', 'encouraged', 'provlde'),
#  ('perslstence', 'persistence', 'provlde', 'needed'),
#  ('llsteddellsted', 'listeddelisted', 'support', 'state'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('varlatlons', 'variations', 'to', 'thls'),
#  ('detemlne', 'determine', 'strongly', 'to'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('revlewlng', 'reviewing', 'encouraged', 'provlde'),
#  ('flnal', 'final', 'member', 'are'),
#  ('detemlne', 'determine', 'strongly', 'to'),
#  ('drganlc', 'organic', 'are', 'encouraged'),
#  ('leachlng', 'leaching', 'strongly', 'to'),
#  ('leachlng', 'leaching', 'strongly', 'to'),
#  ('mlgratlon', 'migration', 'encouraged', 'provlde'),
#  ('perslstence', 'persistence', 'provlde', 'needed'),
#  ('organlc', 'organic', 'are', 'encouraged'),
#  ('ntended', 'intended', 'are', 'encouraged'),
#  ('organlc', 'organic', 'are', 'encouraged'),
#  ('dlscussed', 'discussed', 'encouraged', 'provlde'),
#  ('burnlng', 'burning', 'are', 'encouraged'),
#  ('partlclpate', 'participate', 'provlde', 'needed'),
#  ('regardlng', 'regarding', 'encouraged', 'provlde'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('burnlng', 'burning', 'are', 'encouraged'),
#  ('fom', 'form', 'communlcatlons', 'member'),
#  ('developlng', 'developing', 'to', 'thls'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('dlvldes', 'divides', 'are', 'encouraged'),
#  ('burnlng', 'burning', 'are', 'encouraged'),
#  ('categorles', 'categories', 'to', 'thls'),
#  ('contalns', 'contains', 'strongly', 'to'),
#  ('analytlcal', 'analytical', 'to', 'thls'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('contlnulng', 'continuing', 'to', 'thls'),
#  ('landfllls', 'landfills', 'encouraged', 'provlde'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('ncreased', 'increased', 'strongly', 'to'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('analysls', 'analysis', 'strongly', 'to'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('authorlzed', 'authorized', 'to', 'thls'),
#  ('provlde', 'provide', 'are', 'encouraged'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('leglslatlve', 'legislative', 'provlde', 'needed'),
#  ('concernlng', 'concerning', 'to', 'thls'),
#  ('codlflcatlon', 'codification', 'thls', 'support'),
#  ('authorlzed', 'authorized', 'to', 'thls'),
#  ('ntervene', 'intervene', 'strongly', 'to'),
#  ('lltlgatlon', 'litigation', 'to', 'thls'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('deslgned', 'designed', 'strongly', 'to'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('llquld', 'liquid', 'companles', 'strongly'),
#  ('technologlcal', 'technological', 'needed', 'the'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('contlnulng', 'continuing', 'to', 'thls'),
#  ('provlslon', 'provision', 'encouraged', 'provlde'),
#  ('quantlty', 'quantity', 'strongly', 'to'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('preconstructlon', 'preconstruction', 'the', 'advocacy'),
#  ('labelllng', 'labelling', 'encouraged', 'provlde'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('recordkeeplng', 'recordkeeping', 'needed', 'the'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('mlnlmlze', 'minimize', 'strongly', 'to'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('flnal', 'final', 'member', 'are'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('llmltlng', 'limiting', 'strongly', 'to'),
#  ('authorlzed', 'authorized', 'to', 'thls'),
#  ('brlef', 'brief', 'member', 'are'),
#  ('conslderatlon', 'consideration', 'needed', 'the'),
#  ('ordlnance', 'ordinance', 'encouraged', 'provlde'),
#  ('bannlng', 'banning', 'are', 'encouraged'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('hlthln', 'within', 'companles', 'strongly'),
#  ('ordlnances', 'ordinances', 'to', 'thls'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('locallty', 'locality', 'strongly', 'to'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('longiterm', 'longterm', 'encouraged', 'provlde'),
#  ('burnlng', 'burning', 'are', 'encouraged'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('revlsed', 'revised', 'are', 'encouraged'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('concernlng', 'concerning', 'to', 'thls'),
#  ('burnlng', 'burning', 'are', 'encouraged'),
#  ('ndustrlal', 'industrial', 'encouraged', 'provlde'),
#  ('revlslons', 'revisions', 'encouraged', 'provlde'),
#  ('revlsed', 'revised', 'are', 'encouraged'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('antlclpated', 'anticipated', 'provlde', 'needed'),
#  ('burnlng', 'burning', 'are', 'encouraged'),
#  ('ndustrlal', 'industrial', 'encouraged', 'provlde'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('burnlng', 'burning', 'are', 'encouraged'),
#  ('ndustrlal', 'industrial', 'encouraged', 'provlde'),
#  ('representatlves', 'representatives', 'the', 'advocacy'),
#  ('partlclpate', 'participate', 'provlde', 'needed'),
#  ('injectlon', 'injection', 'encouraged', 'provlde'),
#  ('injectlon', 'injection', 'encouraged', 'provlde'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('dlsposed', 'disposed', 'strongly', 'to'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('ultlmately', 'ultimately', 'to', 'thls'),
#  ('dlsposed', 'disposed', 'strongly', 'to'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('mp', 'imp', '', 'network'),
#  ('negotlatlons', 'negotiations', 'thls', 'support'),
#  ('injectlon', 'injection', 'encouraged', 'provlde'),
#  ('partlclpate', 'participate', 'provlde', 'needed'),
#  ('injectlon', 'injection', 'encouraged', 'provlde'),
#  ('mrpcy', 'uipc', 'member', 'are'),
#  ('meetlng', 'meeting', 'are', 'encouraged'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('appllcable', 'applicable', 'to', 'thls'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('approprlate', 'appropriate', 'provlde', 'needed'),
#  ('negotlatlons', 'negotiations', 'thls', 'support'),
#  ('meetlng', 'meeting', 'are', 'encouraged'),
#  ('exlst', 'exist', 'member', 'are'),
#  ('meanlngful', 'meaningful', 'to', 'thls'),
#  ('negotlatlons', 'negotiations', 'thls', 'support'),
#  ('questlon', 'question', 'strongly', 'to'),
#  ('meetlng', 'meeting', 'are', 'encouraged'),
#  ('partlclpate', 'participate', 'provlde', 'needed'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('thlgatlon', 'litigation', 'encouraged', 'provlde'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('deflnltlon', 'definition', 'to', 'thls'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('deflnlng', 'defining', 'strongly', 'to'),
#  ('nclude', 'include', 'companles', 'strongly'),
#  ('resultlng', 'resulting', 'encouraged', 'provlde'),
#  ('manufacturlng', 'manufacturing', 'needed', 'the'),
#  ('manufacturlng', 'manufacturing', 'needed', 'the'),
#  ('reclalmed', 'reclaimed', 'encouraged', 'provlde'),
#  ('closediloop', 'closedloop', 'provlde', 'needed'),
#  ('manufacturlng', 'manufacturing', 'needed', 'the'),
#  ('thelr', 'their', 'member', 'are'),
#  ('manufacturlng', 'manufacturing', 'needed', 'the'),
#  ('closediloop', 'closedloop', 'provlde', 'needed'),
#  ('reclamatlon', 'reclamation', 'provlde', 'needed'),
#  ('jurlsdlctlon', 'jurisdiction', 'thls', 'support'),
#  ('supportlng', 'supporting', 'to', 'thls'),
#  ('codlflcatlon', 'codification', 'thls', 'support'),
#  ('rulecorrectlve', 'rulecorrective', 'support', 'state'),
#  ('ntervened', 'intervened', 'encouraged', 'provlde'),
#  ('codlfylng', 'codifying', 'encouraged', 'provlde'),
#  ('nvolves', 'involves', 'are', 'encouraged'),
#  ('questlon', 'question', 'strongly', 'to'),
#  ('repalr', 'repair', 'companles', 'strongly'),
#  ('envlronment', 'environment', 'provlde', 'needed'),
#  ('lltlgatlon', 'litigation', 'to', 'thls'),
#  ('partlclpate', 'participate', 'provlde', 'needed'),
#  ('negotlatlons', 'negotiations', 'thls', 'support'),
#  ('almed', 'aimed', 'member', 'are'),
#  ('clarlfylng', 'clarifying', 'to', 'thls'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('bonsaipassed', 'housepassed', 'thls', 'support'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('contalns', 'contains', 'strongly', 'to'),
#  ('ncludng', 'certain', 'are', 'encouraged'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('reportlng', 'reporting', 'encouraged', 'provlde'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('descrlptlon', 'description', 'provlde', 'needed'),
#  ('nghtitoiknow', 'righttoknow', 'thls', 'support'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('fulliscale', 'fullscale', 'to', 'thls'),
#  ('mu', 'un', '', 'network'),
#  ('ntroduced', 'introduced', 'encouraged', 'provlde'),
#  ('slnce', 'since', 'member', 'are'),
#  ('preoccupled', 'preoccupied', 'provlde', 'needed'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('addltlonal', 'additional', 'to', 'thls'),
#  ('antlelpatlon', 'anticipation', 'thls', 'support'),
#  ('mngen', 'survey', 'member', 'are'),
#  ('nformatlon', 'information', 'to', 'thls'),
#  ('regardlng', 'regarding', 'encouraged', 'provlde'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('addltlonal', 'additional', 'to', 'thls'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('senatejoassed', 'senatepassed', 'needed', 'the'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('contalns', 'contains', 'strongly', 'to'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('reportlng', 'reporting', 'encouraged', 'provlde'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('ncludng', 'certain', 'are', 'encouraged'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('provlslon', 'provision', 'encouraged', 'provlde'),
#  ('raln', 'rain', 'network', 'companles'),
#  ('toplc', 'topic', 'member', 'are'),
#  ('envlronment', 'environment', 'provlde', 'needed'),
#  ('chromlum', 'chromium', 'strongly', 'to'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('chromlum', 'chromium', 'strongly', 'to'),
#  ('chromlum', 'chromium', 'strongly', 'to'),
#  ('chromlum', 'chromium', 'strongly', 'to'),
#  ('coollng', 'cooling', 'are', 'encouraged'),
#  ('chromlum', 'chromium', 'strongly', 'to'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('tradlng', 'trading', 'are', 'encouraged'),
#  ('conjunctlon', 'conjunction', 'provlde', 'needed'),
#  ('petltloned', 'petitioned', 'to', 'thls'),
#  ('publlsh', 'publish', 'are', 'encouraged'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('tradlng', 'trading', 'are', 'encouraged'),
#  ('llne', 'line', 'network', 'companles'),
#  ('orlglnal', 'original', 'strongly', 'to'),
#  ('negotlated', 'negotiated', 'to', 'thls'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('tradlng', 'trading', 'are', 'encouraged'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('tradlng', 'trading', 'are', 'encouraged'),
#  ('publlsh', 'publish', 'are', 'encouraged'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('tradlng', 'trading', 'are', 'encouraged'),
#  ('envlronment', 'environment', 'provlde', 'needed'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('insslon', 'qnission', 'are', 'encouraged'),
#  ('developmg', 'developing', 'encouraged', 'provlde'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('estlmatlng', 'estimating', 'to', 'thls'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('deslgned', 'designed', 'strongly', 'to'),
#  ('developmg', 'developing', 'encouraged', 'provlde'),
#  ('predlctlve', 'predictive', 'to', 'thls'),
#  ('estlmatlng', 'estimating', 'to', 'thls'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('unlts', 'units', 'member', 'are'),
#  ('comprlslng', 'comprising', 'to', 'thls'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('analytlcal', 'analytical', 'to', 'thls'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('leglslatlve', 'legislative', 'provlde', 'needed'),
#  ('prlnclples', 'principles', 'to', 'thls'),
#  ('prlnclples', 'principles', 'to', 'thls'),
#  ('addresslng', 'addressing', 'to', 'thls'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('prlnclples', 'principles', 'to', 'thls'),
#  ('routlne', 'routine', 'are', 'encouraged'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('accldental', 'accidental', 'to', 'thls'),
#  ('emlsslons', 'emissions', 'encouraged', 'provlde'),
#  ('prlnclples', 'principles', 'to', 'thls'),
#  ('dlrectors', 'directors', 'encouraged', 'provlde'),
#  ('developlng', 'developing', 'to', 'thls'),
#  ('leglslatlve', 'legislative', 'provlde', 'needed'),
#  ('asslsted', 'assisted', 'strongly', 'to'),
#  ('executlve', 'executive', 'encouraged', 'provlde'),
#  ('developlng', 'developing', 'to', 'thls'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('mplemented', 'implemented', 'to', 'thls'),
#  ('dlrectors', 'directors', 'encouraged', 'provlde'),
#  ('educatlon', 'education', 'encouraged', 'provlde'),
#  ('unplementlng', 'implementing', 'thls', 'support'),
#  ('thlgatlon', 'litigation', 'encouraged', 'provlde'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('brlef', 'brief', 'member', 'are'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('margln', 'margin', 'companles', 'strongly'),
#  ('requlred', 'required', 'strongly', 'to'),
#  ('zeroirlsk', 'zerorisk', 'encouraged', 'provlde'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('carclnogens', 'carcinogens', 'provlde', 'needed'),
#  ('argulng', 'arguing', 'are', 'encouraged'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('authorlzed', 'authorized', 'to', 'thls'),
#  ('feaslblllty', 'feasibility', 'provlde', 'needed'),
#  ('settlng', 'setting', 'are', 'encouraged'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('radlonuclldes', 'radionuclides', 'needed', 'the'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('brlef', 'brief', 'member', 'are'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('radlonuclldes', 'radionuclides', 'needed', 'the'),
#  ('margln', 'margin', 'companles', 'strongly'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('agaln', 'again', 'member', 'are'),
#  ('zeroirlsk', 'zerorisk', 'encouraged', 'provlde'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('carclnogens', 'carcinogens', 'provlde', 'needed'),
#  ('flexlblllty', 'flexibility', 'provlde', 'needed'),
#  ('feaslblllty', 'feasibility', 'provlde', 'needed'),
#  ('settlng', 'setting', 'are', 'encouraged'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('chlorlde', 'chloride', 'strongly', 'to'),
#  ('prevlously', 'previously', 'to', 'thls'),
#  ('ntervened', 'intervened', 'encouraged', 'provlde'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('emlsslon', 'emission', 'strongly', 'to'),
#  ('chlorlde', 'chloride', 'strongly', 'to'),
#  ('meanlng', 'meaning', 'are', 'encouraged'),
#  ('brlefs', 'briefs', 'companles', 'strongly'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('declslon', 'decision', 'strongly', 'to'),
#  ('sprlng', 'spring', 'companles', 'strongly'),
#  ('questlon', 'question', 'strongly', 'to'),
#  ('mngen', 'survey', 'member', 'are'),
#  ('rface', 'water', 'member', 'are'),
#  ('tlmlng', 'timing', 'companles', 'strongly'),
#  ('constructlon', 'construction', 'thls', 'support'),
#  ('fundlng', 'funding', 'are', 'encouraged'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('dlstrlbutlng', 'distributing', 'thls', 'support'),
#  ('dlscusslng', 'discussing', 'to', 'thls'),
#  ('mprovements', 'improvements', 'provlde', 'needed'),
#  ('followlng', 'following', 'encouraged', 'provlde'),
#  ('deadllnes', 'deadlines', 'encouraged', 'provlde'),
#  ('applylng', 'applying', 'strongly', 'to'),
#  ('ye', 'yet', '', 'network'),
#  ('deadllne', 'deadline', 'strongly', 'to'),
#  ('provldlng', 'providing', 'encouraged', 'provlde'),
#  ('admlnlstratlve', 'administrative', 'support', 'state'),
#  ('hearlng', 'hearings', 'are', 'encouraged'),
#  ('falrer', 'fairer', 'companles', 'strongly'),
#  ('slze', 'size', 'network', 'companles'),
#  ('maxlmum', 'judicial', 'are', 'encouraged'),
#  ('admlnlstratlve', 'administrative', 'support', 'state'),
#  ('penaltles', 'penalties', 'encouraged', 'provlde'),
#  ('cltlzen', 'citizen', 'are', 'encouraged'),
#  ('relatlve', 'relative', 'strongly', 'to'),
#  ('admlnlstratlve', 'administrative', 'support', 'state'),
#  ('altlesi', 'fairer', 'are', 'encouraged'),
#  ('falrer', 'fairer', 'companles', 'strongly'),
#  ('slze', 'size', 'network', 'companles'),
#  ('maxlmum', 'judicial', 'are', 'encouraged'),
#  ('judlclal', 'judicial', 'strongly', 'to'),
#  ('clvll', 'civil', 'member', 'are'),
#  ('penaltles', 'penalties', 'encouraged', 'provlde'),
#  ('rmatve', 'defense', 'companles', 'strongly'),
#  ('crlmlnal', 'penalties', 'strongly', 'to'),
#  ('penaltles', 'penalties', 'encouraged', 'provlde'),
#  ('eu', 'bu', '', 'network'),
#  ('damentally', 'different', 'to', 'thls'),
#  ('allowlng', 'allowing', 'strongly', 'to'),
#  ('avallable', 'technology', 'encouraged', 'provlde'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('provldlng', 'providing', 'encouraged', 'provlde'),
#  ('responslblllty', 'responsibility', 'support', 'state'),
#  ('pemlts', 'permits', 'companles', 'strongly'),
#  ('dlscharges', 'discharges', 'to', 'thls'),
#  ('pemltted', 'permitted', 'strongly', 'to'),
#  ('fag', 'page', 'communlcatlons', 'member'),
#  ('guldellnes', 'guidelines', 'to', 'thls'),
#  ('guldellnes', 'guidelines', 'to', 'thls'),
#  ('comprehenslve', 'comprehensive', 'needed', 'the'),
#  ('revlslons', 'revisions', 'encouraged', 'provlde'),
#  ('org', 'orig', 'communlcatlons', 'member'),
#  ('ocpsfy', 'ocpsf', 'companles', 'strongly'),
#  ('hlghllght', 'technical', 'encouraged', 'provlde'),
#  ('constructlve', 'alternatives', 'thls', 'support'),
#  ('alternatlves', 'alternatives', 'thls', 'support'),
#  ('achleve', 'achieve', 'are', 'encouraged'),
#  ('hlgh', 'high', 'network', 'companles'),
#  ('exlstence', 'existence', 'encouraged', 'provlde'),
#  ('enomous', 'enormous', 'are', 'encouraged'),
#  ('addltlonal', 'additional', 'to', 'thls'),
#  ('mlght', 'might', 'member', 'are'),
#  ('mposed', 'imposed', 'companles', 'strongly'),
#  ('representatlves', 'representatives', 'the', 'advocacy'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('dlscussed', 'discussed', 'encouraged', 'provlde'),
#  ('revlslons', 'revisions', 'encouraged', 'provlde'),
#  ('guldellnes', 'guidelines', 'to', 'thls'),
#  ('permlts', 'permits', 'are', 'encouraged'),
#  ('revlslons', 'revisions', 'encouraged', 'provlde'),
#  ('modlflcatlons', 'modifications', 'needed', 'the'),
#  ('representatlves', 'representatives', 'the', 'advocacy'),
#  ('dlscussed', 'discussed', 'encouraged', 'provlde'),
#  ('durlng', 'during', 'companles', 'strongly'),
#  ('revlslons', 'revisions', 'encouraged', 'provlde'),
#  ('odlfled', 'modified', 'are', 'encouraged'),
#  ('flnal', 'final', 'member', 'are'),
#  ('stomwater', 'stormwater', 'encouraged', 'provlde'),
#  ('requlrement', 'requirement', 'provlde', 'needed'),
#  ('prl', 'to', 'communlcatlons', 'member'),
#  ('llstlngdellstlng', 'listingdelisting', 'state', 'program'),
#  ('crlterla', 'criteria', 'strongly', 'to'),
#  ('conjunctlon', 'conjunction', 'provlde', 'needed'),
#  ('ranklng', 'ranking', 'are', 'encouraged'),
#  ('prlorlty', 'priority', 'strongly', 'to'),
#  ('opportunlty', 'opportunity', 'provlde', 'needed'),
#  ('dellst', 'certain', 'companles', 'strongly'),
#  ('prlorlty', 'priority', 'strongly', 'to'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('meetlng', 'meeting', 'are', 'encouraged'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('dlscuss', 'discuss', 'are', 'encouraged'),
#  ('mlnlmlzatlon', 'minimization', 'thls', 'support'),
#  ('prlorlty', 'priority', 'strongly', 'to'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('mportant', 'important', 'strongly', 'to'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('llttle', 'little', 'companles', 'strongly'),
#  ('actlvlty', 'activity', 'strongly', 'to'),
#  ('mlnlmlzatlon', 'minimization', 'thls', 'support'),
#  ('emerglng', 'emerging', 'strongly', 'to'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('inlectlon', 'inlection', 'encouraged', 'provlde'),
#  ('requlre', 'require', 'are', 'encouraged'),
#  ('detemlne', 'determine', 'strongly', 'to'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('remaln', 'remain', 'companles', 'strongly'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('ellmlnatlon', 'elimination', 'provlde', 'needed'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('thelr', 'their', 'member', 'are'),
#  ('prlorltles', 'priorities', 'to', 'thls'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('prohlbltlng', 'prohibiting', 'provlde', 'needed'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('dlrectly', 'directly', 'strongly', 'to'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('opposltlon', 'opposition', 'to', 'thls'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('injectlon', 'injection', 'encouraged', 'provlde'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('thelr', 'their', 'member', 'are'),
#  ('contlnue', 'continue', 'strongly', 'to'),
#  ('envlronmentallst', 'environmentalist', 'state', 'program'),
#  ('opposltlon', 'opposition', 'to', 'thls'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('speclflcally', 'specifically', 'thls', 'support'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('overslght', 'oversight', 'encouraged', 'provlde'),
#  ('ntroductlon', 'introduction', 'provlde', 'needed'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('contlnue', 'continue', 'strongly', 'to'),
#  ('comnunlcata', 'comnunicata', 'provlde', 'needed'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('njectlon', 'injection', 'strongly', 'to'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('begln', 'begin', 'member', 'are'),
#  ('attentlon', 'attention', 'encouraged', 'provlde'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('avaliablllty', 'availability', 'thls', 'support'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('flnal', 'final', 'member', 'are'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('dlsposlng', 'disposing', 'encouraged', 'provlde'),
#  ('speclfled', 'specified', 'encouraged', 'provlde'),
#  ('landfllls', 'landfills', 'encouraged', 'provlde'),
#  ('varlablllty', 'variability', 'provlde', 'needed'),
#  ('modlflcatlons', 'modifications', 'needed', 'the'),
#  ('analytlcal', 'analytical', 'to', 'thls'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('approxlmately', 'approximately', 'needed', 'the'),
#  ('representatlves', 'representatives', 'the', 'advocacy'),
#  ('partlclpated', 'participated', 'thls', 'support'),
#  ('twoiday', 'twoday', 'are', 'encouraged'),
#  ('representatlves', 'representatives', 'the', 'advocacy'),
#  ('luvplementatlon', 'implementation', 'the', 'advocacy'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('organlc', 'organic', 'are', 'encouraged'),
#  ('toxlclty', 'toxicity', 'strongly', 'to'),
#  ('retroflt', 'retrofit', 'strongly', 'to'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('correctlve', 'corrective', 'to', 'thls'),
#  ('requlrements', 'requirements', 'thls', 'support'),
#  ('thlgatlon', 'litigation', 'encouraged', 'provlde'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('flnal', 'final', 'member', 'are'),
#  ('mpoundment', 'impoundment', 'to', 'thls'),
#  ('landflll', 'landfill', 'strongly', 'to'),
#  ('recelvlng', 'receiving', 'encouraged', 'provlde'),
#  ('requlres', 'requires', 'strongly', 'to'),
#  ('unlt', 'unit', 'network', 'companles'),
#  ('hlthln', 'within', 'companles', 'strongly'),
#  ('flnal', 'final', 'member', 'are'),
#  ('recelpt', 'receipt', 'are', 'encouraged'),
#  ('unlt', 'unit', 'network', 'companles'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('negotlatlons', 'negotiations', 'thls', 'support'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('brleflng', 'briefing', 'strongly', 'to'),
#  ('nlnety', 'ninety', 'companles', 'strongly'),
#  ('alternatlves', 'alternatives', 'thls', 'support'),
#  ('retroflttlng', 'retrofitting', 'thls', 'support'),
#  ('luvpoundments', 'impoundments', 'needed', 'the'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('llners', 'liners', 'companles', 'strongly'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('rastrlcuonsy', 'rastrlctions', 'thls', 'support'),
#  ('ntervened', 'intervened', 'encouraged', 'provlde'),
#  ('flnal', 'final', 'member', 'are'),
#  ('restrlctlng', 'restricting', 'provlde', 'needed'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('dloxlns', 'dioxins', 'are', 'encouraged'),
#  ('exlstlng', 'existing', 'strongly', 'to'),
#  ('unlt', 'unit', 'network', 'companles'),
#  ('doublellned', 'doublelined', 'provlde', 'needed'),
#  ('bemg', 'being', 'network', 'companles'),
#  ('flnal', 'final', 'member', 'are'),
#  ('speclflcally', 'specifically', 'thls', 'support'),
#  ('requlred', 'required', 'strongly', 'to'),
#  ('dloxlns', 'dioxins', 'are', 'encouraged'),
#  ('concentratlons', 'concentrations', 'support', 'state'),
#  ('concentratlons', 'concentrations', 'support', 'state'),
#  ('conslderlng', 'considering', 'provlde', 'needed'),
#  ('llmltatlon', 'limitation', 'to', 'thls'),
#  ('mlgratlon', 'migration', 'encouraged', 'provlde'),
#  ('ndvdual', 'states', 'are', 'encouraged'),
#  ('ndvdual', 'states', 'are', 'encouraged'),
#  ('unlts', 'units', 'member', 'are'),
#  ('mlgratlon', 'migration', 'encouraged', 'provlde'),
#  ('exceptlon', 'exception', 'encouraged', 'provlde'),
#  ('dlsposal', 'disposal', 'strongly', 'to'),
#  ('requlrement', 'requirement', 'provlde', 'needed'),
#  ('zaey', 'zhe', 'network', 'companles'),
#  ('assesslng', 'assessing', 'encouraged', 'provlde'),
#  ('concentratlon', 'concentration', 'needed', 'the'),
#  ('varlablllty', 'variability', 'provlde', 'needed'),
#  ('excesslve', 'excessive', 'encouraged', 'provlde'),
#  ('drganlc', 'organic', 'are', 'encouraged'),
#  ('petltloned', 'petitioned', 'to', 'thls'),
#  ('adoptlng', 'adopting', 'strongly', 'to'),
#  ('organlc', 'organic', 'are', 'encouraged'),
#  ('dellstlng', 'delisting', 'encouraged', 'provlde'),
#  ('organlc', 'organic', 'are', 'encouraged'),
#  ('landfllls', 'landfills', 'encouraged', 'provlde'),
#  ('crlterla', 'criteria', 'strongly', 'to'),
#  ('conslderlng', 'considering', 'provlde', 'needed'),
#  ('decldlng', 'deciding', 'strongly', 'to'),
#  ('dellst', 'certain', 'companles', 'strongly'),
#  ('noniconslderatlon', 'nonconsideration', 'advocacy', 'ncludng'),
#  ('bemg', 'being', 'network', 'companles'),
#  ('llsted', 'listed', 'companles', 'strongly'),
#  ('belng', 'being', 'member', 'are'),
#  ('drlnklng', 'drinking', 'strongly', 'to'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('developmg', 'developing', 'encouraged', 'provlde'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('belleve', 'believe', 'are', 'encouraged'),
#  ('mportant', 'important', 'strongly', 'to'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('establlsh', 'establish', 'encouraged', 'provlde'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('llkely', 'likely', 'companles', 'strongly'),
#  ('pestlcldes', 'pesticides', 'to', 'thls'),
#  ('concernlng', 'concerning', 'to', 'thls'),
#  ('llablllty', 'liability', 'encouraged', 'provlde'),
#  ('ncludng', 'certain', 'are', 'encouraged'),
#  ('compensatlon', 'compensation', 'thls', 'support'),
#  ('taxlng', 'taxing', 'companles', 'strongly'),
#  ('mechanlsms', 'mechanisms', 'to', 'thls'),
#  ('partlclpant', 'participant', 'provlde', 'needed'),
#  ('natlonal', 'national', 'strongly', 'to'),
#  ('leglslatures', 'legislatures', 'thls', 'support'),
#  ('partlcularly', 'particularly', 'thls', 'support'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('testlmony', 'testimony', 'encouraged', 'provlde'),
#  ('addresslng', 'addressing', 'to', 'thls'),
#  ('provlslons', 'provisions', 'to', 'thls'),
#  ('drlnklng', 'drinking', 'strongly', 'to'),
#  ('dlrectly', 'directly', 'strongly', 'to'),
#  ('educatlng', 'educating', 'encouraged', 'provlde'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('thlgatlon', 'litigation', 'encouraged', 'provlde'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('erleflng', 'briefing', 'strongly', 'to'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('maxlmum', 'judicial', 'are', 'encouraged'),
#  ('contamlnant', 'contaminant', 'provlde', 'needed'),
#  ('organlc', 'organic', 'are', 'encouraged'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('brlefs', 'briefs', 'companles', 'strongly'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('apb', 'api', 'communlcatlons', 'member'),
#  ('jolntlw', 'jointly', 'are', 'encouraged'),
#  ('msmy', 'hsia', 'network', 'companles'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('thelr', 'their', 'member', 'are'),
#  ('addltlonal', 'additional', 'to', 'thls'),
#  ('brlefs', 'briefs', 'companles', 'strongly'),
#  ('replylng', 'replying', 'strongly', 'to'),
#  ('posltlon', 'position', 'strongly', 'to'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('brlefs', 'briefs', 'companles', 'strongly'),
#  ('concentratlng', 'concentrating', 'needed', 'the'),
#  ('lssue', 'issue', 'member', 'are'),
#  ('brleflng', 'briefing', 'strongly', 'to'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('evldence', 'evidence', 'strongly', 'to'),
#  ('carclnogenlclty', 'carcinogenicity', 'the', 'advocacy'),
#  ('declslon', 'decision', 'strongly', 'to'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('unanlmously', 'unanimously', 'provlde', 'needed'),
#  ('urglng', 'urging', 'companles', 'strongly'),
#  ('mu', 'un', '', 'network'),
#  ('programmatlc', 'programmatic', 'thls', 'support'),
#  ('cltlng', 'citing', 'companles', 'strongly'),
#  ('constructlon', 'construction', 'thls', 'support'),
#  ('ntroduce', 'introduce', 'strongly', 'to'),
#  ('avold', 'avoid', 'member', 'are'),
#  ('mu', 'un', '', 'network'),
#  ('presldentlal', 'presidential', 'thls', 'support'),
#  ('subcommlttee', 'subcommittee', 'thls', 'support'),
#  ('mu', 'un', '', 'network'),
#  ('supportlve', 'supportive', 'to', 'thls'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('worklng', 'working', 'are', 'encouraged'),
#  ('compromlsed', 'compromised', 'provlde', 'needed'),
#  ('communlcatlon', 'communication', 'needed', 'the'),
#  ('munlclpal', 'municipal', 'encouraged', 'provlde'),
#  ('regardlng', 'regarding', 'encouraged', 'provlde'),
#  ('leglslatlon', 'legislation', 'provlde', 'needed'),
#  ('thlgatlon', 'litigation', 'encouraged', 'provlde'),
#  ('actlvltles', 'activities', 'to', 'thls'),
#  ('pestlcldes', 'pesticides', 'to', 'thls'),
#  ('guldellnes', 'guidelines', 'to', 'thls'),
#  ('removlng', 'removing', 'strongly', 'to'),
#  ('pestleldes', 'pesticides', 'to', 'thls'),
#  ('guldellnes', 'guidelines', 'to', 'thls'),
#  ('announclng', 'announcing', 'to', 'thls'),
#  ('effectlve', 'effective', 'encouraged', 'provlde'),
#  ('lawsult', 'lawsuit', 'are', 'encouraged'),
#  ('challenglng', 'challenging', 'provlde', 'needed'),
#  ('pestlelde', 'pesticide', 'encouraged', 'provlde'),
#  ('nfomed', 'about', 'companles', 'strongly'),
#  ('developlng', 'developing', 'to', 'thls'),
#  ('guldellnes', 'guidelines', 'to', 'thls'),
#  ('pestlcldes', 'pesticides', 'to', 'thls'),
#  ('prevlous', 'previous', 'strongly', 'to'),
#  ('guldellnes', 'guidelines', 'to', 'thls'),
#  ('flnal', 'final', 'member', 'are'),
#  ('mum', 'ferc', 'communlcatlons', 'member'),
#  ('clrcults', 'circuits', 'strongly', 'to'),
#  ('declslon', 'decision', 'strongly', 'to'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('brlef', 'brief', 'member', 'are'),
#  ('lled', 'trade', 'network', 'companles'),
#  ('chlcago', 'chicago', 'are', 'encouraged'),
#  ('hlth', 'with', 'network', 'companles'),
#  ('thlrd', 'third', 'member', 'are'),
#  ('ncorrectly', 'incorrectly', 'to', 'thls'),
#  ('unpacts', 'impacts', 'are', 'encouraged'),
#  ('belleve', 'believe', 'are', 'encouraged'),
#  ('congresslonal', 'congressional', 'needed', 'the'),
#  ('raln', 'rain', 'network', 'companles'),
#  ('mus', 'must', 'communlcatlons', 'member'),
#  ('hlndered', 'hindered', 'strongly', 'to'),
#  ('nterreglonal', 'interregional', 'thls', 'support'),
#  ('opposltlon', 'opposition', 'to', 'thls'),
#  ('electrlclty', 'electricity', 'provlde', 'needed'),
#  ('ncludng', 'certain', 'are', 'encouraged'),
#  ...]

# %%
 all_candidates
# Out:
# defaultdict(dict,
#             {'admlnlstratlon': [[], [], [], []],
#              'exemptlons': [[], [], [('exemptions', 'i', 'l')], []],
#              'Commlttee': [[], [], [], []],
#              '"closediloop"': [[], [], [], []],
#              '1n': [[], [], [], []],
#              'whlch': [[],
#               [('wlch', 'w', 'h')],
#               [('which', 'i', 'l'), ('whleh', 'e', 'c')],
#               []],
#              'responder.': [[], [('responder', '', '')], [], []],
#              'authorlty': [[], [], [('authority', 'i', 'l')], []],
#              'MIssIoN': [[], [], [], []],
#              'Volunteers': [[], [], [], []],
#              '1ndustry': [[], [('ndustry', '', '')], [], []],
#              '9a': [[], [], [], []],
#              'presented': [[], [], [('prevented', 'v', 's')], []],
#              'slmllar': [[], [], [], []],
#              "Assoclatlon's": [[], [], [], []],
#              'slgnature': [[], [], [('signature', 'i', 'l')], []],
#              'posslble': [[], [], [('possible', 'i', 'l')], []],
#              'research.': [[], [('research', '', '')], [], []],
#              'formatlon': [[], [], [('formation', 'i', 'l')], []],
#              'restrlctlons': [[], [], [], []],
#              'submlsslon;': [[], [], [], []],
#              '15': [[], [], [], []],
#              'leglslatlve': [[], [], [], []],
#              '1nfomatlon': [[], [], [], []],
#              'maxlmum': [[], [], [('maximum', 'i', 'l')], []],
#              'hearlng.': [[], [], [], []],
#              'staff.': [[], [('staff', '', '')], [], []],
#              'posslblllty': [[], [], [], []],
#              'rullng': [[], [], [('ruling', 'i', 'l')], []],
#              'handllng': [[], [], [('handling', 'i', 'l')], []],
#              'calllng': [[], [], [('calling', 'i', 'l')], []],
#              'Department': [[], [], [], []],
#              'Assoc': [[], [], [], []],
#              'BUSY.': [[], [], [], []],
#              'study;': [[], [('study', '', '')], [], []],
#              '1:': [[], [], [], []],
#              'publlc': [[],
#               [],
#               [('dubllc', 'd', 'p'), ('public', 'i', 'l')],
#               []],
#              'thls': [[],
#               [('ths', 'h', 'l')],
#               [('thes', 'e', 'l'),
#                ('this', 'i', 'l'),
#                ('thos', 'o', 'l'),
#                ('thus', 'u', 'l'),
#                ('thla', 'a', 's')],
#               []],
#              '1nnovatlon': [[], [], [], []],
#              'publlshed.': [[], [], [], []],
#              '4': [[], [], [], []],
#              'Consultatlons.': [[], [], [], []],
#              'publlc.': [[], [], [], []],
#              'actlvlty': [[], [], [], []],
#              'manufacturers.': [[], [('manufacturers', '', '')], [], []],
#              'sollclted': [[], [], [], []],
#              'Congress,': [[], [], [], []],
#              'grows': [[],
#               [('grow', 'w', 's')],
#               [('gross', 's', 'w'), ('grown', 'n', 's')],
#               []],
#              '1ndustry.': [[], [], [], []],
#              'inspection': [[('inspections', 'n', 's')], [], [], []],
#              'thelr': [[], [('ther', 'e', 'l')], [('their', 'i', 'l')], []],
#              'Pollcy': [[], [], [], []],
#              'Cozporatlon': [[], [], [], []],
#              'Th1:': [[], [], [], []],
#              "let's": [[], [('lets', '', '')], [], []],
#              'regulatlon': [[], [], [('regulation', 'i', 'l')], []],
#              'v.': [[], [], [], []],
#              'prof.': [[], [('prof', '', '')], [], []],
#              'commlttee': [[],
#               [],
#               [('conmlttee', 'n', 'm'),
#                ('comtlttee', 't', 'm'),
#                ('committee', 'i', 'l'),
#                ('commlttae', 'a', 'e')],
#               []],
#              'guldellnes': [[], [], [], []],
#              'effects.': [[], [('effects', '', '')], [], []],
#              'Involved': [[], [], [], []],
#              'Compensatlon,': [[], [], [], []],
#              'llttle': [[], [], [('little', 'i', 'l')], []],
#              "EPA'S": [[], [], [], []],
#              'subrogatlon': [[], [], [('subrogation', 'i', 'l')], []],
#              '1ncreaslng': [[], [], [], []],
#              'Provlslonal': [[], [], [], []],
#              'Pollutant': [[], [], [], []],
#              'produclng': [[], [], [('producing', 'i', 'l')], []],
#              'March.': [[], [], [], []],
#              'posltlons,': [[], [('posltlons', '', '')], [], []],
#              'Equlpment': [[], [], [], []],
#              '1n1tlates': [[], [], [], []],
#              'systems': [[], [('system', 'm', 's')], [], []],
#              '(l.e.,': [[], [], [], []],
#              'Commlttee,': [[], [], [], []],
#              'objectlves:': [[], [], [], []],
#              'Exhlblt': [[], [], [], []],
#              'unlts.': [[], [], [], []],
#              'qulckly': [[], [], [('quickly', 'i', 'l')], []],
#              'as.up*toidate': [[], [], [], []],
#              'precursor': [[('precursors', 'r', 's')], [], [], []],
#              'Identlflcatlon': [[], [], [], []],
#              'envlronmental': [[], [], [('environmental', 'i', 'l')], []],
#              '7': [[], [], [], []],
#              'Hlth': [[], [], [], []],
#              'chlorlde': [[], [], [('chloride', 'i', 'l')], []],
#              'penaltles': [[], [], [('penalties', 'i', 'l')], []],
#              '1:5': [[], [], [], []],
#              'Publlc': [[], [], [], []],
#              'dlscusslons': [[], [], [], []],
#              '1::': [[], [], [], []],
#              'Bonsaipassed': [[], [], [], []],
#              'addltlon,': [[], [], [], []],
#              'establlshlng': [[], [], [], []],
#              'phthalate': [[('phthalates', 'e', 's')],
#               [('phthalat', 't', 'e')],
#               [('fhthalate', 'f', 'p'), ('phthaiate', 'i', 'l')],
#               []],
#              'tests': [[],
#               [('test', 't', 's')],
#               [('rests', 'r', 't'), ('texts', 'x', 's'), ('testi', 'i', 's')],
#               []],
#              '1nformatlon.': [[], [], [], []],
#              'stud1ES7:': [[], [], [], []],
#              'dlstrlbutlon': [[], [], [], []],
#              'understandlng': [[], [], [('understanding', 'i', 'l')], []],
#              '1mportant': [[], [], [], []],
#              'Countrles.': [[], [], [], []],
#              'reductlon': [[], [], [('reduction', 'i', 'l')], []],
#              'recelpts.': [[], [], [], []],
#              'beneflts': [[], [], [('benefits', 'i', 'l')], []],
#              'consultant': [[('consultants', 't', 's')], [], [], []],
#              '1nformatlon': [[], [], [], []],
#              '1980.': [[], [], [], []],
#              'problems': [[],
#               [('problem', 'm', 's')],
#               [('probleas', 'a', 'm')],
#               []],
#              'provlslons': [[], [], [], []],
#              'assoclatlon': [[], [], [], []],
#              '3': [[], [], [], []],
#              '11.': [[], [], [], []],
#              'procurement': [[], [], [], []],
#              'hearlngs': [[], [], [('hearings', 'i', 'l')], []],
#              "CMA'S": [[], [], [], []],
#              'emlsslon': [[], [], [], []],
#              'Commlsslon': [[], [], [], []],
#              'provlslons.': [[], [], [], []],
#              '"demonstratlon': [[], [], [], []],
#              '.dvocacy': [[], [], [], []],
#              'Shlpplng': [[], [], [], []],
#              '(NGPA7': [[], [], [], []],
#              'communlcatlons': [[],
#               [],
#               [('comaunlcatlons', 'a', 'm'), ('communlcations', 'i', 'l')],
#               []],
#              'funds': [[], [('fund', 'd', 's')], [('finds', 'i', 'u')], []],
#              'Emergency': [[], [], [], []],
#              'dlbromlde.': [[], [], [], []],
#              'Televlslon': [[], [], [], []],
#              'OSHA.': [[], [], [], []],
#              'v.5.': [[], [], [], []],
#              'chemlcal': [[], [], [('chemical', 'i', 'l')], []],
#              'facslmlle': [[], [], [], []],
#              "'77": [[], [], [], []],
#              'Fernandez': [[], [], [], []],
#              'feaslblllty': [[], [], [], []],
#              'proposals;': [[], [('proposals', '', '')], [], []],
#              'crltlcal': [[], [], [], []],
#              'Regulatlons': [[], [], [], []],
#              'efforts.': [[], [('efforts', '', '')], [], []],
#              'attentlon': [[], [], [('attention', 'i', 'l')], []],
#              'regulatlons': [[], [], [('regulations', 'i', 'l')], []],
#              'products;': [[], [('products', '', '')], [], []],
#              'Congress': [[], [], [], []],
#              'sectlons.': [[], [], [], []],
#              'system': [[('systems', 'm', 's')],
#               [],
#               [('systam', 'a', 'e')],
#               []],
#              'Chalrman': [[], [], [], []],
#              'programs': [[],
#               [('progrms', 'r', 'a'), ('program', 'm', 's')],
#               [('procrams', 'c', 'g'), ('prograas', 'a', 'm')],
#               [('progrmas', 'm', 'a')]],
#              'start': [[('stuart', 't', 'u'), ('starts', 't', 's')],
#               [('stat', 'a', 'r')],
#               [('smart', 'm', 't'), ('staft', 'f', 'r'), ('stars', 's', 't')],
#               []],
#              'supportlng': [[], [], [('supporting', 'i', 'l')], []],
#              '..': [[], [], [], []],
#              'testlng': [[], [], [('testing', 'i', 'l')], []],
#              'Groundwater': [[], [], [], []],
#              'successful': [[], [], [('luccessful', 'l', 's')], []],
#              'Llst"': [[], [], [], []],
#              'Exports': [[], [], [], []],
#              'p05*': [[], [], [], []],
#              'Superfund': [[], [], [], []],
#              'partlcularly': [[], [], [('particularly', 'i', 'l')], []],
#              '1ndustrlal': [[], [], [], []],
#              'congratulated': [[], [], [], []],
#              '1nternatlonal': [[], [], [], []],
#              'programs:': [[], [('programs', '', '')], [], []],
#              'subchronlc,': [[], [('subchronlc', '', '')], [], []],
#              '3.x.': [[], [], [], []],
#              '039373': [[], [], [], []],
#              'establlshed': [[], [], [('established', 'i', 'l')], []],
#              '1915,': [[], [], [], []],
#              'unportant': [[], [], [], []],
#              'Act.': [[], [], [], []],
#              'twoithlrds': [[], [], [], []],
#              'property': [[], [], [('properly', 'l', 't')], []],
#              'Dlvlslon': [[], [], [], []],
#              'neutrallty': [[], [], [('neutrality', 'i', 'l')], []],
#              'lngredlent': [[], [], [], []],
#              'Energy': [[], [], [], []],
#              'jolnt': [[], [], [('joint', 'i', 'l')], []],
#              'Documents,': [[], [], [], []],
#              'Mlxed': [[], [], [], []],
#              '14': [[], [], [], []],
#              'c': [[('ac', '{', 'a'),
#                ('cc', 'c', 'c'),
#                ('dc', '{', 'd'),
#                ('ec', '{', 'e'),
#                ('fc', '{', 'f'),
#                ('hc', '{', 'h'),
#                ('ic', '{', 'i'),
#                ('jc', '{', 'j'),
#                ('mc', '{', 'm'),
#                ('nc', '{', 'n'),
#                ('oc', '{', 'o'),
#                ('sc', '{', 's'),
#                ('tc', '{', 't'),
#                ('vc', '{', 'v'),
#                ('wc', '{', 'w'),
#                ('ca', 'c', 'a'),
#                ('cb', 'c', 'b'),
#                ('cc', 'c', 'c'),
#                ('ce', 'c', 'e'),
#                ('cf', 'c', 'f'),
#                ('cg', 'c', 'g'),
#                ('ch', 'c', 'h'),
#                ('cl', 'c', 'l'),
#                ('cm', 'c', 'm'),
#                ('cn', 'c', 'n'),
#                ('co', 'c', 'o'),
#                ('cq', 'c', 'q'),
#                ('cs', 'c', 's'),
#                ('ct', 'c', 't')],
#               [],
#               [],
#               []],
#              "Long's": [[], [], [], []],
#              "DSHA'S,": [[], [], [], []],
#              'flrst': [[], [], [('first', 'i', 'l'), ('flrat', 'a', 's')], []],
#              'asslglwaats': [[], [], [], []],
#              'dlrectly': [[], [], [('directly', 'i', 'l')], []],
#              'establlsh': [[], [], [('establish', 'i', 'l')], []],
#              'knows': [[], [('know', 'w', 's')], [('known', 'n', 's')], []],
#              'comlng': [[], [], [('coming', 'i', 'l')], []],
#              '1991.': [[], [], [], []],
#              's.': [[], [], [], []],
#              'generally': [[], [], [], []],
#              'effectlveness': [[], [], [('effectiveness', 'i', 'l')], []],
#              'Incentlves': [[], [], [], []],
#              'bllaterally': [[], [], [('bilaterally', 'i', 'l')], []],
#              'etlng': [[], [], [], []],
#              'approprlate': [[], [], [('appropriate', 'i', 'l')], []],
#              'communlcatlons.': [[], [], [], []],
#              'Hllton.': [[], [], [], []],
#              'Wllbur': [[], [], [], []],
#              'polnt,': [[], [], [], []],
#              'groundwater': [[],
#               [],
#               [('groundweter', 'e', 'a'), ('groundwatar', 'a', 'e')],
#               []],
#              'products': [[],
#               [('product', 't', 's')],
#               [('produits', 'i', 'c'), ('produces', 'e', 't')],
#               []],
#              'dlvldends': [[], [], [], []],
#              'lssues': [[], [], [('issues', 'i', 'l')], []],
#              'Drlnklng': [[], [], [], []],
#              'Although': [[], [], [], []],
#              'rulemaklng.': [[], [], [], []],
#              'competltlve': [[], [], [], []],
#              'Commlt-ee': [[], [], [], []],
#              'constltute': [[], [], [('constitute', 'i', 'l')], []],
#              'rallroads': [[], [], [('railroads', 'i', 'l')], []],
#              'Industry': [[], [('ndustry', '', '')], [], []],
#              'Improvements': [[], [], [], []],
#              '200': [[], [], [], []],
#              'Dlstrlbutlon': [[], [], [], []],
#              'efflclently': [[], [], [], []],
#              'perspectlve': [[], [], [('perspective', 'i', 'l')], []],
#              'flscal': [[], [], [('fiscal', 'i', 'l')], []],
#              'Meetlng.': [[], [], [], []],
#              'Congresslonal': [[], [], [], []],
#              'markets.': [[], [('markets', '', '')], [], []],
#              'reduclng': [[], [], [('reducing', 'i', 'l')], []],
#              'Cyanamld': [[], [], [], []],
#              'stats': [[('starts', 'a', 'r'),
#                ('statas', 't', 'a'),
#                ('states', 't', 'e'),
#                ('statis', 't', 'i'),
#                ('statss', 's', 's'),
#                ('status', 't', 'u'),
#                ('statss', 's', 's')],
#               [('stat', 't', 's')],
#               [('seats', 'e', 't'),
#                ('stars', 'r', 't'),
#                ('stays', 'y', 't'),
#                ('stata', 'a', 's'),
#                ('state', 'e', 's')],
#               []],
#              'represents': [[],
#               [('represent', 't', 's')],
#               [('representa', 'a', 's')],
#               []],
#              'requlrement': [[], [], [('requirement', 'i', 'l')], []],
#              'Vehlcles': [[], [], [], []],
#              '402': [[], [], [], []],
#              'Davld': [[], [], [], []],
#              'admlnlstratlve': [[], [], [], []],
#              '5111': [[], [], [], []],
#              'Assoclatlon,': [[], [], [], []],
#              'routlnely': [[], [], [('routinely', 'i', 'l')], []],
#              'Superfund/CERCLA.': [[], [], [], []],
#              '"redacted"': [[], [], [], []],
#              'Programs': [[], [], [], []],
#              '19,': [[], [], [], []],
#              'staff,': [[], [('staff', '', '')], [], []],
#              'factors.': [[], [('factors', '', '')], [], []],
#              'Actlvlty.': [[], [], [], []],
#              'estlmatlng': [[], [], [], []],
#              'scrutlny': [[], [], [('scrutiny', 'i', 'l')], []],
#              'clrcumstances': [[], [], [('circumstances', 'i', 'l')], []],
#              'toxlc': [[], [], [('toxic', 'i', 'l')], []],
#              'prlmary': [[], [], [('primary', 'i', 'l')], []],
#              'synthetlc': [[], [], [('synthetic', 'i', 'l')], []],
#              'spokesmen': [[], [], [('spokesman', 'a', 'e')], []],
#              'sharlng': [[], [], [('sharing', 'i', 'l')], []],
#              'Pollutlon': [[], [], [], []],
#              'comments': [[],
#               [('coments', 'o', 'm'),
#                ('coments', 'o', 'm'),
#                ('comment', 't', 's')],
#               [('conments', 'n', 'm'),
#                ('comnents', 'n', 'm'),
#                ('commants', 'a', 'e'),
#                ('commends', 'd', 't')],
#               []],
#              'whlte': [[], [], [('white', 'i', 'l')], []],
#              'Tarlff': [[], [], [], []],
#              'manufacturlng.': [[], [], [], []],
#              'clalms': [[], [], [('claims', 'i', 'l')], []],
#              '"Alr': [[], [], [], []],
#              'dlsposal': [[], [], [('disposal', 'i', 'l')], []],
#              'declded': [[], [], [('decided', 'i', 'l')], []],
#              '1nvestment': [[], [], [], []],
#              'study': [[('studys', 'y', 's')], [], [], []],
#              'shown': [[],
#               [('show', 'w', 'n')],
#               [('showa', 'a', 'n'), ('shows', 's', 'n')],
#               []],
#              'necessary,': [[], [('necessary', '', '')], [], []],
#              'Progr-ms': [[], [], [], []],
#              '"cr0557cutt1ng"': [[], [], [], []],
#              'Italy': [[], [], [], []],
#              'golng': [[], [], [('going', 'i', 'l')], []],
#              'overslght': [[], [], [('oversight', 'i', 'l')], []],
#              'contract': [[('contracts', 't', 's')],
#               [('contact', 't', 'r'), ('contrac', 'c', 't')],
#               [('contrast', 's', 'c')],
#               []],
#              'dlrectors,': [[], [], [], []],
#              'represented': [[], [], [], []],
#              'deslgnated': [[], [], [('designated', 'i', 'l')], []],
#              'thelr.': [[], [], [], []],
#              'operatlons,': [[], [], [], []],
#              'Clothlng': [[], [], [], []],
#              'responded.': [[], [('responded', '', '')], [], []],
#              'soCMA,': [[], [], [], []],
#              'Membershlp': [[], [], [], []],
#              'Agrlculture': [[], [], [], []],
#              'proposal.': [[], [('proposal', '', '')], [], []],
#              '1': [[], [], [], []],
#              'communltles': [[], [], [], []],
#              'sltus': [[], [], [('situs', 'i', 'l')], []],
#              'speclflc': [[], [], [], []],
#              'Transportatlon': [[], [], [], []],
#              'fundlng': [[], [], [('funding', 'i', 'l')], []],
#              'upifront,': [[], [], [], []],
#              'malntalned': [[], [], [], []],
#              'admlnlstered': [[], [], [], []],
#              'transportatlon': [[], [], [('transportation', 'i', 'l')], []],
#              "Admlnlstratlon's": [[], [], [], []],
#              'ChemEcology': [[], [], [], []],
#              'Support:': [[], [], [], []],
#              'costs.': [[], [('costs', '', '')], [], []],
#              'Hlthln': [[], [], [], []],
#              's': [[('as', '{', 'a'),
#                ('bs', '{', 'b'),
#                ('cs', '{', 'c'),
#                ('es', '{', 'e'),
#                ('gs', '{', 'g'),
#                ('is', '{', 'i'),
#                ('js', '{', 'j'),
#                ('ks', '{', 'k'),
#                ('ms', '{', 'm'),
#                ('ns', '{', 'n'),
#                ('os', '{', 'o'),
#                ('ps', '{', 'p'),
#                ('rs', '{', 'r'),
#                ('ss', 's', 's'),
#                ('ts', '{', 't'),
#                ('us', '{', 'u'),
#                ('vs', '{', 'v'),
#                ('sb', 's', 'b'),
#                ('sc', 's', 'c'),
#                ('sd', 's', 'd'),
#                ('se', 's', 'e'),
#                ('sf', 's', 'f'),
#                ('sh', 's', 'h'),
#                ('si', 's', 'i'),
#                ('sk', 's', 'k'),
#                ('sm', 's', 'm'),
#                ('so', 's', 'o'),
#                ('sp', 's', 'p'),
#                ('sr', 's', 'r'),
#                ('ss', 's', 's'),
#                ('st', 's', 't'),
#                ('sw', 's', 'w'),
#                ('sy', 's', 'y')],
#               [],
#               [],
#               []],
#              '199271993.': [[], [], [], []],
#              'leglslatlon': [[], [], [('legislatlon', 'i', 'l')], []],
#              'underestlmated.': [[], [], [], []],
#              '1dentlfy1ng,': [[], [], [], []],
#              'correspondents': [[], [], [], []],
#              'mllllon': [[], [], [], []],
#              'llliconcelved': [[], [], [], []],
#              'staff': [[('stafff', 'f', 'f'),
#                ('stafff', 'f', 'f'),
#                ('stafff', 'f', 'f'),
#                ('staffs', 'f', 's')],
#               [],
#               [('scaff', 'c', 't'), ('staft', 't', 'f')],
#               []],
#              'emlsslons': [[], [], [], []],
#              'sectors,': [[], [('sectors', '', '')], [], []],
#              'partlcular': [[], [], [('particular', 'i', 'l')], []],
#              'development': [[('developments', 't', 's')],
#               [],
#               [('developaent', 'a', 'm')],
#               []],
#              'cycle': [[], [], [('cyele', 'e', 'c')], []],
#              'foundatl-ns': [[], [], [], []],
#              'compensatlon': [[], [], [('compensation', 'i', 'l')], []],
#              'attempts': [[], [('attempt', 't', 's')], [], []],
#              'enterprlse".': [[], [], [], []],
#              'Petrochemlcal': [[], [], [], []],
#              'Amendments': [[], [('mendments', '', '')], [], []],
#              'envlronment': [[], [], [('environment', 'i', 'l')], []],
#              '3939,': [[], [], [], []],
#              '12,': [[], [], [], []],
#              'whlla': [[], [], [('whila', 'i', 'l'), ('whola', 'o', 'l')], []],
#              'authorlty.': [[], [], [], []],
#              'Monltorlng': [[], [], [], []],
#              'compounds': [[], [('compound', 'd', 's')], [], []],
#              'prellmlnary': [[], [], [], []],
#              'amendments': [[],
#               [('mendments', '{', 'a'), ('amendment', 't', 's')],
#               [],
#               []],
#              'Reslns.': [[], [], [], []],
#              'Standard': [[], [], [], []],
#              'organlzatlon': [[], [], [], []],
#              'Chemlcal': [[], [], [], []],
#              'developlng': [[], [], [('developing', 'i', 'l')], []],
#              '1:1': [[], [], [], []],
#              'plants.': [[], [('plants', '', '')], [], []],
#              'declslon': [[], [], [], []],
#              'offlclals,': [[], [], [], []],
#              'conducted': [[], [], [], []],
#              'conslstently': [[], [], [('consistently', 'i', 'l')], []],
#              'recommended': [[],
#               [('ecommended', '{', 'r'),
#                ('recomended', 'o', 'm'),
#                ('recomended', 'o', 'm')],
#               [('reconmended', 'n', 'm'), ('recomnended', 'n', 'm')],
#               []],
#              'Commlttees': [[], [], [], []],
#              'durlng': [[], [], [('during', 'i', 'l')], []],
#              'representatlves': [[],
#               [('representatves', 't', 'l')],
#               [('representatives', 'i', 'l')],
#               []],
#              'demonstratlon': [[], [], [('demonstration', 'i', 'l')], []],
#              'presently': [[], [], [], []],
#              'prograsts.': [[], [('prograsts', '', '')], [], []],
#              'dlalkyl': [[('dlnalkyl', 'l', 'n')],
#               [],
#               [('dialkyl', 'i', 'l')],
#               []],
#              'chronlc': [[], [], [('chronic', 'i', 'l')], []],
#              'b.': [[], [], [], []],
#              'Compensatlon': [[], [], [], []],
#              '7mg': [[], [('mg', '', '')], [], []],
#              'Vlnners': [[], [], [], []],
#              'portlons': [[], [], [('portions', 'i', 'l')], []],
#              'sult.': [[], [], [], []],
#              'performance': [[], [], [], []],
#              'Karrh': [[], [], [], []],
#              'Cosnlttee,': [[], [], [], []],
#              'Technologles.': [[], [], [], []],
#              '4.': [[], [], [], []],
#              '1993': [[], [], [], []],
#              'currently': [[], [], [('currantly', 'a', 'e')], []],
#              "examlner's": [[], [], [], []],
#              'Nevertheless,': [[], [], [], []],
#              'recognlzlng': [[], [], [], []],
#              'Admlnlstratlon,': [[], [], [], []],
#              ',': [[], [], [], []],
#              'petrochemlcal': [[], [], [('petrochemical', 'i', 'l')], []],
#              'Envlronmental': [[], [], [], []],
#              'm': [[('am', '{', 'a'),
#                ('cm', '{', 'c'),
#                ('em', '{', 'e'),
#                ('gm', '{', 'g'),
#                ('hm', '{', 'h'),
#                ('im', '{', 'i'),
#                ('mm', 'm', 'm'),
#                ('pm', '{', 'p'),
#                ('rm', '{', 'r'),
#                ('sm', '{', 's'),
#                ('wm', '{', 'w'),
#                ('xm', '{', 'x'),
#                ('ma', 'm', 'a'),
#                ('mb', 'm', 'b'),
#                ('mc', 'm', 'c'),
#                ('md', 'm', 'd'),
#                ('me', 'm', 'e'),
#                ('mg', 'm', 'g'),
#                ('mi', 'm', 'i'),
#                ('mm', 'm', 'm'),
#                ('mn', 'm', 'n'),
#                ('mo', 'm', 'o'),
#                ('mr', 'm', 'r'),
#                ('ms', 'm', 's'),
#                ('mt', 'm', 't'),
#                ('my', 'm', 'y')],
#               [],
#               [],
#               []],
#              'manufacturlng': [[], [], [('manufacturing', 'i', 'l')], []],
#              '32': [[], [], [], []],
#              '$5': [[], [], [], []],
#              '12': [[], [], [], []],
#              "couldn't": [[], [('couldnt', '', '')], [], []],
#              'Chlorlde': [[], [], [], []],
#              'Bllllon': [[], [], [], []],
#              'posltlons': [[], [], [], []],
#              'forestall': [[], [], [], []],
#              'Proceedlngs': [[], [], [], []],
#              'unplementlng': [[], [], [], []],
#              'Restrlcted': [[], [], [], []],
#              'coordlnate': [[], [], [('coordinate', 'i', 'l')], []],
#              '3.': [[], [], [], []],
#              'prosecutlon': [[], [], [('prosecution', 'i', 'l')], []],
#              'ﬁlled': [[], [], [], []],
#              '1994': [[], [], [], []],
#              'equlpment.': [[], [], [], []],
#              '1ntervlews.': [[], [], [], []],
#              'p119:': [[], [], [], []],
#              '1933.': [[], [], [], []],
#              '513.9': [[], [], [], []],
#              '505,': [[], [], [], []],
#              'Dlrector': [[], [], [], []],
#              'statements': [[], [('statement', 't', 's')], [], []],
#              'o:\\wp51': [[], [], [], []],
#              'membershlp': [[], [], [('membership', 'i', 'l')], []],
#              '1934.': [[], [], [], []],
#              '371377.': [[], [], [], []],
#              'short': [[],
#               [('sort', 's', 'h')],
#               [('shoot', 'o', 'r'), ('shora', 'a', 't'), ('shore', 'e', 't')],
#               []],
#              'meanlngful': [[], [], [('meaningful', 'i', 'l')], []],
#              '112': [[], [], [], []],
#              'attrlbuted': [[], [], [('attributed', 'i', 'l')], []],
#              'actlvltles': [[], [], [], []],
#              'k': [[('ak', '{', 'a'),
#                ('kk', 'k', 'k'),
#                ('ok', '{', 'o'),
#                ('rk', '{', 'r'),
#                ('sk', '{', 's'),
#                ('uk', '{', 'u'),
#                ('kk', 'k', 'k'),
#                ('ks', 'k', 's'),
#                ('ky', 'k', 'y')],
#               [],
#               [],
#               []],
#              'llmlted': [[], [], [], []],
#              'agreements.': [[], [('agreements', '', '')], [], []],
#              'collected': [[], [], [], []],
#              'complete,': [[], [('complete', '', '')], [], []],
#              'Manufacturers': [[], [], [], []],
#              'Myron': [[], [], [], []],
#              'Whlle': [[], [], [], []],
#              'substantlal': [[], [], [('substantial', 'i', 'l')], []],
#              'testlfy': [[], [], [('testify', 'i', 'l')], []],
#              '1ntends': [[], [], [], []],
#              'Blanchard': [[], [], [], []],
#              'nonitarlff': [[], [], [], []],
#              'p.rt1cularly': [[], [], [], []],
#              'coordlnates': [[], [], [('coordinates', 'i', 'l')], []],
#              '_': [[], [], [], []],
#              'c.': [[], [], [], []],
#              'convlnced': [[], [], [('convinced', 'i', 'l')], []],
#              'contlnued': [[], [], [('continued', 'i', 'l')], []],
#              '1935,': [[], [], [], []],
#              'unprovement': [[], [], [], []],
#              'retalned.': [[], [], [], []],
#              'Executlve': [[], [], [], []],
#              'Government': [[], [], [], []],
#              'tarlffs': [[], [], [('tariffs', 'i', 'l')], []],
#              'llter.ture': [[], [], [], []],
#              'Advocacy': [[], [], [], []],
#              'x': [[('ex', '{', 'e'),
#                ('ix', '{', 'i'),
#                ('nx', '{', 'n'),
#                ('ox', '{', 'o'),
#                ('tx', '{', 't'),
#                ('xx', 'x', 'x'),
#                ('xi', 'x', 'i'),
#                ('xl', 'x', 'l'),
#                ('xm', 'x', 'm'),
#                ('xn', 'x', 'n'),
#                ('xt', 'x', 't'),
#                ('xx', 'x', 'x')],
#               [],
#               [],
#               []],
#              'approprlate."': [[], [], [], []],
#              'effectlve,': [[], [], [], []],
#              'draft': [[('drafts', 't', 's')], [], [], []],
#              'authorlzed': [[], [], [('authorized', 'i', 'l')], []],
#              'obllgatlon': [[], [], [], []],
#              'recommendatlons': [[], [], [('recommendations', 'i', 'l')], []],
#              'promlses': [[], [], [('promises', 'i', 'l')], []],
#              'contacts': [[('contracts', 't', 'r')],
#               [('contact', 't', 's')],
#               [('coatacts', 'a', 'n')],
#               []],
#              '2': [[], [], [], []],
#              'concerns.': [[], [('concerns', '', '')], [], []],
#              'envlronment,': [[], [], [], []],
#              'Spllls': [[], [], [], []],
#              'Whlte': [[], [], [], []],
#              'Immedlate': [[], [], [], []],
#              'Amerlcan': [[], [], [], []],
#              '115:': [[], [], [], []],
#              'preparatlon': [[], [], [('preparation', 'i', 'l')], []],
#              '1995': [[], [], [], []],
#              'alternatlve': [[], [], [('alternative', 'i', 'l')], []],
#              'Ind.': [[], [], [], []],
#              'rlghts': [[], [], [('rights', 'i', 'l')], []],
#              '1977.': [[], [], [], []],
#              't': [[('at', '{', 'a'),
#                ('bt', '{', 'b'),
#                ('ct', '{', 'c'),
#                ('et', '{', 'e'),
#                ('ft', '{', 'f'),
#                ('ht', '{', 'h'),
#                ('it', '{', 'i'),
#                ('lt', '{', 'l'),
#                ('mt', '{', 'm'),
#                ('nt', '{', 'n'),
#                ('rt', '{', 'r'),
#                ('st', '{', 's'),
#                ('tt', 't', 't'),
#                ('ut', '{', 'u'),
#                ('xt', '{', 'x'),
#                ('ta', 't', 'a'),
#                ('tb', 't', 'b'),
#                ('tc', 't', 'c'),
#                ('td', 't', 'd'),
#                ('te', 't', 'e'),
#                ('tg', 't', 'g'),
#                ('th', 't', 'h'),
#                ('ti', 't', 'i'),
#                ('tl', 't', 'l'),
#                ('tn', 't', 'n'),
#                ('to', 't', 'o'),
#                ('tr', 't', 'r'),
#                ('ts', 't', 's'),
#                ('tt', 't', 't'),
#                ('tv', 't', 'v'),
#                ('tx', 't', 'x'),
#                ('ty', 't', 'y')],
#               [],
#               [],
#               []],
#              'sort.': [[], [('sort', '', '')], [], []],
#              '51g,': [[], [], [], []],
#              '1,': [[], [], [], []],
#              'Envlronment': [[], [], [], []],
#              'Overslght.': [[], [], [], []],
#              'Includes': [[], [], [], []],
#              'necessary': [[], [], [('neoessary', 'o', 'c')], []],
#              'cooperatlon,': [[], [], [], []],
#              'slmpllclty.': [[], [], [], []],
#              'purchased': [[],
#               [('purchase', 'e', 'd')],
#               [('purchases', 's', 'd')],
#               []],
#              '"task': [[], [('task', '', '')], [], []],
#              'System': [[], [], [], []],
#              "workers'": [[], [('workers', '', '')], [], []],
#              'communlcatlng': [[], [], [], []],
#              'expertlse.': [[], [], [], []],
#              'process.': [[], [('process', '', '')], [], []],
#              'chloroethylene': [[], [], [], []],
#              '1nstances': [[], [], [], []],
#              'dlfferlng,': [[], [], [], []],
#              'penallzed': [[], [], [('penalized', 'i', 'l')], []],
#              '301': [[], [], [], []],
#              '1ntroductlon': [[], [], [], []],
#              'facllltatlng': [[], [], [], []],
#              'provlded:': [[], [], [], []],
#              'pertlnent': [[], [], [('pertinent', 'i', 'l')], []],
#              '511dE,': [[], [], [], []],
#              'posslbly': [[],
#               [],
#               [('poaslbly', 'a', 's'), ('possibly', 'i', 'l')],
#               []],
#              'appearances.': [[], [('appearances', '', '')], [], []],
#              'passlng': [[], [], [('passing', 'i', 'l')], []],
#              'imposltlln': [[], [], [], []],
#              '(R.Kan.7': [[], [], [], []],
#              'Eridlng': [[], [], [], []],
#              'stronger': [[], [], [], []],
#              'Dperatlons': [[], [], [], []],
#              'toplc': [[], [], [('topic', 'i', 'l')], []],
#              'amendment': [[('amendments', 't', 's')], [], [], []],
#              'Indlgenous': [[], [], [], []],
#              'leglslatlon.': [[], [], [], []],
#              'GATT.': [[], [], [], []],
#              '172': [[], [], [], []],
#              'regardlng': [[], [], [('regarding', 'i', 'l')], []],
#              'exemptlon': [[], [], [('exemption', 'i', 'l')], []],
#              'chemlcals.': [[], [], [], []],
#              'reactlvated.': [[], [], [], []],
#              'them.': [[], [('them', '', '')], [], []],
#              'submlttal': [[], [], [('submittal', 'i', 'l')], []],
#              'se.': [[], [('se', '', '')], [], []],
#              'substances': [[],
#               [('substance', 'e', 's')],
#               [('substancas', 'a', 'e')],
#               []],
#              '51x': [[], [], [], []],
#              'emergencles"': [[], [], [], []],
#              'rlghts.': [[], [], [], []],
#              'revlslons': [[], [], [], []],
#              'substance': [[('substances', 'e', 's')], [], [], []],
#              '1dent1£1ed': [[], [], [], []],
#              'parts': [[('partys', 't', 'y')],
#               [('part', 't', 's')],
#               [('harts', 'h', 'p'),
#                ('ports', 'o', 'a'),
#                ('pares', 'e', 't'),
#                ('paris', 'i', 't'),
#                ('parks', 'k', 't'),
#                ('parte', 'e', 's'),
#                ('parti', 'i', 's'),
#                ('party', 'y', 's')],
#               []],
#              'Guldellnes': [[], [], [], []],
#              '0': [[], [], [], []],
#              'exploratory': [[], [], [], []],
#              'communlcatlons,': [[], [], [], []],
#              'patterns,': [[], [('patterns', '', '')], [], []],
#              '1972.': [[], [], [], []],
#              'known': [[], [('know', 'w', 'n')], [('knows', 's', 'n')], []],
#              'emphasls': [[], [], [('emphasis', 'i', 'l')], []],
#              'leglslators': [[], [], [('legislators', 'i', 'l')], []],
#              'Atlantlc': [[], [], [], []],
#              'approxlmately': [[], [], [('approximately', 'i', 'l')], []],
#              'followlng': [[], [], [('following', 'i', 'l')], []],
#              '039014': [[], [], [], []],
#              'Instltute': [[], [], [], []],
#              '1n51ght': [[], [], [], []],
#              'reportlng': [[], [], [('reporting', 'i', 'l')], []],
#              'Admlnlstratlon': [[], [], [], []],
#              '1nsurance': [[], [], [], []],
#              'Unlted': [[], [], [], []],
#              'flnal': [[], [], [('final', 'i', 'l')], []],
#              '\\Mollle\\37096*37464': [[], [], [], []],
#              'Toxlc': [[], [], [], []],
#              'contlnulng': [[], [], [], []],
#              'analysls': [[],
#               [],
#               [('analyses', 'e', 'l'),
#                ('analysis', 'i', 'l'),
#                ('analysts', 't', 'l')],
#               []],
#              'promulgatlng': [[], [], [('promulgating', 'i', 'l')], []],
#              'concentratlons': [[], [], [('concentrations', 'i', 'l')], []],
#              '51tE*llm1ted': [[], [], [], []],
#              'Drlglnally,': [[], [], [], []],
#              'Overslght': [[], [], [], []],
#              'requlreaents': [[], [], [('requireaents', 'i', 'l')], []],
#              'approprlatlons': [[], [], [], []],
#              '1ncluded': [[], [], [], []],
#              'reauthorlzetlon': [[], [], [('reauthorlzatlon', 'a', 'e')], []],
#              'regulatlons,': [[], [], [], []],
#              '.nd': [[], [('nd', '', '')], [], []],
#              '50,000': [[], [], [], []],
#              'rabbl': [[('rabble', 'l', 'e')], [], [], []],
#              'GATT,': [[], [], [], []],
#              'Interagency': [[], [], [], []],
#              'companles.': [[], [], [], []],
#              'negotlated': [[], [], [('negotiated', 'i', 'l')], []],
#              'Edward': [[], [], [], []],
#              'Agency': [[], [('gency', '', '')], [], []],
#              'b111,': [[], [], [], []],
#              'addltlon': [[],
#               [],
#               [('jddltlon', 'j', 'a'), ('addlelon', 'e', 't')],
#               []],
#              '13': [[], [], [], []],
#              'relatlons': [[], [], [('relations', 'i', 'l')], []],
#              'attempt': [[('attempts', 't', 's')], [], [], []],
#              'A11“': [[], [], [], []],
#              'conslderlng': [[], [], [], []],
#              'L98L”': [[], [], [], []],
#              'plannlng': [[], [], [('planning', 'i', 'l')], []],
#              'reconclllatlon': [[], [], [], []],
#              'procedures,': [[], [('procedures', '', '')], [], []],
#              'dlstrlbuted': [[], [], [], []],
#              'supports': [[], [('support', 't', 's')], [], []],
#              'recently': [[], [], [], []],
#              'Communlcate': [[], [], [], []],
#              'wheellng': [[], [], [('wheeling', 'i', 'l')], []],
#              ':h.:': [[], [], [], []],
#              'responder': [[('responders', 'r', 's')],
#               [],
#               [('responded', 'd', 'r')],
#               []],
#              'Congressmen': [[], [], [], []],
#              'dlstrlbuted.': [[], [], [], []],
#              '55': [[], [], [], []],
#              '45': [[], [], [], []],
#              'Undoubtedly': [[], [], [], []],
#              'llluslon': [[], [], [], []],
#              'mlght': [[], [], [('might', 'i', 'l')], []],
#              '$350': [[], [], [], []],
#              'posltlve': [[], [], [], []],
#              'dlfflcu': [[], [], [], []],
#              'Sellakumar,': [[], [], [], []],
#              '1nvolved': [[], [], [], []],
#              'Experlment.': [[], [], [], []],
#              'ordlnatlng': [[], [], [], []],
#              'sesslon.': [[], [], [], []],
#              'submlttad': [[], [], [('submittad', 'i', 'l')], []],
#              'Regul.tory': [[], [], [], []],
#              'changed!': [[], [('changed', '', '')], [], []],
#              '275,100': [[], [], [], []],
#              'Secretary': [[], [], [], []],
#              'gestatlon': [[], [], [('gestation', 'i', 'l')], []],
#              'functlon': [[], [], [('function', 'i', 'l')], []],
#              'hlghly': [[], [], [('highly', 'i', 'l')], []],
#              '1.': [[], [], [], []],
#              'RCRA.': [[], [], [], []],
#              'Sltes.': [[], [], [], []],
#              'drlnklng': [[], [], [], []],
#              'projected': [[], [], [('protected', 't', 'j')], []],
#              'communlcator': [[], [], [('communicator', 'i', 'l')], []],
#              'productlve.': [[], [], [], []],
#              'Representatlve': [[], [], [], []],
#              'credlble': [[], [], [('credible', 'i', 'l')], []],
#              'toxlcologlsts': [[], [], [], []],
#              'wlsdom': [[], [], [('wisdom', 'i', 'l')], []],
#              '.1': [[], [], [], []],
#              'Superfund.': [[], [], [], []],
#              '(HMTA7': [[], [], [], []],
#              'gross': [[],
#               [],
#               [('cross', 'c', 'g'), ('grass', 'a', 'o'), ('grows', 'w', 's')],
#               []],
#              'Flanlgan.': [[], [], [], []],
#              '11%': [[], [], [], []],
#              '935': [[], [], [], []],
#              'supported': [[], [], [], []],
#              'belng': [[('belong', 'l', 'o')], [], [('being', 'i', 'l')], []],
#              'majorlty': [[], [], [('majority', 'i', 'l')], []],
#              'costs': [[],
#               [('cost', 't', 's')],
#               [('posts', 'p', 'c'), ('custs', 'u', 'o'), ('costa', 'a', 's')],
#               []],
#              'searchlng': [[], [], [('searching', 'i', 'l')], []],
#              'emergency': [[],
#               [],
#               [('eaergency', 'a', 'm'), ('emergence', 'e', 'y')],
#               []],
#              'Bloresearch': [[], [], [], []],
#              'unplementatlon;': [[], [], [], []],
#              'Phillips': [[], [], [], []],
#              'subsequently': [[], [], [('subseauently', 'a', 'q')], []],
#              'laws,': [[], [('laws', '', '')], [], []],
#              'dlsclpllnes': [[], [], [], []],
#              'llght': [[], [], [('light', 'i', 'l')], []],
#              'concerns': [[], [('concern', 'n', 's')], [], []],
#              'regulatory': [[],
#               [],
#               [('ragulatory', 'a', 'e'), ('regulators', 's', 'y')],
#               []],
#              'Adjournment': [[], [], [], []],
#              '1931,': [[], [], [], []],
#              '1nformat10n,': [[], [], [], []],
#              'questlon.': [[], [], [], []],
#              "Commlttee's": [[], [], [], []],
#              '551-': [[], [], [], []],
#              'accompllshed.': [[], [], [], []],
#              '1ntenslfy': [[], [], [], []],
#              'conslstent': [[], [], [('consistent', 'i', 'l')], []],
#              '1ntegratlon': [[], [], [], []],
#              'partlclpated': [[], [], [], []],
#              'assoclatlon.': [[], [], [], []],
#              'Recommended': [[], [('ecommended', '', '')], [], []],
#              'candldates': [[], [], [('candidates', 'i', 'l')], []],
#              're*': [[], [('re', '', '')], [], []],
#              'Stlpulatlons': [[], [], [], []],
#              'Blamedlcal': [[], [], [], []],
#              'basls"': [[], [], [], []],
#              'Clark': [[], [], [], []],
#              'horror': [[], [], [], []],
#              'testlfled': [[], [], [], []],
#              'plant': [[('plants', 't', 's')],
#               [('plan', 'n', 't')],
#               [('slant', 's', 'p'),
#                ('plana', 'a', 't'),
#                ('plank', 'k', 't'),
#                ('plans', 's', 't')],
#               []],
#              '-n': [[], [], [], []],
#              '$2.25': [[], [], [], []],
#              'scheduled.': [[], [('scheduled', '', '')], [], []],
#              '5:111': [[], [], [], []],
#              'modellng.': [[], [], [], []],
#              '1njectlon': [[], [], [], []],
#              '1mplled': [[], [], [], []],
#              'Costs': [[], [], [], []],
#              '1935.': [[], [], [], []],
#              'JCIA,': [[], [], [], []],
#              'lrements': [[], [], [], []],
#              '95': [[], [], [], []],
#              '(:1:': [[], [], [], []],
#              'sows,': [[], [('sows', '', '')], [], []],
#              'Offlce': [[], [], [], []],
#              '1nterest': [[], [], [], []],
#              'operatlonal': [[], [], [('operational', 'i', 'l')], []],
#              '10': [[], [], [], []],
#              'matters.': [[], [('matters', '', '')], [], []],
#              'recommendatlon': [[], [], [('recommendation', 'i', 'l')], []],
#              'structure': [[('structured', 'e', 'd'),
#                ('structures', 'e', 's')],
#               [],
#               [],
#               []],
#              'programs.': [[], [('programs', '', '')], [], []],
#              'sufflclent': [[], [], [], []],
#              'Trust': [[], [], [], []],
#              'knowledge': [[], [], [], []],
#              'assessm-nts.': [[], [], [], []],
#              '1ncludes': [[], [], [], []],
#              'management': [[], [], [], []],
#              'RESPONSIBILITIES': [[], [], [], []],
#              'ng,': [[], [('ng', '', '')], [], []],
#              '1ncreased': [[], [], [], []],
#              'restrlcted,': [[], [], [], []],
#              'Rodrlcks.': [[], [], [], []],
#              "document's": [[], [('documents', '', '')], [], []],
#              'plans': [[('plants', 'n', 't')],
#               [('plan', 'n', 's')],
#               [('plays', 'y', 'n'),
#                ('plana', 'a', 's'),
#                ('plank', 'k', 's'),
#                ('plant', 't', 's')],
#               []],
#              'produced.': [[], [('produced', '', '')], [], []],
#              'plants,': [[], [('plants', '', '')], [], []],
#              'llkely': [[], [], [('likely', 'i', 'l')], []],
#              'unllkely': [[], [], [('unlikely', 'i', 'l')], []],
#              'publlshed': [[], [], [('published', 'i', 'l')], []],
#              'story': [[],
#               [('tory', '{', 's')],
#               [('atory', 'a', 's'), ('store', 'e', 'y'), ('storm', 'm', 'y')],
#               []],
#              'methodology': [[], [], [], []],
#              'commlttees': [[],
#               [('commlttee', 'e', 's')],
#               [('comnlttees', 'n', 'm'), ('committees', 'i', 'l')],
#               []],
#              'governlng': [[], [], [('governing', 'i', 'l')], []],
#              'relatlng': [[], [], [('relating', 'i', 'l')], []],
#              'leveraglng': [[], [], [('leveraging', 'i', 'l')], []],
#              'suggestlons': [[], [], [('suggestions', 'i', 'l')], []],
#              'feedstock': [[('feedstocks', 'k', 's')], [], [], []],
#              'spokespersons': [[], [], [], []],
#              'contracted': [[],
#               [('contacted', 't', 'r')],
#               [('contrasted', 's', 'c')],
#               []],
#              'mllllans': [[], [], [], []],
#              'exlsts': [[], [], [('exists', 'i', 'l')], []],
#              'Endlng': [[], [], [], []],
#              'exports“': [[], [('exports', '', '')], [], []],
#              'assembllng': [[], [], [('assembling', 'i', 'l')], []],
#              'slderatlon.': [[], [], [], []],
#              'Drafts': [[], [], [], []],
#              'pestlcldes': [[], [], [], []],
#              'protects': [[],
#               [('protect', 't', 's')],
#               [('projects', 'j', 't')],
#               []],
#              'experlenced': [[], [], [('experienced', 'i', 'l')], []],
#              '(Pennsylvanla,': [[], [], [], []],
#              'rabblts': [[],
#               [],
#               [('rabbits', 'i', 'l'), ('rabbles', 'e', 't')],
#               []],
#              'establlshment': [[], [], [('establishment', 'i', 'l')], []],
#              '74,100': [[], [], [], []],
#              'enployers.': [[], [('enployers', '', '')], [], []],
#              'materlal,': [[], [], [], []],
#              'materlals': [[], [], [('materials', 'i', 'l')], []],
#              'moratorlum': [[], [], [('moratorium', 'i', 'l')], []],
#              'Emlsslon': [[], [], [], []],
#              'complled,': [[], [], [], []],
#              'supportlve': [[], [], [('supportive', 'i', 'l')], []],
#              'Beglnnlng': [[], [], [], []],
#              'extenslon': [[], [], [('extension', 'i', 'l')], []],
#              'margln': [[], [], [('margin', 'i', 'l')], []],
#              'March': [[], [('arch', '', '')], [], []],
#              'affectlng': [[], [], [('affecting', 'i', 'l')], []],
#              'descrlbed': [[], [], [('described', 'i', 'l')], []],
#              '1994/95': [[], [], [], []],
#              'workplace.': [[], [('workplace', '', '')], [], []],
#              'Chemlcals.': [[], [], [], []],
#              'Dlrectors:': [[], [], [], []],
#              'expandlng': [[], [], [('expanding', 'i', 'l')], []],
#              'excellent': [[], [], [], []],
#              '201': [[], [], [], []],
#              'exlstlng': [[], [], [], []],
#              'polnt': [[], [('pont', 'o', 'l')], [('point', 'i', 'l')], []],
#              '1nput': [[], [], [], []],
#              'Preventlon': [[], [], [], []],
# ...
#              'removlng': [[], [], [('removing', 'i', 'l')], []],
#              '"Vlslted': [[], [], [], []],
#              'dlscharges': [[], [], [('discharges', 'i', 'l')], []],
#              '5:11': [[], [], [], []],
#              'answers"': [[], [('answers', '', '')], [], []],
#              'separately.': [[], [('separately', '', '')], [], []],
#              '1937.': [[], [], [], []],
#              '[47': [[], [], [], []],
#              'ultlmately': [[], [], [('ultimately', 'i', 'l')], []],
#              'mendments': [[('amendments', '{', 'a')],
#               [],
#               [('wendments', 'w', 'm')],
#               []],
#              'Unfortunately,': [[], [], [], []],
#              'crossdzuttlng': [[], [], [], []],
#              'marrlage.': [[], [], [], []],
#              'regardless': [[], [], [], []],
#              'dlscusslon.': [[], [], [], []],
#              'Reportlng': [[], [], [], []],
#              'hydrocarbon': [[('hydrocarbons', 'n', 's')], [], [], []],
#              'omlsslons': [[], [], [], []],
#              '~': [[], [], [], []],
#              'unnecessary.': [[], [('unnecessary', '', '')], [], []],
#              '50': [[], [], [], []],
#              'productlon': [[], [], [('production', 'i', 'l')], []],
#              'locatlons': [[], [], [('locations', 'i', 'l')], []],
#              'commltted': [[],
#               [],
#               [('committed', 'i', 'l'), ('commlttee', 'e', 'd')],
#               []],
#              'asslstlng': [[], [], [], []],
#              'conslderable': [[], [], [('considerable', 'i', 'l')], []],
#              'w.': [[], [], [], []],
#              'support.': [[], [('support', '', '')], [], []],
#              'Varlablllty': [[], [], [], []],
#              '19': [[], [], [], []],
#              'semlnars': [[], [], [('seminars', 'i', 'l')], []],
#              'throughout': [[], [], [], []],
#              'operatlons': [[], [], [('operations', 'i', 'l')], []],
#              'ellmlnatlng': [[], [], [], []],
#              '1ntended': [[], [], [], []],
#              '21.': [[], [], [], []],
#              'prlorlty': [[], [], [], []],
#              'strength': [[('strengths', 'h', 's')], [], [], []],
#              'Pollcy.': [[], [], [], []],
#              'dlstrlbutlon.': [[], [], [], []],
#              'correct:': [[], [('correct', '', '')], [], []],
#              'Corporatlon': [[], [], [], []],
#              'Contalnment': [[], [], [], []],
#              'cusslons': [[], [], [('cussions', 'i', 'l')], []],
#              '1nformed': [[], [], [], []],
#              'colmnlsslon': [[], [], [], []],
#              'Durlng': [[], [], [], []],
#              'unprovlng': [[], [], [], []],
#              "Department's": [[], [], [], []],
#              '11th': [[], [], [], []],
#              'overcomlng': [[], [], [('overcoming', 'i', 'l')], []],
#              '037509': [[], [], [], []],
#              '._': [[], [], [], []],
#              'responded,': [[], [('responded', '', '')], [], []],
#              'wrlters': [[], [], [('writers', 'i', 'l')], []],
#              'cs-': [[], [('cs', '', '')], [], []],
#              '$2': [[], [], [], []],
#              "lssues'": [[], [], [], []],
#              'exemptlon/lmport': [[], [], [], []],
#              'Vlews': [[], [('lews', '', '')], [], []],
#              '5.': [[], [], [], []],
#              'unllkely,': [[], [], [], []],
#              'R1co7': [[], [], [], []],
#              'gettlng': [[], [], [('getting', 'i', 'l')], []],
#              'growlng': [[], [], [('growing', 'i', 'l')], []],
#              'wrltten': [[], [], [('written', 'i', 'l')], []],
#              'hands': [[],
#               [('hans', 'n', 'd'), ('hand', 'd', 's')],
#               [('lands', 'l', 'h'), ('mands', 'm', 'h')],
#               []],
#              'revlslon': [[], [], [], []],
#              'contrlbutlons': [[], [], [], []],
#              'Thlrd': [[], [], [], []],
#              'Prellml': [[], [], [], []],
#              'Montanarl': [[], [], [], []],
#              'sensltlve': [[], [], [], []],
#              'Significant': [[], [], [], []],
#              'havlng': [[], [], [('having', 'i', 'l')], []],
#              'Nonimetalllc': [[], [], [], []],
#              'remarkably': [[], [], [('remarkable', 'e', 'y')], []],
#              'reflects': [[], [('reflect', 't', 's')], [], []],
#              'distrlh': [[], [], [], []],
#              'ellmlnatlon': [[], [], [], []],
#              'negotlatlons,': [[], [], [], []],
#              'procedures': [[], [('procedure', 'e', 's')], [], []],
#              'whlle': [[], [], [('while', 'i', 'l'), ('whole', 'o', 'l')], []],
#              'organlzatlons,': [[], [], [], []],
#              'sectors.': [[], [('sectors', '', '')], [], []],
#              'Interstate': [[], [], [], []],
#              'runnlng': [[], [], [('running', 'i', 'l')], []],
#              'technlcal': [[],
#               [],
#               [('eechnlcal', 'e', 't'), ('technical', 'i', 'l')],
#               []],
#              '.': [[], [], [], []],
#              'Floyd': [[], [], [], []],
#              'lsslon': [[], [], [], []],
#              'system.': [[], [('system', '', '')], [], []],
#              'recordikeeplng': [[], [], [], []],
#              'd': [[('ad', '{', 'a'),
#                ('bd', '{', 'b'),
#                ('ed', '{', 'e'),
#                ('fd', '{', 'f'),
#                ('id', '{', 'i'),
#                ('jd', '{', 'j'),
#                ('md', '{', 'm'),
#                ('nd', '{', 'n'),
#                ('rd', '{', 'r'),
#                ('sd', '{', 's'),
#                ('td', '{', 't'),
#                ('vd', '{', 'v'),
#                ('da', 'd', 'a'),
#                ('dc', 'd', 'c'),
#                ('de', 'd', 'e'),
#                ('di', 'd', 'i'),
#                ('dl', 'd', 'l'),
#                ('do', 'd', 'o'),
#                ('dr', 'd', 'r'),
#                ('du', 'd', 'u')],
#               [],
#               [],
#               []],
#              'p-st,': [[], [], [], []],
#              'yardstlck': [[], [], [('yardstick', 'i', 'l')], []],
#              'do.': [[], [('do', '', '')], [], []],
#              'programsl.': [[], [], [], []],
#              'contractor': [[('contractors', 'r', 's')], [], [], []],
#              'surplus,': [[], [('surplus', '', '')], [], []],
#              'tradlng': [[], [], [('trading', 'i', 'l')], []],
#              'Shell': [[], [('hell', '', '')], [], []],
#              '1971,': [[], [], [], []],
#              '1975': [[], [], [], []],
#              '(USTR7': [[], [], [], []],
#              'depth': [[('depths', 'h', 's')],
#               [('dept', 't', 'h')],
#               [('death', 'a', 'p')],
#               []],
#              'chemlcals': [[], [], [('chemicals', 'i', 'l')], []],
#              'reauthorlzatlon': [[],
#               [],
#               [('reauthorizatlon', 'i', 'l'), ('reauthorlzation', 'i', 'l')],
#               []],
#              '1nv1ted': [[], [], [], []],
#              'attalnment': [[], [], [('attainment', 'i', 'l')], []],
#              '1,500': [[], [], [], []],
#              'Inspectlon': [[], [], [], []],
#              'plcketlng': [[], [], [], []],
#              '1njunctlon': [[], [], [], []],
#              'meetlng,': [[], [], [], []],
#              'determlne': [[], [], [('determine', 'i', 'l')], []],
#              'reapportlonment': [[], [], [('reapportionment', 'i', 'l')], []],
#              '117': [[], [], [], []],
#              '511.9': [[], [], [], []],
#              'g1': [[], [], [], []],
#              'partlclpatlon': [[], [], [], []],
#              'pollcy': [[], [], [('policy', 'i', 'l')], []],
#              'Reauthor12atlon': [[], [], [], []],
#              '1tself.."': [[], [], [], []],
#              'studles.': [[], [], [], []],
#              'Unltad': [[], [], [], []],
#              'accompllsh': [[], [], [('accomplish', 'i', 'l')], []],
#              'Confldentlallty': [[], [], [], []],
#              '1mplementatlon': [[], [], [], []],
#              'Impact': [[], [], [], []],
#              'basls': [[],
#               [('bass', 's', 'l')],
#               [('bases', 'e', 'l'), ('basis', 'i', 'l')],
#               []],
#              'dlrected': [[], [], [('directed', 'i', 'l')], []],
#              'commlttees,': [[], [], [], []],
#              'Blomonltorlng': [[], [], [], []],
#              'e11': [[], [], [], []],
#              'capaclty': [[], [], [('capacity', 'i', 'l')], []],
#              'compllcated': [[], [], [('complicated', 'i', 'l')], []],
#              'upw.rd': [[], [], [], []],
#              'legally': [[], [], [], []],
#              'toxlcs': [[], [], [('toxics', 'i', 'l')], []],
#              'lltlgatlon': [[], [], [], []],
#              'prlnclpally': [[], [], [], []],
#              'Dlngell': [[], [], [], []],
#              'offlcers': [[], [], [('officers', 'i', 'l')], []],
#              'posltlon': [[('posltlons', 'n', 's')], [], [], []],
#              "presldent's": [[], [], [], []],
#              'soundly.': [[], [('soundly', '', '')], [], []],
#              'stats:': [[], [('stats', '', '')], [], []],
#              'types': [[], [('type', 'e', 's')], [('tapes', 'a', 'y')], []],
#              'clalm': [[], [('calm', 'c', 'l')], [('claim', 'i', 'l')], []],
#              'Awards': [[], [], [], []],
#              'reconstltuted': [[], [], [('reconstituted', 'i', 'l')], []],
#              'pretty': [[], [], [], []],
#              '1nc1dents': [[], [], [], []],
#              'wlngs': [[], [], [('wings', 'i', 'l')], []],
#              "'eductlon": [[], [], [], []],
#              'strong,': [[], [('strong', '', '')], [], []],
#              '27': [[], [], [], []],
#              'harmonlzatlon': [[], [], [], []],
#              'advlsory': [[], [], [('advisory', 'i', 'l')], []],
#              '1ntervlewed': [[], [], [], []],
#              'Presldent': [[], [], [], []],
#              'Dlrectors': [[], [], [], []],
#              'restrlctlvethan': [[], [], [], []],
#              'envlronmental,': [[], [('envlronmental', '', '')], [], []],
#              "1ndustry's": [[], [], [], []],
#              'frequency': [[], [], [], []],
#              'optlmlstlcally': [[], [], [], []],
#              '5': [[], [], [], []],
#              'certalnly': [[], [], [('certainly', 'i', 'l')], []],
#              'ellmlnatl-n': [[], [], [], []],
#              'mlnor': [[], [], [('minor', 'i', 'l')], []],
#              'dlffer': [[], [], [('differ', 'i', 'l')], []],
#              '-7n2': [[], [], [], []],
#              'comprlsed': [[], [], [('comprised', 'i', 'l')], []],
#              'hearlngs,': [[], [], [], []],
#              'm-nths.': [[], [], [], []],
#              'Admlnlstrator': [[], [], [], []],
#              'Analytlcal': [[], [], [], []],
#              '315': [[], [], [], []],
#              'costeffectlve': [[], [], [('costeffective', 'i', 'l')], []],
#              'tlons': [[], [('tons', 't', 'l')], [('tions', 'i', 'l')], []],
#              '"Vlews': [[], [], [], []],
#              'sh-uld': [[], [], [], []],
#              'developments': [[], [('development', 't', 's')], [], []],
#              'press': [[],
#               [('pres', 's', 's'), ('pres', 's', 's')],
#               [('dress', 'd', 'p'), ('prass', 'a', 'e'), ('presi', 'i', 's')],
#               []],
#              'untll': [[], [], [('until', 'i', 'l')], []],
#              "members'": [[], [('members', '', '')], [], []],
#              'worldwlde': [[], [], [('worldwide', 'i', 'l')], []],
#              '£111': [[], [], [], []],
#              'reservatlon': [[], [], [('reservation', 'i', 'l')], []],
#              'quallfylng': [[], [], [], []],
#              'studylng': [[], [], [('studying', 'i', 'l')], []],
#              'Capplng': [[], [], [], []],
#              'Secretary:': [[], [], [], []],
#              'Tumlpseed': [[], [], [], []],
#              'enactment': [[('enactments', 't', 's')],
#               [('nactment', '{', 'e')],
#               [],
#               []],
#              '1991': [[], [], [], []],
#              'lssues.': [[], [], [], []],
#              'Drlglnal': [[], [], [], []],
#              'orlglnally': [[], [], [], []],
#              'provlslon.': [[], [], [], []],
#              '311': [[], [], [], []],
#              'Owners,': [[], [], [], []],
#              'occupatlonal': [[],
#               [],
#               [('occupaclonal', 'c', 't'), ('occupational', 'i', 'l')],
#               []],
#              'revlslng': [[], [], [], []],
#              'llmltatlons': [[], [], [], []],
#              'expressed': [[], [], [('expresses', 's', 'd')], []],
#              'CAER.': [[], [], [], []],
#              'dlstlnctlon': [[], [], [], []],
#              '1997799': [[], [], [], []],
#              'tarlffs,': [[], [], [], []],
#              '037773': [[], [], [], []],
#              'statement': [[('statements', 't', 's')], [], [], []],
#              'brlefs': [[], [], [('briefs', 'i', 'l')], []],
#              'flxlng,': [[], [], [], []],
#              '1.0,': [[], [], [], []],
#              '1ndependent': [[], [], [], []],
#              'carclnogen': [[], [], [('carcinogen', 'i', 'l')], []],
#              'consultatlon': [[], [], [('consultation', 'i', 'l')], []],
#              'TSCA.': [[], [], [], []],
#              'percent.': [[], [('percent', '', '')], [], []],
#              'country,': [[], [('country', '', '')], [], []],
#              'dlscussl': [[], [], [], []],
#              'mechanlsm': [[], [], [('mechanism', 'i', 'l')], []],
#              'r': [[('ar', '{', 'a'),
#                ('dr', '{', 'd'),
#                ('er', '{', 'e'),
#                ('fr', '{', 'f'),
#                ('gr', '{', 'g'),
#                ('hr', '{', 'h'),
#                ('ir', '{', 'i'),
#                ('jr', '{', 'j'),
#                ('mr', '{', 'm'),
#                ('or', '{', 'o'),
#                ('pr', '{', 'p'),
#                ('sr', '{', 's'),
#                ('tr', '{', 't'),
#                ('ur', '{', 'u'),
#                ('yr', '{', 'y'),
#                ('ra', 'r', 'a'),
#                ('rd', 'r', 'd'),
#                ('re', 'r', 'e'),
#                ('ri', 'r', 'i'),
#                ('rk', 'r', 'k'),
#                ('rm', 'r', 'm'),
#                ('ro', 'r', 'o'),
#                ('rs', 'r', 's'),
#                ('rt', 'r', 't'),
#                ('ry', 'r', 'y')],
#               [],
#               [],
#               []],
#              'longiterm': [[], [('longterm', 'g', 'i')], [], []],
#              '1932,': [[], [], [], []],
#              ';': [[], [], [], []],
#              'maxlmlze': [[], [], [], []],
#              '2.12': [[], [], [], []],
#              '(Exhlblt': [[], [], [], []],
#              '1.5': [[], [], [], []],
#              'placement': [[], [], [], []],
#              'Addltlonally,': [[], [], [], []],
#              'electrlc': [[], [], [('electric', 'i', 'l')], []],
#              'worklng': [[], [], [('working', 'i', 'l')], []],
#              'appllcat': [[], [], [], []],
#              'Electr': [[], [], [], []],
#              'reau.thorlzatlon': [[], [('reauthorlzatlon', '', '')], [], []],
#              'past.': [[], [('past', '', '')], [], []],
#              'deslgn': [[], [], [('design', 'i', 'l')], []],
#              'reexamlnatlon': [[], [], [], []],
#              "EEC'S": [[], [], [], []],
#              '1ncluded.': [[], [], [], []],
#              'Actlvltles': [[], [], [], []],
#              'governmental': [[], [], [], []],
#              'Reportlng.': [[], [], [], []],
#              'Internatlonal': [[], [], [], []],
#              'Conventlon': [[], [], [], []],
#              'Affalrs': [[], [], [], []],
#              'Membersh': [[], [], [], []],
#              'Sltes': [[], [], [], []],
#              'bllateral': [[], [], [('bilateral', 'i', 'l')], []],
#              'offlclals': [[], [], [], []],
#              'communlty': [[], [], [('community', 'i', 'l')], []],
#              'technlque': [[], [], [('technique', 'i', 'l')], []],
#              'tlvely': [[], [], [('tively', 'i', 'l')], []],
#              'company.': [[], [('company', '', '')], [], []],
#              '1ntellectual': [[], [], [], []],
#              'extremely': [[], [], [], []],
#              'wlllful': [[], [], [('willful', 'i', 'l')], []],
#              'arrangements': [[], [('arrangement', 't', 's')], [], []],
#              ...})
